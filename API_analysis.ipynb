# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# ### Analysing *batting_stats()* with different paramters

# %%
all_data_2019 = batting_stats(2019)

# %%
all_data_2019 = batting_stats(2019)
players_with_more_than_50 = batting_stats(2019, qual=50)
all_data_since_2015 = batting_stats(2015, 2019)
aggregated_data = batting_stats(2010, 2016, ind=0)

print(all_data_2019.head())
print(players_with_more_than_50.head())
print(all_data_since_2015.head())
print(aggregated_data.head())

# %% [markdown]
# # Conclusion for batting_stats()
# Very versitile function that can take one or two years as parameters (single season or multiple seasons). It would return a dataframe with 287 columns with all the batting statistics for every single player for the whole season/seasons. A lot of statistics!
#
# ### Analysing *schedule_and_record()*

# %%
from pybaseball import schedule_and_record

Astros_record = schedule_and_record(2019, "HOU")
Astros_record.head(20)

# %%
Astros_record.columns

# %% [markdown]
# ### Conclusion for schedule_and_record()
# Very useful function that can get the players who played in each game, and also all the dates in which each a team played in a season, among others. It only has 19 columns, but this will be used as a *link* table between the others.
#
# ## Analysing *batting_stats_range()*

# %%
data_range = batting_stats_range("2019-09-01","2019-09-30")
data_range

# %%
print(data_range.columns)
print(all_data_2019.columns)

# %% [markdown]
# ### Conclusion for *batting_stats_range()*
#
# this functions returns a much smaller dataframe with only 27 columns. This will be useful to get the most recent information for each player right before each game.
#
# # Let's look at all the columns for batting_stats() and batting_stats_range()

# %%
print(all_data_2019.columns[:95])

# %%
print(all_data_2019.columns[95:190])

# %%
print(all_data_2019.columns[190:])

# %%
len(all_data_2019.columns)

# %%
len(data_range.columns)

# %% [markdown]
# ### Let's see what columns in the smaller dataframe are also in the larger df

# %%
shared_columns = list(data_range.columns & all_data_2019.columns)

# %%
shared_columns

# %%
len(shared_columns)

# %% [markdown]
# ### basically all of them. Only 4 are not included. Let's see which one are not in the larger df.

# %%
range_columns_not_in_all_data = list(data_range.columns.difference(all_data_2019.columns))
range_columns_not_in_all_data

# %% [markdown]
# # So #days is a useless column, BA is the same as AVG, Lev is useless too, and Tm is the same as Team. As a conclusion, all the columns are included.

# %%
Astros_2019stats  =  all_data_2019[all_data_2019["Team"]=="Astros"]

# %%
Astros_2019stats.count()

# %%
#Thursday, Mar 28
#"2019-03-28"
game_march_28_2019 = batting_stats_range("2019-03-28",)

# %%
game_march_28_2019["Tm"].unique

# %%
game_march_28_2019[game_march_28_2019["Tm"]=="Houston"]

# %% [markdown]
# ## ...We can see who played in every game ^

# %%
game_march_28_2019.columns

# %%
game_march_28_2019.iloc[:,6]

# %% [markdown]
# ### *"@"* means they're playing as *visitors*.

# %% [markdown]
# # Startegy:
# ### General Strategy:
# Retrieve data for each player in each game played. Feed the model with data from past year for each player and past month. Build a dataframe where each row represents the features to train the model and to make predictions out of the model.
#
# Each row would have the full 283 features from past season plus the 23 from past month for each player that played the particular game plus 2 team features.
#
# ### Specific Tasks
#
# Usually there are 9 players, so there would be 9 times 283 features only to account for past season statistics of 1 team. So this number would be later mulitply also by 2 since each game involves 2 teams. We will use **schedule_and_record()** function to get the players who played in a game, so we can later use **batting_stats()** function to get those 283 features from last season for each player that played a particular game.
#
# There will be also recent statistics from last month for each player as well, which is 22 features. Again this number would be multiply by 9 and then by 2. We will use **schedule_and_record()** function to get the players who played in that game, so we can later retrieve the past month statistics for each one of those players from **batting_stats_range()**.
#
# There will be also statistics from the team to be included in each record such as streak, and GB, also gotten from **schedule_and_record()**.
#
# ### Conclusion
# The training DataFrame will contain a record for each game of a single team and its opponent. This leads us to  **DataFrame with dimensions of 5494 columns by *Games-Played-By-The-Team* rows**. This is only batting statistics so far.

# %% [markdown]
# ## Analysing *pitching_stats()*

# %%
from pybaseball import pitching_stats

pitching_stats_2019 = pitching_stats("2019")
pitching_stats_2019.head(15)

# %%
pitching_stats_2019.columns

# %%
pitching_stats_2019.columns[:100]

# %%
pitching_stats_2019.columns[100:200]

# %%
pitching_stats_2019.columns[200:]

# %% [markdown]
# ### Aparanetly, we should use only the *(pi)* variables. They are calculated using a new algorythm that eliminates what Brooks Baseball considers errors from Pitch FX (pfx).
#
# link: https://www.reddit.com/r/Sabermetrics/comments/6qepoa/what_is_the_data_source_for_nonattributed_plate/

# %%
pfx_col = [x for x in pitching_stats_2019.columns if "(pfx)" in x ]
pfx_col

# %%
pitching_stats_2019.drop( columns = pfx_col, inplace=True )
pitching_stats_2019.columns

# %%
from pybaseball import pitching_stats_range

pitching_range_1day = pitching_stats_range("2019-03-28",)

# %%
pitching_range_1day.head()

# %%
pitchers_Astros_on_20190328 = pitching_range_1day[pitching_range_1day.Tm == "Houston"]
pitchers_Astros_on_20190328

# %% [markdown]
# ## So! we can know who pitched on a certain game ^

# %%
pitchers_Astros_on_20190328.columns

# %% [markdown]
# #### An idea is to keep columns that represent % of other columns. For example, keeping IFFB% but droping IFFB, since a percentage tells more of a story that an isolated scalar value. In this way, we can reduce redundancy in our features and, therefore, the total size of our features array.

# %%
bat_col_not_to_drop = [x for x in all_data_2019.columns if "%" in x and x[:-1] in all_data_2019.columns]
bat_col_not_to_drop

# %%
bat_col_to_drop = [x[:-1] for x in bat_col_not_to_drop]
bat_col_to_drop

# %%
pitch_col_not_to_drop = [x for x in pitching_stats_2019.columns if "%" in x and x[:-1] in pitching_stats_2019.columns]
pitch_col_not_to_drop

# %%
pitch_col_to_drop = [x[:-1] for x in pitch_col_not_to_drop]
pitch_col_to_drop

# %%
all_data_2019.drop(columns=bat_col_to_drop, inplace=True)
pitching_stats_2019.drop(columns=pitch_col_to_drop, inplace=True)
print(f"Total columns in bat_statistics: {len(all_data_2019.columns)}\nTotal columns in pitch_statistics: {len(pitching_stats_2019.columns)} ")

# %% [markdown]
# ### ...We still have loooots of columns.
#
#
# ##### We will have to get rid of some columns manually that we consider unnecesary such as "Age" or "Team", etc. However, some of these columns might be useful during concatenation, so we will handle this in within the function that creates the dataframe.
#
# ## Let's explore how many pitcher there are per game usually

# %%
# let's grab our datframe created through record_and_schedule() previously for The Astros season 2019:
Astros_record.head()

# %% [markdown]
# ### We will have to convert the date format cuz these guys are assholes

# %%
date = Astros_record.Date[1]
#date = date.split(",")
date = re.findall(r"\w* [0-9][0-9]|[0-9]", date)
date = date[0]
print(date)
year = "2019"
date = year + " " + date
date

# %%
import datetime as dt

# %%
date_formatted = dt.datetime.strptime(date,"%Y %b %d")
date_formatted

# %%
date_formatted.month

# %% [markdown]
# ### it worked out, so now we know how

# %%
type(date_formatted)

# %% [markdown]
# # %%%%%%%    Building the Training DataFrame    %%%%%%%%

# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
teams = set(all_data_2017["Team"])
teams
# Out:
# {'- - -',
#  'Angels',
#  'Astros',
#  'Athletics',
#  'Blue Jays',
#  'Braves',
#  'Brewers',
#  'Cardinals',
#  'Cubs',
#  'Diamondbacks',
#  'Dodgers',
#  'Giants',
#  'Indians',
#  'Mariners',
#  'Marlins',
#  'Mets',
#  'Nationals',
#  'Orioles',
#  'Padres',
#  'Phillies',
#  'Pirates',
#  'Rangers',
#  'Rays',
#  'Red Sox',
#  'Reds',
#  'Rockies',
#  'Royals',
#  'Tigers',
#  'Twins',
#  'White Sox',
#  'Yankees'}

# %%
team_dict = {'Angels':'LAA',
            'Athletics': 'OAK',
            'Astros': 'HOU',
            'Braves': 'ATL',
            'Brewers': 'MIL',
            'Cards': 'STL',
            'Cubs': 'CUB',
            'Diamondbacks': 'ARI',
            'Dodgers': 'LAD',
            'Giants': 'SFG',
            'Indians': 'CLE',
            'Blue Jays': 'TOR',
            'Mariners': 'SEA',
            'Marlins': 'MIA',
            'Mets': 'NYM',
            'Nats': 'WAS',
            'Orioles': 'BAL',
            'Padres': 'SDP',
            'Phillies': 'PHI',
            'Pirates': 'PIT',
            'Rangers': 'TEX',
            'Rays': 'TBR',
            'Red Sox': 'BOS',
            'Reds': 'CIN',
            'Rockies': 'COL',
            'Royals': 'KCR',
            'Tigers': 'DET',
            'Twins': 'MIN',
            'White_Sox': 'CHW',
            'Yankees': 'NYY'
             
           }
def get_key_from_dict(dictionary, val): 
    for key, value in dictionary.items(): 
         if val == value: 
            return key

# %%
from pybaseball import pitching_stats

def format_dates_to_dt(un_date="Monday, Dec 31", year=1999):
    date = re.findall(r"\W\w\w\w\s\d+", un_date)
    date = date[0]
    date = str(year) + date
    date_formatted = dt.datetime.strptime(date,"%Y %b %d")
    return date_formatted

# %%
def modify_dates_from_lineups(date="1. Thu,3/29 at TEX W (4-1)#", year = 2018):
    date = re.findall(r"\d+/\d+", date)
    try: date = date[0]
    except: return
    date = str(year) +" " + date
    return date

# %%
def modify_date_col_from_lineups(df, year):
    df["0"] = df.apply(lambda x: modify_dates_from_lineups(x["0"],year), axis=1)
    df["0"] = pd.to_datetime(df["0"])
    return df

# %%
def clean_lineups(df):
    for row in range(0,len(df)):
        for column in range(2,11):
            original_name = df.iloc[row,column]
            name = original_name.split("-")
            name = name[0]
            df.replace(original_name,name, inplace=True)
            #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
            #has the same names over and over. We just need to grab all the different names and replace them
    return df

# %%
def format_lineups_df(df, year):
    df  =  modify_date_col_from_lineups(df, year)
    df = clean_lineups(df)
    df.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
    df.set_index("index", inplace=True, drop=True)
    return df

# %%
def get_dates_played(df=None,year=None):
    
    dates_played = [format_dates_to_dt(date, year) for date in df.Date]
    return dates_played

# %%
def get_team_schedule(year=None, team = "HOU"):
    
    teams_df  = schedule_and_record(year, team)
    teams_df  = teams_df.iloc[ : , [0,1,2,3,10,17] ]
    teams_df["Date"] = teams_df.apply(lambda x: format_dates_to_dt(x["Date"],year), axis=1)
    teams_df.replace("@",1, inplace=True)
    teams_df.replace("Home",0, inplace=True)
    return teams_df

# %%
def get_players_per_game(year = None, team = None):
    
    schedule_df = get_team_schedule(year, team)
    opponents = set(schedule_df["Opp"])
    
    bat_stat_path = Path(f"Data/Batting/Clean_Data/clean_batting_data_{year}.csv")
    all_bat_stats = pd.read_csv(bat_stat_path)
    
    lineups_path = Path(f"Lineups/{team}_lineups_{year}.csv")
    all_lineups_season = pd.read_csv(lineups_path)
    all_lineups_season = format_lineups_df(all_lineups_season, year)
    
    opponents_lineups = {}
    for opponent in opponents:
        opp_lineups_path = Path(f"Lineups/{opponent}_lineups_{year}.csv")
        opp_all_lineups_season = pd.read_csv(opp_lineups_path)
        #print(f"opp: {opponent}")
        opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
        opponents_lineups.update({opponent:opp_all_lineups_season})
    
    players_df = pd.DataFrame()
    
    i = 0
    for date in schedule_df["Date"]:
        
        
        adversary = schedule_df[schedule_df["Date"]==date.strftime("%Y-%m-%d")]["Opp"].values[0]

        temp_dict = {"Date":date}

        ##Line ups for the team
        try: all_players_on_date = all_lineups_season[all_lineups_season["Date"]==date.strftime("%Y-%m-%d")]
            
        except:
            print(f"No game on this date {date} for team")
            continue
            
        count = 1  
        all_players_team = all_players_on_date.iloc[0]       
        for player in all_players_team[1:]:            
            temp_dict.update({f"player_{count:02}" : player})           
            count+=1
            
        ##Line ups for the adversary
        try:
            opp_lineups_df = opponents_lineups[adversary]
            all_opponents_on_date = opp_lineups_df[opp_lineups_df["Date"]==date.strftime("%Y-%m-%d")]
            all_opponents_on_date.columns = ["Date","10","11","12","12","14","15","16","17","18"]
        except:
            print(f"No game on this date {date} for opponent")
            continue

        count = 10  
        all_players_opp = all_opponents_on_date.iloc[0]       
        for enemy in all_players_opp[1:]:            
            temp_dict.update({f"player_{count:02}" : enemy})           
            count+=1
         
              
        temp_df = pd.DataFrame(temp_dict, index =[i])
        players_df = pd.concat([players_df,temp_df], axis=0, sort = True )
        i+=1
        
    schedule_df.set_index("Date", inplace=True)
    players_df.set_index("Date", inplace=True)
    teams_df = pd.concat([schedule_df,players_df], axis=1, join="inner")
    teams_df.reset_index(inplace=True, drop=False)
    
    return teams_df

# %%
players_per_game_for_HOU_2018 = get_players_per_game(year = 2018, team = "HOU")
players_per_game_for_HOU_2018.head(20)
# Out:
# opp: KCR
# opp: DET
# opp: TBR
# opp: BOS
# opp: OAK
# opp: CHW
# opp: LAD
# opp: TOR
# opp: MIN
# opp: TEX
# opp: CLE
# opp: LAA
# opp: SDP
# opp: ARI
# opp: SFG
# opp: NYY
# opp: COL
# opp: BAL
# opp: SEA
#          Date   Tm  Home_Away  Opp      GB  Streak player_01 player_02  \
# 0  2018-03-29  HOU          1  TEX    Tied       1  Springer   Bregman
# 1  2018-03-30  HOU          1  TEX     0.5      -1  Springer   Reddick
# 2  2018-03-31  HOU          1  TEX    Tied       1  Springer   Bregman
# 3  2018-04-01  HOU          1  TEX    Tied       2  Springer   Bregman
# 4  2018-04-02  HOU          0  BAL  up 1.0       3  Springer   Bregman
# 5  2018-04-03  HOU          0  BAL  up 1.0       4  Springer   Bregman
# 6  2018-04-04  HOU          0  BAL  up 1.0       5  Springer   Bregman
# 7  2018-04-06  HOU          0  SDP    Tied      -1  Springer   Bregman
# 8  2018-04-07  HOU          0  SDP  up 1.0       1  Springer   Bregman
# 9  2018-04-08  HOU          0  SDP  up 1.0       2  Springer   Bregman
# 10 2018-04-09  HOU          1  MIN  up 1.0       3  Springer   Bregman
# 11 2018-04-10  HOU          1  MIN    Tied      -1  Springer   Bregman
# 12 2018-04-11  HOU          1  MIN     1.0      -2  Springer   Bregman
# 13 2018-04-13  HOU          0  TEX     1.5       1  Springer   Bregman
# 14 2018-04-14  HOU          0  TEX     2.5      -1  Springer   Bregman
# 15 2018-04-15  HOU          0  TEX     3.0      -2  Springer   Bregman
# 16 2018-04-16  HOU          1  SEA     3.5      -3  Springer   Bregman
# 17 2018-04-17  HOU          1  SEA     2.5       1  Springer    Altuve
# 18 2018-04-18  HOU          1  SEA     1.5       2  Springer    Altuve
# 19 2018-04-19  HOU          1  SEA     0.5       3  Springer    Altuve
#
#    player_03 player_04  ...  player_09  player_10 player_11 player_12  \
# 0     Altuve    Correa  ...     McCann  DeShields     Gallo    Andrus
# 1     Altuve    Correa  ...     Stassi  DeShields     Gallo    Andrus
# 2     Altuve    Correa  ...  Marisnick     Andrus     Gallo    Beltre
# 3     Altuve    Correa  ...     Fisher     Andrus     Gallo    Beltre
# 4     Altuve    Correa  ...     Fisher      Davis   Machado    Schoop
# 5     Altuve    Correa  ...     Fisher      Davis   Machado    Schoop
# 6     Altuve   Reddick  ...     Fisher    Beckham   Machado    Schoop
# 7     Altuve    Correa  ...     Fisher     Margot    Pirela    Hosmer
# 8     Altuve    Correa  ...  Marisnick     Pirela    Galvis    Hosmer
# 9     Altuve    Correa  ...     Fisher     Asuaje    Hosmer    Pirela
# 10    Altuve    Correa  ...     Fisher     Dozier     Mauer      Sano
# 11    Altuve    Correa  ...  Marisnick     Dozier     Mauer      Sano
# 12    Altuve    Correa  ...     Fisher     Dozier     Mauer   Rosario
# 13    Altuve    Correa  ...  Marisnick       Choo    Profar    Mazara
# 14    Altuve    Correa  ...     Stassi       Choo    Profar     Gallo
# 15    Altuve    Correa  ...     Fisher       Choo    Profar    Mazara
# 16    Altuve    Correa  ...  Marisnick     Gordon    Segura      Cano
# 17    Correa   Gurriel  ...  Marisnick     Gordon    Segura      Cano
# 18    Correa   Reddick  ...     Fisher     Gordon    Segura      Cano
# 19    Correa    Gattis  ...  Marisnick     Gordon    Segura      Cano
#
#      player_13 player_14 player_15    player_16    player_17  player_18
# 0       Beltre    Mazara      Choo     Chirinos         Odor        Rua
# 1       Beltre    Mazara      Choo     Chirinos         Odor        Rua
# 2       Mazara      Choo      Odor      Centeno     Robinson      Tocci
# 3       Mazara  Chirinos      Odor          Rua       Profar   Robinson
# 4        Jones   Mancini    Rasmus      Beckham      Alvarez     Joseph
# 5        Jones   Mancini    Rasmus      Beckham        Sisco  Santander
# 6        Jones   Mancini  Valencia    Santander       Joseph     Gentry
# 7   Villanueva   Renfroe    Asuaje       Galvis  Spangenberg     Hedges
# 8   Villanueva    Asuaje   Renfroe  Spangenberg        Ellis     Margot
# 9   Villanueva   Headley   Renfroe       Galvis       Hedges     Margot
# 10     Rosario  Morrison   Escobar       Kepler       Buxton     Castro
# 11     Escobar  Grossman  Morrison       Garver       Buxton    LaMarre
# 12    Morrison   Escobar    Kepler       Buxton       Castro   Adrianza
# 13      Beltre     Gallo    Guzman     Chirinos     Robinson      Kiner
# 14      Beltre    Guzman       Rua      Centeno        Kiner   Robinson
# 15      Beltre     Gallo    Guzman     Chirinos        Kiner      Tocci
# 16        Cruz    Seager   Haniger      Heredia       Motter    Freitas
# 17        Cruz    Seager   Haniger    Vogelbach       Suzuki    Marjama
# 18        Cruz    Seager   Haniger        Gamel    Vogelbach    Freitas
# 19        Cruz    Seager   Haniger        Gamel    Vogelbach    Freitas
#
# [20 rows x 24 columns]

# %%
x = players_per_game_for_HOU_2018.iloc[0][3]
x
# Out:
# 'TEX'

# %%
def get_col_explanation(col1,col2):
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    try: col1 = [x.split("_")[1] for x in col1 if x is not "index"]
    except: pass
    try: col2 = [x.split("_")[1] for x in col2 if x is not "index"]
    except: pass   
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    if(len(col1)>len(col2)):missing_col = list(set(col1).difference(set(col2)))
    else:missing_col = list(set(col2).difference(set(col1)))
    return missing_col

# %%
get_col_explanation(["1_a","222_b","2_c"],["222_b","1_c"])
# Out:
# column 1: ['1_a', '222_b', '2_c']
# column2: ['222_b', '1_c']
# column 1: ['a', 'b', 'c']
# column2: ['b', 'c']
# ['a']

# %%
type(players_per_game_for_HOU_2018.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
def get_stats_startingplayer_by_game(players_df, team, year):
    
    batting_season_data = batting_stats(year-1)   
    #pitching_season_data = pitching_stats(year)
    #print(pitching_season_data.head()) 
    
    stats_players_start_lineup = pd.DataFrame()
    
    for row in range(0,len(players_df)):
        #print(row)       
        all_players_stats = pd.DataFrame()
        all_players_team_stats = pd.DataFrame()
        all_players_opp_stats = pd.DataFrame()
        
        #for players of team  
        count =1
        for player in players_df.iloc[row][6:15]:
            #print(f"players: {len(players_df.iloc[row][6:])}\n {players_df.iloc[row][6:]}")
            if("00:00:00" in str(player)): continue #it gets the Date as first row by default. Skip it.
                
            try: 
                all_team_bat_stats = batting_season_data[batting_season_data.Team == get_key_from_dict(team_dict,team)]
                #print(f"ALL TEAM STATS :\n{all_team_bat_stats.head()}")
                player_full_name = [x for x in all_team_bat_stats.Name if player in x]
                #print(player_full_name)
                player_bat_stats = all_team_bat_stats[all_team_bat_stats.Name == player_full_name[0]]
              
                #print(f"Stats for player {player_full_name} only: \n{player_bat_stats}")

            except: 
                print(f"{player} not in batting list")
                #create code to fill batting statistics for a new player full of NAs or 0.0
                try:
                    nanlist = np.empty((1,len(player_bat_stats.columns)))
                except Exception as e:
                    print(f"Not able to get columns from last player\n{e}")
                    continue
                nanlist.fill(np.nan)
                #fake_columns = columns = ["index",*batting_season_data.columns]
                fake_columns = []
                for col in player_bat_stats.columns:
                    try: fake_columns.append(col.split("_")[1])
                    except: fake_columns.append(col)
                #print(fake_columns)
                player_bat_stats = pd.DataFrame(data = nanlist, columns = fake_columns)
                player_bat_stats.drop(columns=["index"], inplace=True)
                #print(player_bat_stats)
                #continue
                
                
            new_col = []
            for col in player_bat_stats.columns:
                new_col.append(f"{count:02}_{col}")
            player_bat_stats.columns = new_col
                
                
                
            player_bat_stats.reset_index(inplace=True)
            #print(f"SINGLE_PLAYER_STAT ++++++++++++++\n{player_bat_stats}")
            all_players_team_stats = pd.concat([ all_players_team_stats, player_bat_stats ] ,   axis=1)
            #print(f"ALL_PLAYER_STAT ##############\n{all_players_team_stats}")
            count+=1
            
         #for players of opponent 
        #count=10
        for enemy in players_df.iloc[row][15:24]:
            #print(f"players: {len(players_df.iloc[row][6:])}\n {players_df.iloc[row][6:]}")
            if("00:00:00" in str(enemy)): continue #it gets the Date as first row by default. Skip it.
                
            try: 
                #print(f"row[3]: {players_df.iloc[row][3]}")
                all_opp_bat_stats = batting_season_data[batting_season_data.Team == 
                                                         get_key_from_dict(team_dict,players_df.iloc[row][3])]
                #print(f"ALL OPPONENT STATS :\n{all_opp_bat_stats.head()}")
                enemy_full_name = [x for x in all_opp_bat_stats.Name if enemy in x]
                #print(player_full_name)
                enemy_bat_stats = all_opp_bat_stats[all_opp_bat_stats.Name == enemy_full_name[0]]
                #print(f"Stats for player {player_full_name} only: \n{player_bat_stats}")

            except: 
                print(f"enemy {enemy} not in batting list")
                #create code to fill batting statistics for a new player full of NAs or 0.0
                try:
                    nanlist = np.empty((1,len(enemy_bat_stats.columns)))
                except Exception as e:
                    print(f"Not able to get columns from last enemy\n{e}")
                    continue
                nanlist.fill(np.nan)
                fake_columns = []
                for col in enemy_bat_stats.columns:
                    try: fake_columns.append(col.split("_")[1])
                    except: fake_columns.append(col)
                #fake_columns = batting_season_data.columns
                #print(f"explanation: \n{get_col_explanation(fake_columns,enemy_bat_stats.columns)}")
                enemy_bat_stats = pd.DataFrame(data = nanlist, columns = fake_columns)
                enemy_bat_stats.drop(columns=["index"], inplace=True)
                #print(enemy_bat_stats)
                #continue
            
            
            new_col = []
            for col in enemy_bat_stats.columns:
                new_col.append(f"{count:02}_{col}")
            enemy_bat_stats.columns = new_col
                     
            try: enemy_bat_stats.reset_index(inplace=True)
            except: 
                #print("couldnt reset index")
                pass
            
            
            #print(f"SINGLE_PLAYER_STAT ++++++++++++++\n{player_bat_stats}")
            all_players_opp_stats = pd.concat([ all_players_opp_stats, enemy_bat_stats] ,   axis=1)
            #print(f"ALL_OPPONENT_STAT ##############\n{all_players_opp_stats}")
            count+=1
            
        try:
            all_players_stats = pd.concat([ all_players_team_stats, all_players_opp_stats] ,   axis=1)
            #print(f"CONCATENATE_STATS ******\n***********\n{all_players_stats}")
        except Exception as e: 
            #print(f"could concatenate team with opponent stats\n{e}")
            continue
            
        try: 
            stats_players_start_lineup = stats_players_start_lineup.append(all_players_stats, ignore_index=True)
            #stats_players_start_lineup = pd.concat([stats_players_start_lineup,all_players_stats], join="inner",axis=0, sort = True )
        except Exception as e: 
            #print(f"could not append {e}")
            #print(f"explanation: \n{get_col_explanation(stats_players_start_lineup.columns,all_players_stats.columns)}")
            
            continue
        
    
    return stats_players_start_lineup

# %%
test = get_stats_startingplayer_by_game(players_per_game_for_HOU_2018, "HOU", 2018)
test
# Out:
# 0
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -0.41          -5.21             0.346
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.608           0.461               0.509               0.752
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0              0.65           0.44          22.3
#
# [1 rows x 5184 columns]
# 1
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -0.41          -5.21             0.346
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.608           0.461               0.509               0.752
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0              0.65           0.44          22.3
#
# [1 rows x 5184 columns]
# 2
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Centeno not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# row[3]: TEX
# enemy Tocci not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 3
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...           0.33            NaN             0.274
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.628           0.434                0.56               0.781
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.704          0.451          26.1
#
# [1 rows x 5184 columns]
# 4
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Rasmus not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: BAL
# enemy Beckham not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: BAL
# row[3]: BAL
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -0.55            NaN             0.358
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.642           0.494                0.66               0.825
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.762          0.479          23.2
#
# [1 rows x 5184 columns]
# 5
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Rasmus not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: BAL
# enemy Beckham not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: BAL
# row[3]: BAL
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -4.53            NaN             0.536
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.726           0.617               0.595               0.784
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.689          0.425          25.8
#
# [1 rows x 5184 columns]
# 6
# row[3]: BAL
# enemy Beckham not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Valencia not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...           0.94           4.97             0.245
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.655           0.436               0.603               0.882
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.798          0.465          23.8
#
# [1 rows x 5184 columns]
# 7
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# enemy Hosmer not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# enemy Galvis not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# row[3]: SDP
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -3.61            NaN             0.383
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.696            0.53               0.518                0.81
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.698          0.469          23.4
#
# [1 rows x 5184 columns]
# 8
# row[3]: SDP
# row[3]: SDP
# enemy Galvis not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '10_Season', '10_Name', '10_Team', '10_Age', '10_G', '10_AB',
#        '10_PA', '10_H', '10_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# enemy Hosmer not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# enemy Ellis not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -0.13            NaN             0.283
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.624           0.455               0.623               0.891
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.808          0.504          21.3
#
# [1 rows x 5184 columns]
# 9
# row[3]: SDP
# row[3]: SDP
# enemy Hosmer not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '10_Season', '10_Name', '10_Team', '10_Age', '10_G', '10_AB',
#        '10_PA', '10_H', '10_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# row[3]: SDP
# row[3]: SDP
# enemy Headley not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '13_Season', '13_Name', '13_Team', '13_Age', '13_G', '13_AB',
#        '13_PA', '13_H', '13_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# row[3]: SDP
# enemy Galvis not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SDP
# row[3]: SDP
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -0.13            NaN             0.283
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.624           0.455               0.623               0.891
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.808          0.504          21.3
#
# [1 rows x 5184 columns]
# 10
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Morrison not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '13_Season', '13_Name', '13_Team', '13_Age', '13_G', '13_AB',
#        '13_PA', '13_H', '13_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -1.48          -4.27             0.249
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.642           0.445               0.557               0.781
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.718          0.499          27.1
#
# [1 rows x 5184 columns]
# 11
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Morrison not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy LaMarre not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 12
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Morrison not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '12_Season', '12_Name', '12_Team', '12_Age', '12_G', '12_AB',
#        '12_PA', '12_H', '12_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -2.04            NaN              0.23
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.625           0.424               0.798               0.941
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.901          0.491          25.6
#
# [1 rows x 5184 columns]
# 13
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 14
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '13_Season', '13_Name', '13_Team', '13_Age', '13_G', '13_AB',
#        '13_PA', '13_H', '13_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# row[3]: TEX
# enemy Centeno not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# enemy Kiner not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...           0.33            NaN             0.274
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.628           0.434                0.56               0.781
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.704          0.451          26.1
#
# [1 rows x 5184 columns]
# 15
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: TEX
# enemy Tocci not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 16
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Freitas not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 17
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Suzuki not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: SEA
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...         -10.35            NaN             0.286
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0              0.75           0.609                 0.5               0.917
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.857          0.696          17.9
#
# [1 rows x 5184 columns]
# 18
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Freitas not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 19
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Freitas not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 20
# row[3]: CHW
# enemy Moncada not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Garcia not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '10_Season', '10_Name', '10_Team', '10_Age', '10_G', '10_AB',
#        '10_PA', '10_H', '10_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Abreu not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Delmonico not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '12_Season', '12_Name', '12_Team', '12_Age', '12_G', '12_AB',
#        '12_PA', '12_H', '12_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Castillo not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '13_Season', '13_Name', '13_Team', '13_Age', '13_G', '13_AB',
#        '13_PA', '13_H', '13_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Sanchez not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Anderson not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Narvaez not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Engel not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 21
# row[3]: CHW
# enemy Anderson not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Garcia not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '10_Season', '10_Name', '10_Team', '10_Age', '10_G', '10_AB',
#        '10_PA', '10_H', '10_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Abreu not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Castillo not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '12_Season', '12_Name', '12_Team', '12_Age', '12_G', '12_AB',
#        '12_PA', '12_H', '12_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Davidson not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '13_Season', '13_Name', '13_Team', '13_Age', '13_G', '13_AB',
#        '13_PA', '13_H', '13_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Moncada not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Thompson not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Sanchez not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Engel not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 22
# row[3]: CHW
# enemy Moncada not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Garcia not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '10_Season', '10_Name', '10_Team', '10_Age', '10_G', '10_AB',
#        '10_PA', '10_H', '10_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Abreu not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Delmonico not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '12_Season', '12_Name', '12_Team', '12_Age', '12_G', '12_AB',
#        '12_PA', '12_H', '12_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Castillo not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '13_Season', '13_Name', '13_Team', '13_Age', '13_G', '13_AB',
#        '13_PA', '13_H', '13_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Davidson not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Sanchez not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '15_Season', '15_Name', '15_Team', '15_Age', '15_G', '15_AB',
#        '15_PA', '15_H', '15_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Anderson not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '16_Season', '16_Name', '16_Team', '16_Age', '16_G', '16_AB',
#        '16_PA', '16_H', '16_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: CHW
# enemy Garcia not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '17_Season', '17_Name', '17_Team', '17_Age', '17_G', '17_AB',
#        '17_PA', '17_H', '17_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...            NaN            NaN               NaN
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               NaN             NaN                 NaN                 NaN
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               NaN            NaN           NaN
#
# [1 rows x 5184 columns]
# 23
# row[3]: LAA
# enemy Kinsler not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -2.47            NaN             0.349
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.635           0.491                0.49               0.884
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.743          0.495          27.4
#
# [1 rows x 5184 columns]
# 24
# row[3]: LAA
# enemy Kinsler not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '14_Season', '14_Name', '14_Team', '14_Age', '14_G', '14_AB',
#        '14_PA', '14_H', '14_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# CONCATENATE_STATS ******
# ***********
#    index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#     01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0  155.0   92.0  ...          -2.47            NaN             0.349
#
#    18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0             0.635           0.491                0.49               0.884
#
#    18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0             0.743          0.495          27.4
#
# [1 rows x 5184 columns]
# 25
# row[3]: LAA
# enemy Kinsler not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '18_Season', '18_Name', '18_Team', '18_Age', '18_G', '18_AB',
#        '18_PA', '18_H', '18_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: Index(['index', '11_Season', '11_Name', '11_Team', '11_Age', '11_G', '11_AB',
#        '11_PA', '11_H', '11_1B'],
#       dtype='object')
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# ['index']
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# column 1: ['index', 'Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B']
# ...
# 23      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 24      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 25      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 26      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 27      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 28      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 29      79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# ..     ...        ...              ...     ...     ...    ...    ...    ...
# 132     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 133     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 134     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 135     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 136     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 137     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 138     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 139     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 140     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 141     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 142     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 143     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 144     48     2017.0      Jose Altuve  Astros    27.0  153.0  590.0  662.0
# 145     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 146     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 147     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 148     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 149     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 150     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 151     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 152     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 153     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 154     48     2017.0      Jose Altuve  Astros    27.0  153.0  590.0  662.0
# 155     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 156     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 157    172     2017.0   Jake Marisnick  Astros    26.0  106.0  230.0  259.0
# 158     48     2017.0      Jose Altuve  Astros    27.0  153.0  590.0  662.0
# 159     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 160     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
# 161     79     2017.0  George Springer  Astros    27.0  140.0  548.0  629.0
#
#       01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0    155.0   92.0  ...          -0.41          -5.21             0.346
# 1    155.0   92.0  ...          -0.41          -5.21             0.346
# 2    155.0   92.0  ...            NaN            NaN               NaN
# 3    155.0   92.0  ...           0.33            NaN             0.274
# 4    155.0   92.0  ...          -0.55            NaN             0.358
# 5    155.0   92.0  ...          -4.53            NaN             0.536
# 6    155.0   92.0  ...           0.94           4.97             0.245
# 7    155.0   92.0  ...          -3.61            NaN             0.383
# 8    155.0   92.0  ...          -0.13            NaN             0.283
# 9    155.0   92.0  ...          -0.13            NaN             0.283
# 10   155.0   92.0  ...          -1.48          -4.27             0.249
# 11   155.0   92.0  ...            NaN            NaN               NaN
# 12   155.0   92.0  ...          -2.04            NaN             0.230
# 13   155.0   92.0  ...            NaN            NaN               NaN
# 14   155.0   92.0  ...           0.33            NaN             0.274
# 15   155.0   92.0  ...            NaN            NaN               NaN
# 16   155.0   92.0  ...            NaN            NaN               NaN
# 17   155.0   92.0  ...         -10.35            NaN             0.286
# 18   155.0   92.0  ...            NaN            NaN               NaN
# 19   155.0   92.0  ...            NaN            NaN               NaN
# 20   155.0   92.0  ...            NaN            NaN               NaN
# 21   155.0   92.0  ...            NaN            NaN               NaN
# 22   155.0   92.0  ...            NaN            NaN               NaN
# 23   155.0   92.0  ...          -2.47            NaN             0.349
# 24   155.0   92.0  ...          -2.47            NaN             0.349
# 25   155.0   92.0  ...            NaN            NaN               NaN
# 26   155.0   92.0  ...            NaN            NaN               NaN
# 27   155.0   92.0  ...           3.61            NaN             0.259
# 28   155.0   92.0  ...            NaN            NaN               NaN
# 29   155.0   92.0  ...          -1.69            NaN             0.365
# ..     ...    ...  ...            ...            ...               ...
# 132  155.0   92.0  ...          -0.80            NaN             0.415
# 133  155.0   92.0  ...          -2.81            NaN             0.291
# 134  155.0   92.0  ...            NaN            NaN               NaN
# 135  155.0   92.0  ...           7.12            NaN             0.259
# 136  155.0   92.0  ...           7.12            NaN             0.259
# 137  155.0   92.0  ...            NaN            NaN               NaN
# 138  155.0   92.0  ...           0.61            NaN             0.231
# 139  155.0   92.0  ...            NaN            NaN               NaN
# 140  155.0   92.0  ...           0.08         -26.29             0.285
# 141  155.0   92.0  ...           0.08         -26.29             0.285
# 142  155.0   92.0  ...          -1.83            NaN             0.321
# 143  155.0   92.0  ...          -4.12            NaN             0.364
# 144  204.0  137.0  ...          -4.12            NaN             0.364
# 145  155.0   92.0  ...            NaN            NaN               NaN
# 146  155.0   92.0  ...          -2.69           3.90             0.345
# 147  155.0   92.0  ...            NaN            NaN               NaN
# 148  155.0   92.0  ...          -2.69           3.90             0.345
# 149  155.0   92.0  ...          -4.01            NaN             0.467
# 150  155.0   92.0  ...          -4.01            NaN             0.467
# 151  155.0   92.0  ...          -4.01            NaN             0.467
# 152  155.0   92.0  ...            NaN            NaN               NaN
# 153  155.0   92.0  ...            NaN            NaN               NaN
# 154  204.0  137.0  ...            NaN            NaN               NaN
# 155  155.0   92.0  ...          -4.67            NaN             0.377
# 156  155.0   92.0  ...          -4.67            NaN             0.377
# 157   56.0   30.0  ...            NaN            NaN               NaN
# 158  204.0  137.0  ...            NaN            NaN               NaN
# 159  155.0   92.0  ...          -0.55            NaN             0.358
# 160  155.0   92.0  ...          -0.55            NaN             0.358
# 161  155.0   92.0  ...          -0.55            NaN             0.358
#
#      18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               0.608           0.461               0.509               0.752
# 1               0.608           0.461               0.509               0.752
# 2                 NaN             NaN                 NaN                 NaN
# 3               0.628           0.434               0.560               0.781
# 4               0.642           0.494               0.660               0.825
# 5               0.726           0.617               0.595               0.784
# 6               0.655           0.436               0.603               0.882
# 7               0.696           0.530               0.518               0.810
# 8               0.624           0.455               0.623               0.891
# 9               0.624           0.455               0.623               0.891
# 10              0.642           0.445               0.557               0.781
# 11                NaN             NaN                 NaN                 NaN
# 12              0.625           0.424               0.798               0.941
# 13                NaN             NaN                 NaN                 NaN
# 14              0.628           0.434               0.560               0.781
# 15                NaN             NaN                 NaN                 NaN
# 16                NaN             NaN                 NaN                 NaN
# 17              0.750           0.609               0.500               0.917
# 18                NaN             NaN                 NaN                 NaN
# 19                NaN             NaN                 NaN                 NaN
# 20                NaN             NaN                 NaN                 NaN
# 21                NaN             NaN                 NaN                 NaN
# 22                NaN             NaN                 NaN                 NaN
# 23              0.635           0.491               0.490               0.884
# 24              0.635           0.491               0.490               0.884
# 25                NaN             NaN                 NaN                 NaN
# 26                NaN             NaN                 NaN                 NaN
# 27              0.563           0.415               0.732               0.851
# 28                NaN             NaN                 NaN                 NaN
# 29              0.630           0.487               0.636               0.830
# ..                ...             ...                 ...                 ...
# 132             0.607           0.507               0.633               0.901
# 133             0.689           0.468               0.451               0.882
# 134               NaN             NaN                 NaN                 NaN
# 135             0.717           0.504               0.519               0.800
# 136             0.717           0.504               0.519               0.800
# 137               NaN             NaN                 NaN                 NaN
# 138             0.614           0.419               0.541               0.820
# 139               NaN             NaN                 NaN                 NaN
# 140             0.665           0.470               0.564               0.794
# 141             0.665           0.470               0.564               0.794
# 142             0.610           0.454               0.662               0.884
# 143             0.623           0.481               0.500               0.727
# 144             0.623           0.481               0.500               0.727
# 145               NaN             NaN                 NaN                 NaN
# 146             0.683           0.517               0.441               0.803
# 147               NaN             NaN                 NaN                 NaN
# 148             0.683           0.517               0.441               0.803
# 149             0.606           0.540               0.429               0.950
# 150             0.606           0.540               0.429               0.950
# 151             0.606           0.540               0.429               0.950
# 152               NaN             NaN                 NaN                 NaN
# 153               NaN             NaN                 NaN                 NaN
# 154               NaN             NaN                 NaN                 NaN
# 155             0.609           0.482               0.508               0.857
# 156             0.609           0.482               0.508               0.857
# 157               NaN             NaN                 NaN                 NaN
# 158               NaN             NaN                 NaN                 NaN
# 159             0.642           0.494               0.660               0.825
# 160             0.642           0.494               0.660               0.825
# 161             0.642           0.494               0.660               0.825
#
#      18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               0.650          0.440          22.3
# 1               0.650          0.440          22.3
# 2                 NaN            NaN           NaN
# 3               0.704          0.451          26.1
# 4               0.762          0.479          23.2
# 5               0.689          0.425          25.8
# 6               0.798          0.465          23.8
# 7               0.698          0.469          23.4
# 8               0.808          0.504          21.3
# 9               0.808          0.504          21.3
# 10              0.718          0.499          27.1
# 11                NaN            NaN           NaN
# 12              0.901          0.491          25.6
# 13                NaN            NaN           NaN
# 14              0.704          0.451          26.1
# 15                NaN            NaN           NaN
# 16                NaN            NaN           NaN
# 17              0.857          0.696          17.9
# 18                NaN            NaN           NaN
# 19                NaN            NaN           NaN
# 20                NaN            NaN           NaN
# 21                NaN            NaN           NaN
# 22                NaN            NaN           NaN
# 23              0.743          0.495          27.4
# 24              0.743          0.495          27.4
# 25                NaN            NaN           NaN
# 26                NaN            NaN           NaN
# 27              0.815          0.515          23.8
# 28                NaN            NaN           NaN
# 29              0.752          0.461          23.8
# ..                ...            ...           ...
# 132             0.787          0.480          24.3
# 133             0.733          0.446          23.1
# 134               NaN            NaN           NaN
# 135             0.733          0.534          23.3
# 136             0.733          0.534          23.3
# 137               NaN            NaN           NaN
# 138             0.741          0.490          24.1
# 139               NaN            NaN           NaN
# 140             0.722          0.485          24.0
# 141             0.722          0.485          24.0
# 142             0.799          0.458          25.7
# 143             0.633          0.450          23.2
# 144             0.633          0.450          23.2
# 145               NaN            NaN           NaN
# 146             0.684          0.507          25.2
# 147               NaN            NaN           NaN
# 148             0.684          0.507          25.2
# 149             0.735          0.524          21.7
# 150             0.735          0.524          21.7
# 151             0.735          0.524          21.7
# 152               NaN            NaN           NaN
# 153               NaN            NaN           NaN
# 154               NaN            NaN           NaN
# 155             0.708          0.453          22.3
# 156             0.708          0.453          22.3
# 157               NaN            NaN           NaN
# 158               NaN            NaN           NaN
# 159             0.762          0.479          23.2
# 160             0.762          0.479          23.2
# 161             0.762          0.479          23.2
#
# [162 rows x 5184 columns]

# %%
def create_trining_df(year = (dt.datetime.today().year-1), team = "HOU" ):
                       
    
    players_df = get_players_per_game(year, team)
    #print(players_df.tail(10))    
    stats_players_start_lineup = get_stats_startingplayer_by_game(players_df, team, year)
    
    return pd.concat([players_df.iloc[:,[0,1,2,3,4,5]],stats_players_start_lineup], axis=1, join='inner')
       
    
    
    
    #dates_played = get_dates_played(last_season_games_played, year)

# %%
stats_players_start_lineup = create_trining_df()
stats_players_start_lineup
# Out:
# enemy Centeno not in batting list
# enemy Tocci not in batting list
# enemy Rasmus not in batting list
# enemy Beckham not in batting list
# enemy Rasmus not in batting list
# enemy Beckham not in batting list
# enemy Beckham not in batting list
# enemy Valencia not in batting list
# enemy Hosmer not in batting list
# enemy Galvis not in batting list
# enemy Galvis not in batting list
# enemy Hosmer not in batting list
# enemy Ellis not in batting list
# enemy Hosmer not in batting list
# enemy Headley not in batting list
# enemy Galvis not in batting list
# enemy Morrison not in batting list
# enemy Morrison not in batting list
# enemy LaMarre not in batting list
# enemy Morrison not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Guzman not in batting list
# enemy Centeno not in batting list
# enemy Kiner not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Tocci not in batting list
# enemy Freitas not in batting list
# enemy Suzuki not in batting list
# enemy Freitas not in batting list
# enemy Freitas not in batting list
# enemy Moncada not in batting list
# enemy Garcia not in batting list
# enemy Abreu not in batting list
# enemy Delmonico not in batting list
# enemy Castillo not in batting list
# enemy Sanchez not in batting list
# enemy Anderson not in batting list
# enemy Narvaez not in batting list
# enemy Engel not in batting list
# enemy Anderson not in batting list
# enemy Garcia not in batting list
# enemy Abreu not in batting list
# enemy Castillo not in batting list
# enemy Davidson not in batting list
# enemy Moncada not in batting list
# enemy Thompson not in batting list
# enemy Sanchez not in batting list
# enemy Engel not in batting list
# enemy Moncada not in batting list
# enemy Garcia not in batting list
# enemy Abreu not in batting list
# enemy Delmonico not in batting list
# enemy Castillo not in batting list
# enemy Davidson not in batting list
# enemy Sanchez not in batting list
# enemy Anderson not in batting list
# enemy Garcia not in batting list
# enemy Kinsler not in batting list
# enemy Upton not in batting list
# enemy Cozart not in batting list
# enemy Kinsler not in batting list
# enemy Upton not in batting list
# enemy Cozart not in batting list
# enemy Kinsler not in batting list
# enemy Upton not in batting list
# enemy Cozart not in batting list
# enemy Rivera not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Piscotty not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Stanton not in batting list
# enemy Walker not in batting list
# enemy Torres not in batting list
# enemy Stanton not in batting list
# enemy Torres not in batting list
# enemy Stanton not in batting list
# enemy Torres not in batting list
# enemy Stanton not in batting list
# enemy Walker not in batting list
# enemy Torres not in batting list
# Cole not in batting list
# enemy Dyson not in batting list
# enemy Avila not in batting list
# enemy Medlen not in batting list
# enemy Souza not in batting list
# Verlander not in batting list
# enemy Souza not in batting list
# enemy Avila not in batting list
# enemy Koch not in batting list
# enemy Lucroy not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Piscotty not in batting list
# enemy Guzman not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Cozart not in batting list
# enemy Upton not in batting list
# enemy Kinsler not in batting list
# enemy Ohtani not in batting list
# enemy Upton not in batting list
# enemy Kinsler not in batting list
# enemy Rivera not in batting list
# enemy Ohtani not in batting list
# enemy Upton not in batting list
# enemy Cozart not in batting list
# enemy Kinsler not in batting list
# enemy Alonso not in batting list
# enemy Davis not in batting list
# enemy Davis not in batting list
# enemy Alonso not in batting list
# enemy Cabrera not in batting list
# enemy McCutchen not in batting list
# enemy Longoria not in batting list
# enemy Sandoval not in batting list
# enemy Jackson not in batting list
# enemy McCutchen not in batting list
# enemy Longoria not in batting list
# enemy Sandoval not in batting list
# enemy Alonso not in batting list
# enemy Cabrera not in batting list
# enemy Cabrera not in batting list
# enemy Davis not in batting list
# enemy Alonso not in batting list
# enemy Cabrera not in batting list
# enemy Alonso not in batting list
# enemy Cabrera not in batting list
# enemy Torres not in batting list
# enemy Walker not in batting list
# enemy Stanton not in batting list
# enemy Torres not in batting list
# enemy Stanton not in batting list
# enemy Torres not in batting list
# Federowicz not in batting list
# enemy Martinez not in batting list
# enemy Martinez not in batting list
# enemy Nunez not in batting list
# enemy Martinez not in batting list
# enemy Nunez not in batting list
# enemy Martinez not in batting list
# enemy Nunez not in batting list
# enemy Healy not in batting list
# Federowicz not in batting list
# enemy Healy not in batting list
# enemy Span not in batting list
# enemy Kiner not in batting list
# enemy Guzman not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Guzman not in batting list
# enemy Fowler not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Fowler not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Fowler not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Dozier not in batting list
# enemy Almonte not in batting list
# enemy Dozier not in batting list
# enemy Almonte not in batting list
# enemy Goins not in batting list
# enemy Dozier not in batting list
# enemy Goins not in batting list
# enemy Almonte not in batting list
# enemy Duffy not in batting list
# enemy Bauers not in batting list
# enemy Cron not in batting list
# enemy Wendle not in batting list
# enemy Adames not in batting list
# enemy Gomez not in batting list
# enemy Field not in batting list
# enemy Duffy not in batting list
# enemy Bauers not in batting list
# enemy Wendle not in batting list
# enemy Cron not in batting list
# enemy Gomez not in batting list
# enemy Hechavarria not in batting list
# enemy Hechavarria not in batting list
# enemy Bauers not in batting list
# enemy Wendle not in batting list
# enemy Adames not in batting list
# enemy Gomez not in batting list
# enemy Field not in batting list
# enemy Herrera not in batting list
# enemy Dozier not in batting list
# enemy Herrera not in batting list
# enemy Duda not in batting list
# enemy Dozier not in batting list
# enemy Goins not in batting list
# enemy Herrera not in batting list
# enemy Duda not in batting list
# enemy Dozier not in batting list
# enemy Almonte not in batting list
# enemy Granderson not in batting list
# enemy Hernandez not in batting list
# enemy Solarte not in batting list
# enemy Grichuk not in batting list
# enemy Diaz not in batting list
# enemy Granderson not in batting list
# enemy Hernandez not in batting list
# enemy Solarte not in batting list
# enemy Grichuk not in batting list
# enemy Diaz not in batting list
# enemy Grichuk not in batting list
# enemy Hernandez not in batting list
# enemy Solarte not in batting list
# enemy Diaz not in batting list
# enemy Duffy not in batting list
# enemy Bauers not in batting list
# enemy Wendle not in batting list
# enemy Cron not in batting list
# enemy Gomez not in batting list
# enemy Adames not in batting list
# enemy Duffy not in batting list
# enemy Bauers not in batting list
# enemy Wendle not in batting list
# enemy Hechavarria not in batting list
# enemy Adames not in batting list
# enemy Duffy not in batting list
# enemy Bauers not in batting list
# enemy Wendle not in batting list
# enemy Cron not in batting list
# enemy Gomez not in batting list
# enemy Hechavarria not in batting list
# enemy Wendle not in batting list
# enemy Duffy not in batting list
# enemy Bauers not in batting list
# enemy Gomez not in batting list
# enemy Adames not in batting list
# enemy Field not in batting list
# enemy Guzman not in batting list
# Federowicz not in batting list
# enemy Guzman not in batting list
# enemy Moncada not in batting list
# enemy Sanchez not in batting list
# enemy Abreu not in batting list
# enemy Garcia not in batting list
# enemy Palka not in batting list
# enemy Davidson not in batting list
# enemy Narvaez not in batting list
# enemy Garcia not in batting list
# enemy Anderson not in batting list
# Federowicz not in batting list
# enemy Moncada not in batting list
# enemy Sanchez not in batting list
# enemy Abreu not in batting list
# enemy Garcia not in batting list
# enemy Palka not in batting list
# enemy Davidson not in batting list
# enemy Smith not in batting list
# enemy Garcia not in batting list
# enemy Engel not in batting list
# Tucker not in batting list
# enemy Moncada not in batting list
# enemy Sanchez not in batting list
# enemy Abreu not in batting list
# enemy Garcia not in batting list
# enemy Palka not in batting list
# enemy Davidson not in batting list
# enemy Narvaez not in batting list
# enemy Anderson not in batting list
# enemy Engel not in batting list
# Tucker not in batting list
# enemy Anderson not in batting list
# enemy Garcia not in batting list
# enemy Abreu not in batting list
# enemy Davidson not in batting list
# enemy Smith not in batting list
# enemy Garcia not in batting list
# enemy Moncada not in batting list
# enemy Sanchez not in batting list
# enemy Engel not in batting list
# Tucker not in batting list
# Federowicz not in batting list
# enemy Fowler not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# Tucker not in batting list
# enemy Fowler not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# Tucker not in batting list
# Federowicz not in batting list
# enemy Fowler not in batting list
# enemy Piscotty not in batting list
# enemy Martini not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# Tucker not in batting list
# enemy Goodrum not in batting list
# enemy Rodriguez not in batting list
# enemy Candelario not in batting list
# Tucker not in batting list
# Federowicz not in batting list
# enemy Goodrum not in batting list
# enemy Candelario not in batting list
# enemy Reyes not in batting list
# enemy Goodrum not in batting list
# enemy Rodriguez not in batting list
# enemy Candelario not in batting list
# enemy Reyes not in batting list
# Tucker not in batting list
# enemy Fletcher not in batting list
# enemy Upton not in batting list
# enemy Ohtani not in batting list
# enemy Kinsler not in batting list
# enemy Blash not in batting list
# Tucker not in batting list
# enemy Upton not in batting list
# enemy Ohtani not in batting list
# enemy Kinsler not in batting list
# enemy Fletcher not in batting list
# Federowicz not in batting list
# enemy Upton not in batting list
# enemy Ohtani not in batting list
# enemy Kinsler not in batting list
# enemy Briceno not in batting list
# enemy Fletcher not in batting list
# Cole not in batting list
# enemy Hampson not in batting list
# enemy Iannetta not in batting list
# Tucker not in batting list
# enemy Hampson not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Tocci not in batting list
# Tucker not in batting list
# enemy Guzman not in batting list
# enemy Kiner not in batting list
# enemy Tocci not in batting list
# Maldonado not in batting list
# enemy Kiner not in batting list
# enemy Guzman not in batting list
# enemy Span not in batting list
# enemy Healy not in batting list
# enemy Romine not in batting list
# Maldonado not in batting list
# enemy Span not in batting list
# enemy Herrmann not in batting list
# enemy Healy not in batting list
# enemy Romine not in batting list
# enemy Maybin not in batting list
# enemy Romine not in batting list
# enemy Vincej not in batting list
# Maldonado not in batting list
# Verlander not in batting list
# enemy Machado not in batting list
# enemy Kemp not in batting list
# enemy Muncy not in batting list
# Maldonado not in batting list
# enemy Machado not in batting list
# enemy Kemp not in batting list
# enemy Dozier not in batting list
# Cole not in batting list
# enemy Machado not in batting list
# enemy Dozier not in batting list
# enemy Muncy not in batting list
# enemy Buehler not in batting list
# Maldonado not in batting list
# enemy McCutchen not in batting list
# enemy Longoria not in batting list
# enemy Duggar not in batting list
# enemy Rodriguez not in batting list
# enemy McCutchen not in batting list
# enemy Longoria not in batting list
# enemy d'Arnaud not in batting list
# enemy Duggar not in batting list
# Maldonado not in batting list
# enemy Span not in batting list
# enemy Healy not in batting list
# enemy Maybin not in batting list
# Maldonado not in batting list
# enemy Span not in batting list
# enemy Healy not in batting list
# enemy Maybin not in batting list
# enemy Span not in batting list
# enemy Herrmann not in batting list
# enemy Healy not in batting list
# Tucker not in batting list
# Maldonado not in batting list
# enemy Maybin not in batting list
# enemy Healy not in batting list
# enemy Romine not in batting list
# Tucker not in batting list
# Maldonado not in batting list
# enemy Dahl not in batting list
# enemy Iannetta not in batting list
# Maldonado not in batting list
# enemy Martini not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Piscotty not in batting list
# enemy Laureano not in batting list
# Maldonado not in batting list
# enemy Martini not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# Maldonado not in batting list
# enemy Span not in batting list
# enemy Span not in batting list
# enemy Healy not in batting list
# enemy Herrmann not in batting list
# Maldonado not in batting list
# enemy Span not in batting list
# enemy Healy not in batting list
# Maldonado not in batting list
# enemy Fletcher not in batting list
# enemy Rivera not in batting list
# enemy Ward not in batting list
# Maldonado not in batting list
# enemy Fletcher not in batting list
# enemy Ohtani not in batting list
# enemy Arcia not in batting list
# enemy Ward not in batting list
# enemy Fletcher not in batting list
# enemy Rivera not in batting list
# enemy Ward not in batting list
# Maldonado not in batting list
# enemy Martini not in batting list
# enemy Piscotty not in batting list
# enemy Lucroy not in batting list
# enemy Laureano not in batting list
# Maldonado not in batting list
# enemy Martini not in batting list
# enemy Piscotty not in batting list
# enemy Laureano not in batting list
# enemy Lucroy not in batting list
# enemy Piscotty not in batting list
# enemy Laureano not in batting list
# Maldonado not in batting list
# enemy Fletcher not in batting list
# enemy Upton not in batting list
# enemy Ohtani not in batting list
# enemy Arcia not in batting list
# enemy Ward not in batting list
# Maldonado not in batting list
# enemy Fletcher not in batting list
# enemy Upton not in batting list
# enemy Ohtani not in batting list
# enemy Ward not in batting list
# enemy Briceno not in batting list
# enemy Fletcher not in batting list
# enemy Upton not in batting list
# enemy Fernandez not in batting list
# enemy Ward not in batting list
# enemy Arcia not in batting list
# Maldonado not in batting list
# enemy Fletcher not in batting list
# enemy Fernandez not in batting list
# enemy Ward not in batting list
# enemy Arcia not in batting list
# enemy Forsythe not in batting list
# enemy Cave not in batting list
# enemy Austin not in batting list
# enemy Field not in batting list
# Maldonado not in batting list
# enemy Forsythe not in batting list
# enemy Cave not in batting list
# enemy Forsythe not in batting list
# enemy Austin not in batting list
# enemy Astudillo not in batting list
# enemy Field not in batting list
# Maldonado not in batting list
# enemy Martinez not in batting list
# enemy Kinsler not in batting list
# enemy Nunez not in batting list
# Maldonado not in batting list
# enemy Martinez not in batting list
# enemy Kinsler not in batting list
# enemy Martinez not in batting list
# enemy Pearce not in batting list
# enemy Kinsler not in batting list
# enemy Phillips not in batting list
# enemy Nunez not in batting list
# Maldonado not in batting list
# enemy Candelario not in batting list
# enemy Stewart not in batting list
# enemy Goodrum not in batting list
# enemy Rodriguez not in batting list
# enemy Lugo not in batting list
# enemy Candelario not in batting list
# enemy Stewart not in batting list
# enemy Goodrum not in batting list
# enemy Greiner not in batting list
# enemy Rodriguez not in batting list
# enemy Lugo not in batting list
# Maldonado not in batting list
# enemy Candelario not in batting list
# enemy Stewart not in batting list
# enemy Goodrum not in batting list
# enemy Lugo not in batting list
# enemy Reyes not in batting list
# Maldonado not in batting list
# enemy Escobar not in batting list
# enemy Souza not in batting list
# enemy Escobar not in batting list
# enemy Souza not in batting list
# enemy Avila not in batting list
# Maldonado not in batting list
# enemy Jay not in batting list
# enemy Escobar not in batting list
# Maldonado not in batting list
# enemy Healy not in batting list
# enemy Maybin not in batting list
# enemy Span not in batting list
# enemy Herrmann not in batting list
# Maldonado not in batting list
# enemy Healy not in batting list
# Maldonado not in batting list
# enemy Fernandez not in batting list
# enemy Ohtani not in batting list
# enemy Upton not in batting list
# enemy Arcia not in batting list
# enemy Ward not in batting list
# enemy Fernandez not in batting list
# enemy Ohtani not in batting list
# enemy Upton not in batting list
# enemy Ward not in batting list
# enemy Briceno not in batting list
# Maldonado not in batting list
# enemy Upton not in batting list
# enemy Ohtani not in batting list
# enemy Arcia not in batting list
# enemy Hermosillo not in batting list
# enemy Johnson not in batting list
# enemy Davis not in batting list
# enemy Gurriel not in batting list
# enemy Grichuk not in batting list
# enemy Diaz not in batting list
# enemy Hernandez not in batting list
# Maldonado not in batting list
# enemy Davis not in batting list
# enemy McKinney not in batting list
# enemy Tellez not in batting list
# enemy Solarte not in batting list
# enemy Diaz not in batting list
# enemy Jansen not in batting list
# Tucker not in batting list
# Straw not in batting list
# enemy McKinney not in batting list
# enemy Grichuk not in batting list
# enemy Tellez not in batting list
# enemy Diaz not in batting list
# enemy McGuire not in batting list
# enemy Berti not in batting list
# Maldonado not in batting list
# enemy Mullins not in batting list
# enemy Villar not in batting list
# enemy Stewart not in batting list
# enemy Wilkerson not in batting list
# enemy Peterson not in batting list
# enemy Wynns not in batting list
# Maldonado not in batting list
# enemy Mullins not in batting list
# enemy Villar not in batting list
# enemy Beckham not in batting list
# enemy Nunez not in batting list
# enemy Stewart not in batting list
# Maldonado not in batting list
# enemy Mullins not in batting list
# enemy Villar not in batting list
# enemy Beckham not in batting list
# enemy Nunez not in batting list
# enemy Stewart not in batting list
# enemy Mullins not in batting list
# enemy Villar not in batting list
# enemy Beckham not in batting list
# enemy Nunez not in batting list
# enemy Stewart not in batting list
# enemy Wilkerson not in batting list
#           Date   Tm  Home_Away  Opp      GB  Streak  index  01_Season  \
# 0   2018-03-29  HOU          1  TEX    Tied       1     79     2017.0
# 1   2018-03-30  HOU          1  TEX     0.5      -1     79     2017.0
# 2   2018-03-31  HOU          1  TEX    Tied       1     79     2017.0
# 3   2018-04-01  HOU          1  TEX    Tied       2     79     2017.0
# 4   2018-04-02  HOU          0  BAL  up 1.0       3     79     2017.0
# 5   2018-04-03  HOU          0  BAL  up 1.0       4     79     2017.0
# 6   2018-04-04  HOU          0  BAL  up 1.0       5     79     2017.0
# 7   2018-04-06  HOU          0  SDP    Tied      -1     79     2017.0
# 8   2018-04-07  HOU          0  SDP  up 1.0       1     79     2017.0
# 9   2018-04-08  HOU          0  SDP  up 1.0       2     79     2017.0
# 10  2018-04-09  HOU          1  MIN  up 1.0       3     79     2017.0
# 11  2018-04-10  HOU          1  MIN    Tied      -1     79     2017.0
# 12  2018-04-11  HOU          1  MIN     1.0      -2     79     2017.0
# 13  2018-04-13  HOU          0  TEX     1.5       1     79     2017.0
# 14  2018-04-14  HOU          0  TEX     2.5      -1     79     2017.0
# 15  2018-04-15  HOU          0  TEX     3.0      -2     79     2017.0
# 16  2018-04-16  HOU          1  SEA     3.5      -3     79     2017.0
# 17  2018-04-17  HOU          1  SEA     2.5       1     79     2017.0
# 18  2018-04-18  HOU          1  SEA     1.5       2     79     2017.0
# 19  2018-04-19  HOU          1  SEA     0.5       3     79     2017.0
# 20  2018-04-20  HOU          1  CHW  up 0.5       4     79     2017.0
# 21  2018-04-21  HOU          1  CHW  up 0.5       5     79     2017.0
# 22  2018-04-22  HOU          1  CHW  up 1.5       6     79     2017.0
# 23  2018-04-23  HOU          0  LAA  up 0.5      -1     79     2017.0
# 24  2018-04-24  HOU          0  LAA     0.5      -2     79     2017.0
# 25  2018-04-25  HOU          0  LAA  up 0.5       1     79     2017.0
# 26  2018-04-27  HOU          0  OAK  up 0.5      -1     79     2017.0
# 27  2018-04-28  HOU          0  OAK  up 1.5       1     79     2017.0
# 28  2018-04-29  HOU          0  OAK  up 2.0       2     79     2017.0
# 29  2018-04-30  HOU          0  NYY  up 2.5       3     79     2017.0
# ..         ...  ...        ...  ...     ...     ...    ...        ...
# 132 2018-08-29  HOU          0  OAK  up 2.5       1     79     2017.0
# 133 2018-08-30  HOU          0  LAA  up 2.5      -1     79     2017.0
# 134 2018-08-31  HOU          0  LAA  up 1.5      -2     79     2017.0
# 135 2018-09-01  HOU          0  LAA  up 2.5       1     79     2017.0
# 136 2018-09-02  HOU          0  LAA  up 2.5       2     79     2017.0
# 137 2018-09-03  HOU          0  MIN  up 2.5       3     79     2017.0
# 138 2018-09-04  HOU          0  MIN  up 3.5       4     79     2017.0
# 139 2018-09-05  HOU          0  MIN  up 3.5       5     79     2017.0
# 140 2018-09-07  HOU          1  BOS  up 3.5       6     79     2017.0
# 141 2018-09-08  HOU          1  BOS  up 3.5       7     79     2017.0
# 142 2018-09-09  HOU          1  BOS  up 2.5      -1     79     2017.0
# 143 2018-09-10  HOU          1  DET  up 3.0       1     79     2017.0
# 144 2018-09-11  HOU          1  DET  up 3.0       2     48     2017.0
# 145 2018-09-12  HOU          1  DET  up 3.0       3     79     2017.0
# 146 2018-09-14  HOU          0  ARI  up 2.5      -1     79     2017.0
# 147 2018-09-15  HOU          0  ARI  up 3.5       1     79     2017.0
# 148 2018-09-16  HOU          0  ARI  up 4.5       2     79     2017.0
# 149 2018-09-17  HOU          0  SEA  up 4.0      -1     79     2017.0
# 150 2018-09-18  HOU          0  SEA  up 5.0       1     79     2017.0
# 151 2018-09-19  HOU          0  SEA  up 4.0      -1     79     2017.0
# 152 2018-09-21  HOU          0  LAA  up 3.5       1     79     2017.0
# 153 2018-09-22  HOU          0  LAA  up 3.5       2     79     2017.0
# 154 2018-09-23  HOU          0  LAA  up 4.5       3     48     2017.0
# 155 2018-09-24  HOU          1  TOR  up 4.5       4     79     2017.0
# 156 2018-09-25  HOU          1  TOR  up 5.5       5     79     2017.0
# 157 2018-09-26  HOU          1  TOR  up 4.5      -1    172     2017.0
# 158 2018-09-28  HOU          1  BAL  up 5.5       1     48     2017.0
# 159 2018-09-29  HOU          1  BAL  up 6.0       2     79     2017.0
# 160 2018-09-29  HOU          1  BAL  up 6.0       3     79     2017.0
# 161 2018-09-30  HOU          1  BAL  up 6.0      -1     79     2017.0
#
#              01_Name 01_Team  ...  18_wSL/C (pi)  18_wXX/C (pi)  \
# 0    George Springer  Astros  ...          -0.41          -5.21
# 1    George Springer  Astros  ...          -0.41          -5.21
# 2    George Springer  Astros  ...            NaN            NaN
# 3    George Springer  Astros  ...           0.33            NaN
# 4    George Springer  Astros  ...          -0.55            NaN
# 5    George Springer  Astros  ...          -4.53            NaN
# 6    George Springer  Astros  ...           0.94           4.97
# 7    George Springer  Astros  ...          -3.61            NaN
# 8    George Springer  Astros  ...          -0.13            NaN
# 9    George Springer  Astros  ...          -0.13            NaN
# 10   George Springer  Astros  ...          -1.48          -4.27
# 11   George Springer  Astros  ...            NaN            NaN
# 12   George Springer  Astros  ...          -2.04            NaN
# 13   George Springer  Astros  ...            NaN            NaN
# 14   George Springer  Astros  ...           0.33            NaN
# 15   George Springer  Astros  ...            NaN            NaN
# 16   George Springer  Astros  ...            NaN            NaN
# 17   George Springer  Astros  ...         -10.35            NaN
# 18   George Springer  Astros  ...            NaN            NaN
# 19   George Springer  Astros  ...            NaN            NaN
# 20   George Springer  Astros  ...            NaN            NaN
# 21   George Springer  Astros  ...            NaN            NaN
# 22   George Springer  Astros  ...            NaN            NaN
# 23   George Springer  Astros  ...          -2.47            NaN
# 24   George Springer  Astros  ...          -2.47            NaN
# 25   George Springer  Astros  ...            NaN            NaN
# 26   George Springer  Astros  ...            NaN            NaN
# 27   George Springer  Astros  ...           3.61            NaN
# 28   George Springer  Astros  ...            NaN            NaN
# 29   George Springer  Astros  ...          -1.69            NaN
# ..               ...     ...  ...            ...            ...
# 132  George Springer  Astros  ...          -0.80            NaN
# 133  George Springer  Astros  ...          -2.81            NaN
# 134  George Springer  Astros  ...            NaN            NaN
# 135  George Springer  Astros  ...           7.12            NaN
# 136  George Springer  Astros  ...           7.12            NaN
# 137  George Springer  Astros  ...            NaN            NaN
# 138  George Springer  Astros  ...           0.61            NaN
# 139  George Springer  Astros  ...            NaN            NaN
# 140  George Springer  Astros  ...           0.08         -26.29
# 141  George Springer  Astros  ...           0.08         -26.29
# 142  George Springer  Astros  ...          -1.83            NaN
# 143  George Springer  Astros  ...          -4.12            NaN
# 144      Jose Altuve  Astros  ...          -4.12            NaN
# 145  George Springer  Astros  ...            NaN            NaN
# 146  George Springer  Astros  ...          -2.69           3.90
# 147  George Springer  Astros  ...            NaN            NaN
# 148  George Springer  Astros  ...          -2.69           3.90
# 149  George Springer  Astros  ...          -4.01            NaN
# 150  George Springer  Astros  ...          -4.01            NaN
# 151  George Springer  Astros  ...          -4.01            NaN
# 152  George Springer  Astros  ...            NaN            NaN
# 153  George Springer  Astros  ...            NaN            NaN
# 154      Jose Altuve  Astros  ...            NaN            NaN
# 155  George Springer  Astros  ...          -4.67            NaN
# 156  George Springer  Astros  ...          -4.67            NaN
# 157   Jake Marisnick  Astros  ...            NaN            NaN
# 158      Jose Altuve  Astros  ...            NaN            NaN
# 159  George Springer  Astros  ...          -0.55            NaN
# 160  George Springer  Astros  ...          -0.55            NaN
# 161  George Springer  Astros  ...          -0.55            NaN
#
#      18_O-Swing% (pi)  18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  \
# 0               0.346             0.608           0.461               0.509
# 1               0.346             0.608           0.461               0.509
# 2                 NaN               NaN             NaN                 NaN
# 3               0.274             0.628           0.434               0.560
# 4               0.358             0.642           0.494               0.660
# 5               0.536             0.726           0.617               0.595
# 6               0.245             0.655           0.436               0.603
# 7               0.383             0.696           0.530               0.518
# 8               0.283             0.624           0.455               0.623
# 9               0.283             0.624           0.455               0.623
# 10              0.249             0.642           0.445               0.557
# 11                NaN               NaN             NaN                 NaN
# 12              0.230             0.625           0.424               0.798
# 13                NaN               NaN             NaN                 NaN
# 14              0.274             0.628           0.434               0.560
# 15                NaN               NaN             NaN                 NaN
# 16                NaN               NaN             NaN                 NaN
# 17              0.286             0.750           0.609               0.500
# 18                NaN               NaN             NaN                 NaN
# 19                NaN               NaN             NaN                 NaN
# 20                NaN               NaN             NaN                 NaN
# 21                NaN               NaN             NaN                 NaN
# 22                NaN               NaN             NaN                 NaN
# 23              0.349             0.635           0.491               0.490
# 24              0.349             0.635           0.491               0.490
# 25                NaN               NaN             NaN                 NaN
# 26                NaN               NaN             NaN                 NaN
# 27              0.259             0.563           0.415               0.732
# 28                NaN               NaN             NaN                 NaN
# 29              0.365             0.630           0.487               0.636
# ..                ...               ...             ...                 ...
# 132             0.415             0.607           0.507               0.633
# 133             0.291             0.689           0.468               0.451
# 134               NaN               NaN             NaN                 NaN
# 135             0.259             0.717           0.504               0.519
# 136             0.259             0.717           0.504               0.519
# 137               NaN               NaN             NaN                 NaN
# 138             0.231             0.614           0.419               0.541
# 139               NaN               NaN             NaN                 NaN
# 140             0.285             0.665           0.470               0.564
# 141             0.285             0.665           0.470               0.564
# 142             0.321             0.610           0.454               0.662
# 143             0.364             0.623           0.481               0.500
# 144             0.364             0.623           0.481               0.500
# 145               NaN               NaN             NaN                 NaN
# 146             0.345             0.683           0.517               0.441
# 147               NaN               NaN             NaN                 NaN
# 148             0.345             0.683           0.517               0.441
# 149             0.467             0.606           0.540               0.429
# 150             0.467             0.606           0.540               0.429
# 151             0.467             0.606           0.540               0.429
# 152               NaN               NaN             NaN                 NaN
# 153               NaN               NaN             NaN                 NaN
# 154               NaN               NaN             NaN                 NaN
# 155             0.377             0.609           0.482               0.508
# 156             0.377             0.609           0.482               0.508
# 157               NaN               NaN             NaN                 NaN
# 158               NaN               NaN             NaN                 NaN
# 159             0.358             0.642           0.494               0.660
# 160             0.358             0.642           0.494               0.660
# 161             0.358             0.642           0.494               0.660
#
#      18_Z-Contact% (pi)  18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0                 0.752             0.650          0.440          22.3
# 1                 0.752             0.650          0.440          22.3
# 2                   NaN               NaN            NaN           NaN
# 3                 0.781             0.704          0.451          26.1
# 4                 0.825             0.762          0.479          23.2
# 5                 0.784             0.689          0.425          25.8
# 6                 0.882             0.798          0.465          23.8
# 7                 0.810             0.698          0.469          23.4
# 8                 0.891             0.808          0.504          21.3
# 9                 0.891             0.808          0.504          21.3
# 10                0.781             0.718          0.499          27.1
# 11                  NaN               NaN            NaN           NaN
# 12                0.941             0.901          0.491          25.6
# 13                  NaN               NaN            NaN           NaN
# 14                0.781             0.704          0.451          26.1
# 15                  NaN               NaN            NaN           NaN
# 16                  NaN               NaN            NaN           NaN
# 17                0.917             0.857          0.696          17.9
# 18                  NaN               NaN            NaN           NaN
# 19                  NaN               NaN            NaN           NaN
# 20                  NaN               NaN            NaN           NaN
# 21                  NaN               NaN            NaN           NaN
# 22                  NaN               NaN            NaN           NaN
# 23                0.884             0.743          0.495          27.4
# 24                0.884             0.743          0.495          27.4
# 25                  NaN               NaN            NaN           NaN
# 26                  NaN               NaN            NaN           NaN
# 27                0.851             0.815          0.515          23.8
# 28                  NaN               NaN            NaN           NaN
# 29                0.830             0.752          0.461          23.8
# ..                  ...               ...            ...           ...
# 132               0.901             0.787          0.480          24.3
# 133               0.882             0.733          0.446          23.1
# 134                 NaN               NaN            NaN           NaN
# 135               0.800             0.733          0.534          23.3
# 136               0.800             0.733          0.534          23.3
# 137                 NaN               NaN            NaN           NaN
# 138               0.820             0.741          0.490          24.1
# 139                 NaN               NaN            NaN           NaN
# 140               0.794             0.722          0.485          24.0
# 141               0.794             0.722          0.485          24.0
# 142               0.884             0.799          0.458          25.7
# 143               0.727             0.633          0.450          23.2
# 144               0.727             0.633          0.450          23.2
# 145                 NaN               NaN            NaN           NaN
# 146               0.803             0.684          0.507          25.2
# 147                 NaN               NaN            NaN           NaN
# 148               0.803             0.684          0.507          25.2
# 149               0.950             0.735          0.524          21.7
# 150               0.950             0.735          0.524          21.7
# 151               0.950             0.735          0.524          21.7
# 152                 NaN               NaN            NaN           NaN
# 153                 NaN               NaN            NaN           NaN
# 154                 NaN               NaN            NaN           NaN
# 155               0.857             0.708          0.453          22.3
# 156               0.857             0.708          0.453          22.3
# 157                 NaN               NaN            NaN           NaN
# 158                 NaN               NaN            NaN           NaN
# 159               0.825             0.762          0.479          23.2
# 160               0.825             0.762          0.479          23.2
# 161               0.825             0.762          0.479          23.2
#
# [162 rows x 5190 columns]

# %%
stats_players_start_lineup.head()

# %%
names = stats_players_start_lineup.loc[:]["Name"].isna()

# %%
names.isnull().values.any()
