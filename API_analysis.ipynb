# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# ### Analysing *batting_stats()* with different paramters

# %%
all_data_2019 = batting_stats(2019)

# %%
all_data_2019 = batting_stats(2019)
players_with_more_than_50 = batting_stats(2019, qual=50)
all_data_since_2015 = batting_stats(2015, 2019)
aggregated_data = batting_stats(2010, 2016, ind=0)

print(all_data_2019.head())
print(players_with_more_than_50.head())
print(all_data_since_2015.head())
print(aggregated_data.head())

# %% [markdown]
# # Conclusion for batting_stats()
# Very versitile function that can take one or two years as parameters (single season or multiple seasons). It would return a dataframe with 287 columns with all the batting statistics for every single player for the whole season/seasons. A lot of statistics!
#
# ### Analysing *schedule_and_record()*

# %%
from pybaseball import schedule_and_record

Astros_record = schedule_and_record(2019, "HOU")
Astros_record.head(20)

# %%
Astros_record.columns

# %% [markdown]
# ### Conclusion for schedule_and_record()
# Very useful function that can get the players who played in each game, and also all the dates in which each a team played in a season, among others. It only has 19 columns, but this will be used as a *link* table between the others.
#
# ## Analysing *batting_stats_range()*

# %%
data_range = batting_stats_range("2019-09-01","2019-09-30")
data_range

# %%
print(data_range.columns)
print(all_data_2019.columns)

# %% [markdown]
# ### Conclusion for *batting_stats_range()*
#
# this functions returns a much smaller dataframe with only 27 columns. This will be useful to get the most recent information for each player right before each game.
#
# # Let's look at all the columns for batting_stats() and batting_stats_range()

# %%
print(all_data_2019.columns[:95])

# %%
print(all_data_2019.columns[95:190])

# %%
print(all_data_2019.columns[190:])

# %%
len(all_data_2019.columns)

# %%
len(data_range.columns)

# %% [markdown]
# ### Let's see what columns in the smaller dataframe are also in the larger df

# %%
shared_columns = list(data_range.columns & all_data_2019.columns)

# %%
shared_columns

# %%
len(shared_columns)

# %% [markdown]
# ### basically all of them. Only 4 are not included. Let's see which one are not in the larger df.

# %%
range_columns_not_in_all_data = list(data_range.columns.difference(all_data_2019.columns))
range_columns_not_in_all_data

# %% [markdown]
# # So #days is a useless column, BA is the same as AVG, Lev is useless too, and Tm is the same as Team. As a conclusion, all the columns are included.

# %%
Astros_2019stats  =  all_data_2019[all_data_2019["Team"]=="Astros"]

# %%
Astros_2019stats.count()

# %%
#Thursday, Mar 28
#"2019-03-28"
game_march_28_2019 = batting_stats_range("2019-03-28",)

# %%
game_march_28_2019["Tm"].unique

# %%
game_march_28_2019[game_march_28_2019["Tm"]=="Houston"]

# %% [markdown]
# ## ...We can see who played in every game ^

# %%
game_march_28_2019.columns

# %%
game_march_28_2019.iloc[:,6]

# %% [markdown]
# ### *"@"* means they're playing as *visitors*.

# %% [markdown]
# # Startegy:
# ### General Strategy:
# Retrieve data for each player in each game played. Feed the model with data from past year for each player and past month. Build a dataframe where each row represents the features to train the model and to make predictions out of the model.
#
# Each row would have the full 283 features from past season plus the 23 from past month for each player that played the particular game plus 2 team features.
#
# ### Specific Tasks
#
# Usually there are 9 players, so there would be 9 times 283 features only to account for past season statistics of 1 team. So this number would be later mulitply also by 2 since each game involves 2 teams. We will use **schedule_and_record()** function to get the players who played in a game, so we can later use **batting_stats()** function to get those 283 features from last season for each player that played a particular game.
#
# There will be also recent statistics from last month for each player as well, which is 22 features. Again this number would be multiply by 9 and then by 2. We will use **schedule_and_record()** function to get the players who played in that game, so we can later retrieve the past month statistics for each one of those players from **batting_stats_range()**.
#
# There will be also statistics from the team to be included in each record such as streak, and GB, also gotten from **schedule_and_record()**.
#
# ### Conclusion
# The training DataFrame will contain a record for each game of a single team and its opponent. This leads us to  **DataFrame with dimensions of 5494 columns by *Games-Played-By-The-Team* rows**. This is only batting statistics so far.

# %% [markdown]
# ## Analysing *pitching_stats()*

# %%
from pybaseball import pitching_stats

pitching_stats_2019 = pitching_stats("2019")
pitching_stats_2019.head(15)

# %%
pitching_stats_2019.columns

# %%
pitching_stats_2019.columns[:100]

# %%
pitching_stats_2019.columns[100:200]

# %%
pitching_stats_2019.columns[200:]

# %% [markdown]
# ### Aparanetly, we should use only the *(pi)* variables. They are calculated using a new algorythm that eliminates what Brooks Baseball considers errors from Pitch FX (pfx).
#
# link: https://www.reddit.com/r/Sabermetrics/comments/6qepoa/what_is_the_data_source_for_nonattributed_plate/

# %%
pfx_col = [x for x in pitching_stats_2019.columns if "(pfx)" in x ]
pfx_col

# %%
pitching_stats_2019.drop( columns = pfx_col, inplace=True )
pitching_stats_2019.columns

# %%
from pybaseball import pitching_stats_range

pitching_range_1day = pitching_stats_range("2019-03-28",)

# %%
pitching_range_1day.head()

# %%
pitchers_Astros_on_20190328 = pitching_range_1day[pitching_range_1day.Tm == "Houston"]
pitchers_Astros_on_20190328

# %% [markdown]
# ## So! we can know who pitched on a certain game ^

# %%
pitchers_Astros_on_20190328.columns

# %% [markdown]
# #### An idea is to keep columns that represent % of other columns. For example, keeping IFFB% but droping IFFB, since a percentage tells more of a story that an isolated scalar value. In this way, we can reduce redundancy in our features and, therefore, the total size of our features array.

# %%
bat_col_not_to_drop = [x for x in all_data_2019.columns if "%" in x and x[:-1] in all_data_2019.columns]
bat_col_not_to_drop

# %%
bat_col_to_drop = [x[:-1] for x in bat_col_not_to_drop]
bat_col_to_drop

# %%
pitch_col_not_to_drop = [x for x in pitching_stats_2019.columns if "%" in x and x[:-1] in pitching_stats_2019.columns]
pitch_col_not_to_drop

# %%
pitch_col_to_drop = [x[:-1] for x in pitch_col_not_to_drop]
pitch_col_to_drop

# %%
all_data_2019.drop(columns=bat_col_to_drop, inplace=True)
pitching_stats_2019.drop(columns=pitch_col_to_drop, inplace=True)
print(f"Total columns in bat_statistics: {len(all_data_2019.columns)}\nTotal columns in pitch_statistics: {len(pitching_stats_2019.columns)} ")

# %% [markdown]
# ### ...We still have loooots of columns.
#
#
# ##### We will have to get rid of some columns manually that we consider unnecesary such as "Age" or "Team", etc. However, some of these columns might be useful during concatenation, so we will handle this in within the function that creates the dataframe.
#
# ## Let's explore how many pitcher there are per game usually

# %%
# let's grab our datframe created through record_and_schedule() previously for The Astros season 2019:
Astros_record.head()

# %% [markdown]
# ### We will have to convert the date format cuz these guys are assholes

# %%
date = Astros_record.Date[1]
#date = date.split(",")
date = re.findall(r"\w* [0-9][0-9]|[0-9]", date)
date = date[0]
print(date)
year = "2019"
date = year + " " + date
date

# %%
import datetime as dt

# %%
date_formatted = dt.datetime.strptime(date,"%Y %b %d")
date_formatted

# %%
date_formatted.month

# %% [markdown]
# ### it worked out, so now we know how

# %%
type(date_formatted)

# %% [markdown]
# # %%%%%%%    Building the Training DataFrame    %%%%%%%%

# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
teams = set(all_data_2017["Team"])
teams
# Out:
# {'- - -',
#  'Angels',
#  'Astros',
#  'Athletics',
#  'Blue Jays',
#  'Braves',
#  'Brewers',
#  'Cardinals',
#  'Cubs',
#  'Diamondbacks',
#  'Dodgers',
#  'Giants',
#  'Indians',
#  'Mariners',
#  'Marlins',
#  'Mets',
#  'Nationals',
#  'Orioles',
#  'Padres',
#  'Phillies',
#  'Pirates',
#  'Rangers',
#  'Rays',
#  'Red Sox',
#  'Reds',
#  'Rockies',
#  'Royals',
#  'Tigers',
#  'Twins',
#  'White Sox',
#  'Yankees'}

# %%
team_dict = {'Angels':'LAA',
            'Athletics': 'OAK',
            'Astros': 'HOU',
            'Braves': 'ATL',
            'Brewers': 'MIL',
            'Cards': 'STL',
            'Cubs': 'CUB',
            'Diamondbacks': 'ARI',
            'Dodgers': 'LOS',
            'Giants': 'SFG',
            'Indians': 'CLE',
            'Jays': 'TOR',
            'Mariners': 'SEA',
            'Marlins': 'MIA',
            'Mets': 'NYM',
            'Nats': 'WAS',
            'Orioles': 'BAL',
            'Padres': 'SDP',
            'Phillies': 'PHI',
            'Pirates': 'PIT',
            'Rangers': 'TEX',
            'Rays': 'TBR',
            'Red Sox': 'BOS',
            'Reds': 'CIN',
            'Rockies': 'COL',
            'Royals': 'KCR',
            'Tigers': 'DET',
            'Twins': 'MIN',
            'White_Sox': 'CHW',
            'Yankees': 'NYY'
             
           }
def get_key_from_dict(dictionary, val): 
    for key, value in dictionary.items(): 
         if val == value: 
            return key

# %%
from pybaseball import pitching_stats

def format_dates_to_dt(un_date="Monday, Dec 31", year=1999):
    date = re.findall(r"\W\w\w\w\s\d+", un_date)
    date = date[0]
    date = str(year) + date
    date_formatted = dt.datetime.strptime(date,"%Y %b %d")
    return date_formatted

# %%
def modify_dates_from_lineups(date="1. Thu,3/29 at TEX W (4-1)#", year = 2018):
    date = re.findall(r"\d+/\d+", date)
    try: date = date[0]
    except: return
    date = str(year) +" " + date
    return date

# %%
def modify_date_col_from_lineups(df, year):
    df["0"] = df.apply(lambda x: modify_dates_from_lineups(x["0"],year), axis=1)
    df["0"] = pd.to_datetime(df["0"])
    return df

# %%
def clean_lineups(df):
    for row in range(0,len(df)):
        for column in range(2,11):
            original_name = df.iloc[row,column]
            name = original_name.split("-")
            name = name[0]
            df.replace(original_name,name, inplace=True)
            #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
            #has the same names over and over. We just need to grab all the different names and replace them
    return df

# %%
def format_lineups_df(df, year):
    df  =  modify_date_col_from_lineups(df, year)
    df = clean_lineups(df)
    df.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
    df.set_index("index", inplace=True, drop=True)
    return df

# %%
def get_dates_played(df=None,year=None):
    
    dates_played = [format_dates_to_dt(date, year) for date in df.Date]
    return dates_played

# %%
def get_team_schedule(year=None, team = "HOU"):
    
    teams_df  = schedule_and_record(year, team)
    teams_df  = teams_df.iloc[ : , [0,1,2,3,10,17] ]
    teams_df["Date"] = teams_df.apply(lambda x: format_dates_to_dt(x["Date"],year), axis=1)
    teams_df.replace("@",1, inplace=True)
    teams_df.replace("Home",0, inplace=True)
    return teams_df

# %%
def get_players_per_game(year = None, team = None):
    
    schedule_df = get_team_schedule(year, team)
    opponents = set(schedule_df["Opp"])
    
    bat_stat_path = Path(f"Data/Batting/Clean_Data/clean_batting_data_{year}.csv")
    all_bat_stats = pd.read_csv(bat_stat_path)
    
    lineups_path = Path(f"Lineups/{team}_lineups_{year}.csv")
    all_lineups_season = pd.read_csv(lineups_path)
    all_lineups_season = format_lineups_df(all_lineups_season, year)
    
    opponents_lineups = {}
    for opponent in opponents:
        opp_lineups_path = Path(f"Lineups/{opponent}_lineups_{year}.csv")
        opp_all_lineups_season = pd.read_csv(opp_lineups_path)
        print(f"opp: {opponent}")
        opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
        opponents_lineups.update({opponent:opp_all_lineups_season})
    
    players_df = pd.DataFrame()
    
    i = 0
    for date in schedule_df["Date"]:
        
        
        adversary = schedule_df[schedule_df["Date"]==date.strftime("%Y-%m-%d")]["Opp"].values[0]

        temp_dict = {"Date":date}

        ##Line ups for the team
        try: all_players_on_date = all_lineups_season[all_lineups_season["Date"]==date.strftime("%Y-%m-%d")]
            
        except:
            print(f"No game on this date {date} for team")
            continue
            
        count = 1  
        all_players_team = all_players_on_date.iloc[0]       
        for player in all_players_team[1:]:            
            temp_dict.update({f"player_{count:02}" : player})           
            count+=1
            
        ##Line ups for the adversary
        try:
            opp_lineups_df = opponents_lineups[adversary]
            all_opponents_on_date = opp_lineups_df[opp_lineups_df["Date"]==date.strftime("%Y-%m-%d")]
            all_opponents_on_date.columns = ["Date","10","11","12","12","14","15","16","17","18"]
        except:
            print(f"No game on this date {date} for opponent")
            continue

        count = 10  
        all_players_opp = all_opponents_on_date.iloc[0]       
        for enemy in all_players_opp[1:]:            
            temp_dict.update({f"player_{count:02}" : enemy})           
            count+=1
         
              
        temp_df = pd.DataFrame(temp_dict, index =[i])
        players_df = pd.concat([players_df,temp_df], axis=0, sort = True )
        i+=1
        
    schedule_df.set_index("Date", inplace=True)
    players_df.set_index("Date", inplace=True)
    teams_df = pd.concat([schedule_df,players_df], axis=1, join="inner")
    teams_df.reset_index(inplace=True, drop=False)
    
    return teams_df

# %%
players_per_game_for_HOU_2018 = get_players_per_game(year = 2018, team = "HOU")
players_per_game_for_HOU_2018.head(20)
# Out:
# opp: KCR
# opp: DET
# opp: TBR
# opp: BOS
# opp: OAK
# opp: CHW
# opp: LAD
# opp: TOR
# opp: MIN
# opp: TEX
# opp: CLE
# opp: LAA
# opp: SDP
# opp: ARI
# opp: SFG
# opp: NYY
# opp: COL
# opp: BAL
# opp: SEA
# temporary dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 0 2018-03-29  Springer   Bregman    Altuve    Correa  Gonzalez   Reddick
#
#   player_07  player_08 player_09  player_10 player_11 player_12 player_13  \
# 0    Gattis  Marisnick    McCann  DeShields     Gallo    Andrus    Beltre
#
#   player_14 player_15 player_16 player_17 player_18
# 0    Mazara      Choo  Chirinos      Odor       Rua
# players dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 0 2018-03-29  Springer   Bregman    Altuve    Correa  Gonzalez   Reddick
#
#   player_07  player_08 player_09  player_10 player_11 player_12 player_13  \
# 0    Gattis  Marisnick    McCann  DeShields     Gallo    Andrus    Beltre
#
#   player_14 player_15 player_16 player_17 player_18
# 0    Mazara      Choo  Chirinos      Odor       Rua
# temporary dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 1 2018-03-30  Springer   Reddick    Altuve    Correa   Bregman  Gonzalez
#
#   player_07 player_08 player_09  player_10 player_11 player_12 player_13  \
# 1    Gattis    Fisher    Stassi  DeShields     Gallo    Andrus    Beltre
#
#   player_14 player_15 player_16 player_17 player_18
# 1    Mazara      Choo  Chirinos      Odor       Rua
# players dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 0 2018-03-29  Springer   Bregman    Altuve    Correa  Gonzalez   Reddick
# 1 2018-03-30  Springer   Reddick    Altuve    Correa   Bregman  Gonzalez
#
#   player_07  player_08 player_09  player_10 player_11 player_12 player_13  \
# 0    Gattis  Marisnick    McCann  DeShields     Gallo    Andrus    Beltre
# 1    Gattis     Fisher    Stassi  DeShields     Gallo    Andrus    Beltre
#
#   player_14 player_15 player_16 player_17 player_18
# 0    Mazara      Choo  Chirinos      Odor       Rua
# 1    Mazara      Choo  Chirinos      Odor       Rua
# temporary dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 2 2018-03-31  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
#
#   player_07 player_08  player_09 player_10 player_11 player_12 player_13  \
# 2     Davis    McCann  Marisnick    Andrus     Gallo    Beltre    Mazara
#
#   player_14 player_15 player_16 player_17 player_18
# 2      Choo      Odor   Centeno  Robinson     Tocci
# players dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 0 2018-03-29  Springer   Bregman    Altuve    Correa  Gonzalez   Reddick
# 1 2018-03-30  Springer   Reddick    Altuve    Correa   Bregman  Gonzalez
# 2 2018-03-31  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
#
#   player_07  player_08  player_09  player_10 player_11 player_12 player_13  \
# 0    Gattis  Marisnick     McCann  DeShields     Gallo    Andrus    Beltre
# 1    Gattis     Fisher     Stassi  DeShields     Gallo    Andrus    Beltre
# 2     Davis     McCann  Marisnick     Andrus     Gallo    Beltre    Mazara
#
#   player_14 player_15 player_16 player_17 player_18
# 0    Mazara      Choo  Chirinos      Odor       Rua
# 1    Mazara      Choo  Chirinos      Odor       Rua
# 2      Choo      Odor   Centeno  Robinson     Tocci
# temporary dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 3 2018-04-01  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
#
#    player_07 player_08 player_09 player_10 player_11 player_12 player_13  \
# 3  Marisnick    Stassi    Fisher    Andrus     Gallo    Beltre    Mazara
#
#   player_14 player_15 player_16 player_17 player_18
# 3  Chirinos      Odor       Rua    Profar  Robinson
# players dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 0 2018-03-29  Springer   Bregman    Altuve    Correa  Gonzalez   Reddick
# 1 2018-03-30  Springer   Reddick    Altuve    Correa   Bregman  Gonzalez
# 2 2018-03-31  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
# 3 2018-04-01  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
#
#    player_07  player_08  player_09  player_10 player_11 player_12 player_13  \
# 0     Gattis  Marisnick     McCann  DeShields     Gallo    Andrus    Beltre
# 1     Gattis     Fisher     Stassi  DeShields     Gallo    Andrus    Beltre
# 2      Davis     McCann  Marisnick     Andrus     Gallo    Beltre    Mazara
# 3  Marisnick     Stassi     Fisher     Andrus     Gallo    Beltre    Mazara
#
#   player_14 player_15 player_16 player_17 player_18
# 0    Mazara      Choo  Chirinos      Odor       Rua
# 1    Mazara      Choo  Chirinos      Odor       Rua
# 2      Choo      Odor   Centeno  Robinson     Tocci
# 3  Chirinos      Odor       Rua    Profar  Robinson
# temporary dataframe:
#          Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 4 2018-04-02  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
#
# 8   Villanueva    Asuaje   Renfroe  Spangenberg        Ellis     Margot
# 9   Villanueva   Headley   Renfroe       Galvis       Hedges     Margot
# 10     Rosario  Morrison   Escobar       Kepler       Buxton     Castro
# 11     Escobar  Grossman  Morrison       Garver       Buxton    LaMarre
# 12    Morrison   Escobar    Kepler       Buxton       Castro   Adrianza
# 13      Beltre     Gallo    Guzman     Chirinos     Robinson      Kiner
# 14      Beltre    Guzman       Rua      Centeno        Kiner   Robinson
# 15      Beltre     Gallo    Guzman     Chirinos        Kiner      Tocci
# 16        Cruz    Seager   Haniger      Heredia       Motter    Freitas
# temporary dataframe:
#           Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 17 2018-04-17  Springer    Altuve    Correa   Gurriel   Bregman   Reddick
#
#    player_07 player_08  player_09 player_10 player_11 player_12 player_13  \
# 17    Gattis    McCann  Marisnick    Gordon    Segura      Cano      Cruz
#
#    player_14 player_15  player_16 player_17 player_18
# 17    Seager   Haniger  Vogelbach    Suzuki   Marjama
# players dataframe:
#           Date player_01 player_02 player_03 player_04 player_05 player_06  \
# 0  2018-03-29  Springer   Bregman    Altuve    Correa  Gonzalez   Reddick
# 1  2018-03-30  Springer   Reddick    Altuve    Correa   Bregman  Gonzalez
# 2  2018-03-31  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
# 3  2018-04-01  Springer   Bregman    Altuve    Correa  Gonzalez    Gattis
# 4  2018-04-02  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
# 5  2018-04-03  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
# 6  2018-04-04  Springer   Bregman    Altuve   Reddick  Gonzalez    Stassi
# 7  2018-04-06  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
# 8  2018-04-07  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
# 9  2018-04-08  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
# 10 2018-04-09  Springer   Bregman    Altuve    Correa  Gonzalez    McCann
# 11 2018-04-10  Springer   Bregman    Altuve    Correa   Reddick  Gonzalez
# 12 2018-04-11  Springer   Bregman    Altuve    Correa   Reddick    Gattis
# 13 2018-04-13  Springer   Bregman    Altuve    Correa   Gurriel    Gattis
# 14 2018-04-14  Springer   Bregman    Altuve    Correa   Gurriel   Reddick
# 15 2018-04-15  Springer   Bregman    Altuve    Correa   Reddick   Gurriel
# 16 2018-04-16  Springer   Bregman    Altuve    Correa   Gurriel    Gattis
# 17 2018-04-17  Springer    Altuve    Correa   Gurriel   Bregman   Reddick
#
#     player_07  player_08  player_09  player_10 player_11 player_12  \
# 0      Gattis  Marisnick     McCann  DeShields     Gallo    Andrus
# 1      Gattis     Fisher     Stassi  DeShields     Gallo    Andrus
# 2       Davis     McCann  Marisnick     Andrus     Gallo    Beltre
# 3   Marisnick     Stassi     Fisher     Andrus     Gallo    Beltre
# 4      Gattis     McCann     Fisher      Davis   Machado    Schoop
# 5      Gattis     McCann     Fisher      Davis   Machado    Schoop
# 6   Marisnick      Davis     Fisher    Beckham   Machado    Schoop
# 7      Gattis     McCann     Fisher     Margot    Pirela    Hosmer
# 8      Gattis     McCann  Marisnick     Pirela    Galvis    Hosmer
# 9      Gattis     Stassi     Fisher     Asuaje    Hosmer    Pirela
# 10      Davis  Marisnick     Fisher     Dozier     Mauer      Sano
# 11     McCann      Davis  Marisnick     Dozier     Mauer      Sano
# 12     Stassi      Davis     Fisher     Dozier     Mauer   Rosario
# ...
# 141 2018-09-08   Springer    Altuve   Bregman   Gurriel    Correa     White
# 142 2018-09-09   Springer    Altuve   Bregman   Gurriel    Correa  Gonzalez
# 154      Simmons      Arcia      Marte       Cowart   Hermosillo    Johnson
# 155      Grichuk     Pillar       Diaz    Hernandez        Maile      Urena
# 156      Morales    Solarte       Diaz        Smith       Jansen      Urena
# 157      Grichuk     Tellez       Diaz      McGuire        Urena      Berti
# 158        Jones    Stewart     Joseph    Wilkerson     Peterson      Wynns
# 159      Mancini    Beckham      Nunez      Stewart      Rickard     Joseph
# 160      Mancini    Beckham      Nunez      Stewart      Rickard     Joseph
# 161      Mancini    Beckham      Nunez      Stewart    Wilkerson     Joseph
#
# [162 rows x 19 columns]
#          Date   Tm  Home_Away  Opp      GB  Streak player_01 player_02  \
# 0  2018-03-29  HOU          1  TEX    Tied       1  Springer   Bregman
# 1  2018-03-30  HOU          1  TEX     0.5      -1  Springer   Reddick
# 2  2018-03-31  HOU          1  TEX    Tied       1  Springer   Bregman
# 3  2018-04-01  HOU          1  TEX    Tied       2  Springer   Bregman
# 4  2018-04-02  HOU          0  BAL  up 1.0       3  Springer   Bregman
# 5  2018-04-03  HOU          0  BAL  up 1.0       4  Springer   Bregman
# 6  2018-04-04  HOU          0  BAL  up 1.0       5  Springer   Bregman
# 7  2018-04-06  HOU          0  SDP    Tied      -1  Springer   Bregman
# 8  2018-04-07  HOU          0  SDP  up 1.0       1  Springer   Bregman
# 9  2018-04-08  HOU          0  SDP  up 1.0       2  Springer   Bregman
# 10 2018-04-09  HOU          1  MIN  up 1.0       3  Springer   Bregman
# 11 2018-04-10  HOU          1  MIN    Tied      -1  Springer   Bregman
# 12 2018-04-11  HOU          1  MIN     1.0      -2  Springer   Bregman
# 13 2018-04-13  HOU          0  TEX     1.5       1  Springer   Bregman
# 14 2018-04-14  HOU          0  TEX     2.5      -1  Springer   Bregman
# 15 2018-04-15  HOU          0  TEX     3.0      -2  Springer   Bregman
# 16 2018-04-16  HOU          1  SEA     3.5      -3  Springer   Bregman
# 17 2018-04-17  HOU          1  SEA     2.5       1  Springer    Altuve
# 18 2018-04-18  HOU          1  SEA     1.5       2  Springer    Altuve
# 19 2018-04-19  HOU          1  SEA     0.5       3  Springer    Altuve
#
#    player_03 player_04  ...  player_09  player_10 player_11 player_12  \
# 0     Altuve    Correa  ...     McCann  DeShields     Gallo    Andrus
# 1     Altuve    Correa  ...     Stassi  DeShields     Gallo    Andrus
# 2     Altuve    Correa  ...  Marisnick     Andrus     Gallo    Beltre
# 3     Altuve    Correa  ...     Fisher     Andrus     Gallo    Beltre
# 4     Altuve    Correa  ...     Fisher      Davis   Machado    Schoop
# 5     Altuve    Correa  ...     Fisher      Davis   Machado    Schoop
# 6     Altuve   Reddick  ...     Fisher    Beckham   Machado    Schoop
# 7     Altuve    Correa  ...     Fisher     Margot    Pirela    Hosmer
# 8     Altuve    Correa  ...  Marisnick     Pirela    Galvis    Hosmer
# 9     Altuve    Correa  ...     Fisher     Asuaje    Hosmer    Pirela
# 10    Altuve    Correa  ...     Fisher     Dozier     Mauer      Sano
# 11    Altuve    Correa  ...  Marisnick     Dozier     Mauer      Sano
# 12    Altuve    Correa  ...     Fisher     Dozier     Mauer   Rosario
# 13    Altuve    Correa  ...  Marisnick       Choo    Profar    Mazara
# 14    Altuve    Correa  ...     Stassi       Choo    Profar     Gallo
# 15    Altuve    Correa  ...     Fisher       Choo    Profar    Mazara
# 16    Altuve    Correa  ...  Marisnick     Gordon    Segura      Cano
# 17    Correa   Gurriel  ...  Marisnick     Gordon    Segura      Cano
# 18    Correa   Reddick  ...     Fisher     Gordon    Segura      Cano
# 19    Correa    Gattis  ...  Marisnick     Gordon    Segura      Cano
#
#      player_13 player_14 player_15    player_16    player_17  player_18
# 0       Beltre    Mazara      Choo     Chirinos         Odor        Rua
# 1       Beltre    Mazara      Choo     Chirinos         Odor        Rua
# 2       Mazara      Choo      Odor      Centeno     Robinson      Tocci
# 3       Mazara  Chirinos      Odor          Rua       Profar   Robinson
# 4        Jones   Mancini    Rasmus      Beckham      Alvarez     Joseph
# 5        Jones   Mancini    Rasmus      Beckham        Sisco  Santander
# 6        Jones   Mancini  Valencia    Santander       Joseph     Gentry
# 7   Villanueva   Renfroe    Asuaje       Galvis  Spangenberg     Hedges
# 8   Villanueva    Asuaje   Renfroe  Spangenberg        Ellis     Margot
# 9   Villanueva   Headley   Renfroe       Galvis       Hedges     Margot
# 10     Rosario  Morrison   Escobar       Kepler       Buxton     Castro
# 11     Escobar  Grossman  Morrison       Garver       Buxton    LaMarre
# 12    Morrison   Escobar    Kepler       Buxton       Castro   Adrianza
# 13      Beltre     Gallo    Guzman     Chirinos     Robinson      Kiner
# 14      Beltre    Guzman       Rua      Centeno        Kiner   Robinson
# 15      Beltre     Gallo    Guzman     Chirinos        Kiner      Tocci
# 16        Cruz    Seager   Haniger      Heredia       Motter    Freitas
# 17        Cruz    Seager   Haniger    Vogelbach       Suzuki    Marjama
# 18        Cruz    Seager   Haniger        Gamel    Vogelbach    Freitas
# 19        Cruz    Seager   Haniger        Gamel    Vogelbach    Freitas
#
# [20 rows x 24 columns]

# %%
x = players_per_game_for_HOU_2018.iloc[0][3]
x
# Out:
# 'TEX'

# %%
x[3]
# Out:
# 'TEX'

# %%
def get_stats_startingplayer_by_game(players_df, team, year):
    
    batting_season_data = batting_stats(year-1)   
    #pitching_season_data = pitching_stats(year)
    #print(pitching_season_data.head()) 
    
    stats_players_start_lineup = pd.DataFrame()
    
    for row in range(0,len(players_df)):
        print(row)       
        all_players_stats = pd.DataFrame()
        
        #for players of team      
        for player in players_df.iloc[row][6:15]:
            #print(f"players: {len(players_df.iloc[row][6:])}\n {players_df.iloc[row][6:]}")
            if("00:00:00" in str(player)): continue #it gets the Date as first row by default. Skip it.
                
            try: 
                all_team_bat_stats = batting_season_data[batting_season_data.Team == get_key_from_dict(team_dict,team)]
                #print(f"ALL TEAM STATS :\n{all_team_bat_stats.head()}")
                player_full_name = [x for x in all_team_bat_stats.Name if player in x]
                #print(player_full_name)
                player_bat_stats = all_team_bat_stats[all_team_bat_stats.Name == player_full_name[0]]
                #print(f"Stats for player {player_full_name} only: \n{player_bat_stats}")

            except: 
                print(f"{player} not in batting list")
                #create code to fill batting statistics for a new player full of NAs or 0.0
                continue
            
            player_bat_stats.reset_index(inplace=True)
            #print(f"SINGLE_PLAYER_STAT ++++++++++++++\n{player_bat_stats}")
            all_players_stats = pd.concat([ all_players_stats, player_bat_stats ] ,   axis=1)
            #print(f"ALL_PLAYER_STAT ##############\n{all_players_stats}")
            
         #for players of opponent     
        for enemy in players_df.iloc[row][15:24]:
            #print(f"players: {len(players_df.iloc[row][6:])}\n {players_df.iloc[row][6:]}")
            if("00:00:00" in str(enemy)): continue #it gets the Date as first row by default. Skip it.
                
            try: 
                print(f"row[3]: {players_df.iloc[row][3]}")
                all_opp_bat_stats = batting_season_data[batting_season_data.Team == 
                                                         get_key_from_dict(team_dict,players_df.iloc[row][3])]
                #print(f"ALL OPPONENT STATS :\n{all_opp_bat_stats.head()}")
                enemy_full_name = [x for x in all_opp_bat_stats.Name if enemy in x]
                #print(player_full_name)
                enemy_bat_stats = all_opp_bat_stats[all_opp_bat_stats.Name == enemy_full_name[0]]
                #print(f"Stats for player {player_full_name} only: \n{player_bat_stats}")

            except: 
                print(f"enemy {enemy} not in batting list")
                #create code to fill batting statistics for a new player full of NAs or 0.0
                continue
            
            enemy_bat_stats.reset_index(inplace=True)
            #print(f"SINGLE_PLAYER_STAT ++++++++++++++\n{player_bat_stats}")
            all_players_stats = pd.concat([ all_players_stats, enemy_bat_stats] ,   axis=1)
            #print(f"ALL_PLAYER_STAT ##############\n{all_players_stats}")
            
        try: 
            stats_players_start_lineup = stats_players_start_lineup.append(all_players_stats, ignore_index=True)
            #stats_players_start_lineup = pd.concat([stats_players_start_lineup,all_players_stats], join="outer",axis=0, sort = True )
        except: 
            print("could not append ")
            continue
        
    
    return stats_players_start_lineup

# %%
test = get_stats_startingplayer_by_game(players_per_game_for_HOU_2018, "HOU", 2018)
test
# Out:
# 0
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# 1
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# 2
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Centeno not in batting list
# row[3]: TEX
# row[3]: TEX
# enemy Tocci not in batting list
# could not append
# 3
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# 4
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Rasmus not in batting list
# row[3]: BAL
# enemy Beckham not in batting list
# row[3]: BAL
# row[3]: BAL
# could not append
# 5
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Rasmus not in batting list
# row[3]: BAL
# enemy Beckham not in batting list
# row[3]: BAL
# row[3]: BAL
# could not append
# 6
# row[3]: BAL
# enemy Beckham not in batting list
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Valencia not in batting list
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# could not append
# 7
# row[3]: SDP
# enemy Margot not in batting list
# row[3]: SDP
# enemy Pirela not in batting list
# row[3]: SDP
# enemy Hosmer not in batting list
# row[3]: SDP
# enemy Villanueva not in batting list
# row[3]: SDP
# enemy Renfroe not in batting list
# row[3]: SDP
# enemy Asuaje not in batting list
# row[3]: SDP
# enemy Galvis not in batting list
# row[3]: SDP
# enemy Spangenberg not in batting list
# row[3]: SDP
# enemy Hedges not in batting list
# could not append
# 8
# row[3]: SDP
# enemy Pirela not in batting list
# row[3]: SDP
# enemy Galvis not in batting list
# row[3]: SDP
# enemy Hosmer not in batting list
# row[3]: SDP
# enemy Villanueva not in batting list
# row[3]: SDP
# enemy Asuaje not in batting list
# row[3]: SDP
# enemy Renfroe not in batting list
# row[3]: SDP
# enemy Spangenberg not in batting list
# row[3]: SDP
# enemy Ellis not in batting list
# row[3]: SDP
# enemy Margot not in batting list
# could not append
# 9
# row[3]: SDP
# enemy Asuaje not in batting list
# row[3]: SDP
# enemy Hosmer not in batting list
# row[3]: SDP
# enemy Pirela not in batting list
# row[3]: SDP
# enemy Villanueva not in batting list
# row[3]: SDP
# enemy Headley not in batting list
# row[3]: SDP
# enemy Renfroe not in batting list
# row[3]: SDP
# enemy Galvis not in batting list
# row[3]: SDP
# enemy Hedges not in batting list
# row[3]: SDP
# enemy Margot not in batting list
# could not append
# 10
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Morrison not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# could not append
# 11
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Morrison not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy LaMarre not in batting list
# could not append
# 12
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Morrison not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# could not append
# 13
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# could not append
# 14
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# row[3]: TEX
# enemy Centeno not in batting list
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# could not append
# 15
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# enemy Tocci not in batting list
# could not append
# 16
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Freitas not in batting list
# could not append
# 17
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Suzuki not in batting list
# row[3]: SEA
# could not append
# 18
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Freitas not in batting list
# could not append
# 19
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Freitas not in batting list
# could not append
# 20
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Delmonico not in batting list
# row[3]: CHW
# enemy Castillo not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Anderson not in batting list
# row[3]: CHW
# enemy Narvaez not in batting list
# row[3]: CHW
# enemy Engel not in batting list
# could not append
# 21
# row[3]: CHW
# enemy Anderson not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Castillo not in batting list
# row[3]: CHW
# enemy Davidson not in batting list
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Thompson not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Engel not in batting list
# could not append
# 22
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Delmonico not in batting list
# row[3]: CHW
# enemy Castillo not in batting list
# row[3]: CHW
# enemy Davidson not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Anderson not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# could not append
# 23
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# could not append
# 24
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# could not append
# 25
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Rivera not in batting list
# could not append
# 26
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 27
# row[3]: OAK
# enemy Joyce not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Maxwell not in batting list
# could not append
# 28
# row[3]: OAK
# enemy Joyce not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 29
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Stanton not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Walker not in batting list
# row[3]: NYY
# enemy Torres not in batting list
# row[3]: NYY
# could not append
# 30
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Stanton not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Torres not in batting list
# could not append
# 31
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Stanton not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Torres not in batting list
# could not append
# 32
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Stanton not in batting list
# row[3]: NYY
# row[3]: NYY
# enemy Walker not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Torres not in batting list
# could not append
# 33
# Cole not in batting list
# row[3]: ARI
# enemy Peralta not in batting list
# row[3]: ARI
# enemy Dyson not in batting list
# row[3]: ARI
# enemy Goldschmidt not in batting list
# row[3]: ARI
# enemy Pollock not in batting list
# row[3]: ARI
# enemy Descalso not in batting list
# row[3]: ARI
# enemy Owings not in batting list
# row[3]: ARI
# enemy Ahmed not in batting list
# row[3]: ARI
# enemy Avila not in batting list
# row[3]: ARI
# enemy Medlen not in batting list
# could not append
# 34
# row[3]: ARI
# enemy Peralta not in batting list
# row[3]: ARI
# enemy Descalso not in batting list
# row[3]: ARI
# enemy Goldschmidt not in batting list
# row[3]: ARI
# enemy Pollock not in batting list
# row[3]: ARI
# enemy Souza not in batting list
# row[3]: ARI
# enemy Marte not in batting list
# row[3]: ARI
# enemy Ahmed not in batting list
# row[3]: ARI
# enemy Mathis not in batting list
# row[3]: ARI
# enemy Greinke not in batting list
# could not append
# 35
# Verlander not in batting list
# row[3]: ARI
# enemy Peralta not in batting list
# row[3]: ARI
# enemy Descalso not in batting list
# row[3]: ARI
# enemy Goldschmidt not in batting list
# row[3]: ARI
# enemy Pollock not in batting list
# row[3]: ARI
# enemy Souza not in batting list
# row[3]: ARI
# enemy Marte not in batting list
# row[3]: ARI
# enemy Avila not in batting list
# row[3]: ARI
# enemy Ahmed not in batting list
# row[3]: ARI
# enemy Koch not in batting list
# could not append
# 36
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# row[3]: OAK
# enemy Smolinski not in batting list
# could not append
# 37
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Joyce not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Maxwell not in batting list
# could not append
# 38
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Joyce not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# could not append
# 39
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# could not append
# 40
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# could not append
# 41
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# row[3]: TEX
# could not append
# 42
# row[3]: LAA
# enemy Cozart not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# could not append
# 43
# row[3]: LAA
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Rivera not in batting list
# could not append
# 44
# row[3]: LAA
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Cozart not in batting list
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# could not append
# 45
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Alonso not in batting list
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Davis not in batting list
# could not append
# 46
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Davis not in batting list
# could not append
# 47
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Alonso not in batting list
# row[3]: CLE
# enemy Cabrera not in batting list
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# could not append
# 48
# row[3]: SFG
# enemy Hernandez not in batting list
# row[3]: SFG
# enemy McCutchen not in batting list
# row[3]: SFG
# enemy Posey not in batting list
# row[3]: SFG
# enemy Belt not in batting list
# row[3]: SFG
# enemy Longoria not in batting list
# row[3]: SFG
# enemy Crawford not in batting list
# row[3]: SFG
# enemy Sandoval not in batting list
# row[3]: SFG
# enemy Jackson not in batting list
# row[3]: SFG
# enemy Tomlinson not in batting list
# could not append
# 49
# row[3]: SFG
# enemy Hernandez not in batting list
# row[3]: SFG
# enemy McCutchen not in batting list
# row[3]: SFG
# enemy Posey not in batting list
# row[3]: SFG
# enemy Belt not in batting list
# row[3]: SFG
# enemy Longoria not in batting list
# row[3]: SFG
# enemy Crawford not in batting list
# row[3]: SFG
# enemy Sandoval not in batting list
# row[3]: SFG
# enemy Hundley not in batting list
# row[3]: SFG
# enemy Tomlinson not in batting list
# could not append
# 50
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Alonso not in batting list
# row[3]: CLE
# enemy Cabrera not in batting list
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# could not append
# 51
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Cabrera not in batting list
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Davis not in batting list
# row[3]: CLE
# could not append
# 52
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Alonso not in batting list
# row[3]: CLE
# enemy Cabrera not in batting list
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# could not append
# 53
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# enemy Alonso not in batting list
# row[3]: CLE
# enemy Cabrera not in batting list
# row[3]: CLE
# row[3]: CLE
# row[3]: CLE
# could not append
# 54
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Torres not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Walker not in batting list
# could not append
# 55
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Stanton not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Torres not in batting list
# could not append
# 56
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Stanton not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# enemy Torres not in batting list
# row[3]: NYY
# row[3]: NYY
# row[3]: NYY
# could not append
# 57
# Federowicz not in batting list
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Moreland not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Devers not in batting list
# row[3]: BOS
# enemy Holt not in batting list
# row[3]: BOS
# enemy Leon not in batting list
# row[3]: BOS
# enemy Bradley not in batting list
# row[3]: BOS
# enemy Swihart not in batting list
# could not append
# 58
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Moreland not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Devers not in batting list
# row[3]: BOS
# enemy Nunez not in batting list
# row[3]: BOS
# enemy Holt not in batting list
# row[3]: BOS
# enemy Leon not in batting list
# row[3]: BOS
# enemy Bradley not in batting list
# could not append
# 59
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Moreland not in batting list
# row[3]: BOS
# enemy Nunez not in batting list
# row[3]: BOS
# enemy Devers not in batting list
# row[3]: BOS
# enemy Swihart not in batting list
# row[3]: BOS
# enemy Vazquez not in batting list
# row[3]: BOS
# enemy Bradley not in batting list
# could not append
# 60
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Moreland not in batting list
# row[3]: BOS
# enemy Nunez not in batting list
# row[3]: BOS
# enemy Bradley not in batting list
# row[3]: BOS
# enemy Holt not in batting list
# row[3]: BOS
# enemy Swihart not in batting list
# row[3]: BOS
# enemy Leon not in batting list
# could not append
# 61
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# could not append
# 62
# Federowicz not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# could not append
# 63
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# could not append
# 64
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# could not append
# 65
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# could not append
# 66
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# could not append
# 67
# row[3]: OAK
# enemy Fowler not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 68
# row[3]: OAK
# enemy Fowler not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 69
# row[3]: OAK
# enemy Fowler not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 70
# row[3]: KCR
# enemy Merrifield not in batting list
# row[3]: KCR
# enemy Moustakas not in batting list
# row[3]: KCR
# enemy Perez not in batting list
# row[3]: KCR
# enemy Soler not in batting list
# row[3]: KCR
# enemy Gordon not in batting list
# row[3]: KCR
# enemy Dozier not in batting list
# row[3]: KCR
# enemy Escobar not in batting list
# row[3]: KCR
# enemy Orlando not in batting list
# row[3]: KCR
# enemy Almonte not in batting list
# could not append
# 71
# row[3]: KCR
# enemy Merrifield not in batting list
# row[3]: KCR
# enemy Moustakas not in batting list
# row[3]: KCR
# enemy Perez not in batting list
# row[3]: KCR
# enemy Dozier not in batting list
# row[3]: KCR
# enemy Gordon not in batting list
# row[3]: KCR
# enemy Escobar not in batting list
# row[3]: KCR
# enemy Almonte not in batting list
# row[3]: KCR
# enemy Butera not in batting list
# row[3]: KCR
# enemy Goins not in batting list
# could not append
# 72
# row[3]: KCR
# enemy Merrifield not in batting list
# row[3]: KCR
# enemy Gordon not in batting list
# row[3]: KCR
# enemy Moustakas not in batting list
# row[3]: KCR
# enemy Perez not in batting list
# row[3]: KCR
# enemy Dozier not in batting list
# row[3]: KCR
# enemy Escobar not in batting list
# row[3]: KCR
# enemy Goins not in batting list
# row[3]: KCR
# enemy Almonte not in batting list
# row[3]: KCR
# enemy Orlando not in batting list
# could not append
# 73
# row[3]: TBR
# enemy Duffy not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Ramos not in batting list
# row[3]: TBR
# enemy Cron not in batting list
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Adames not in batting list
# row[3]: TBR
# enemy Smith not in batting list
# row[3]: TBR
# enemy Gomez not in batting list
# row[3]: TBR
# enemy Field not in batting list
# could not append
# 74
# row[3]: TBR
# enemy Kiermaier not in batting list
# row[3]: TBR
# enemy Duffy not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Ramos not in batting list
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Cron not in batting list
# row[3]: TBR
# enemy Smith not in batting list
# row[3]: TBR
# enemy Gomez not in batting list
# row[3]: TBR
# enemy Hechavarria not in batting list
# could not append
# 75
# row[3]: TBR
# enemy Kiermaier not in batting list
# row[3]: TBR
# enemy Hechavarria not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Ramos not in batting list
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Adames not in batting list
# row[3]: TBR
# enemy Smith not in batting list
# row[3]: TBR
# enemy Gomez not in batting list
# row[3]: TBR
# enemy Field not in batting list
# could not append
# 76
# row[3]: KCR
# enemy Merrifield not in batting list
# row[3]: KCR
# enemy Herrera not in batting list
# row[3]: KCR
# enemy Moustakas not in batting list
# row[3]: KCR
# enemy Perez not in batting list
# row[3]: KCR
# enemy Dozier not in batting list
# row[3]: KCR
# enemy Gordon not in batting list
# row[3]: KCR
# enemy Escobar not in batting list
# row[3]: KCR
# enemy Orlando not in batting list
# row[3]: KCR
# enemy Mondesi not in batting list
# could not append
# 77
# row[3]: KCR
# enemy Merrifield not in batting list
# row[3]: KCR
# enemy Herrera not in batting list
# row[3]: KCR
# enemy Moustakas not in batting list
# row[3]: KCR
# enemy Perez not in batting list
# row[3]: KCR
# enemy Duda not in batting list
# row[3]: KCR
# enemy Gordon not in batting list
# row[3]: KCR
# enemy Dozier not in batting list
# row[3]: KCR
# enemy Escobar not in batting list
# row[3]: KCR
# enemy Goins not in batting list
# could not append
# 78
# row[3]: KCR
# enemy Herrera not in batting list
# row[3]: KCR
# enemy Gordon not in batting list
# row[3]: KCR
# enemy Moustakas not in batting list
# row[3]: KCR
# enemy Duda not in batting list
# row[3]: KCR
# enemy Dozier not in batting list
# row[3]: KCR
# enemy Escobar not in batting list
# row[3]: KCR
# enemy Almonte not in batting list
# row[3]: KCR
# enemy Butera not in batting list
# row[3]: KCR
# enemy Mondesi not in batting list
# could not append
# 79
# row[3]: TOR
# enemy Granderson not in batting list
# row[3]: TOR
# enemy Hernandez not in batting list
# row[3]: TOR
# enemy Solarte not in batting list
# row[3]: TOR
# enemy Morales not in batting list
# row[3]: TOR
# enemy Smoak not in batting list
# row[3]: TOR
# enemy Martin not in batting list
# row[3]: TOR
# enemy Grichuk not in batting list
# row[3]: TOR
# enemy Diaz not in batting list
# row[3]: TOR
# enemy Travis not in batting list
# could not append
# 80
# row[3]: TOR
# enemy Granderson not in batting list
# row[3]: TOR
# enemy Hernandez not in batting list
# row[3]: TOR
# enemy Solarte not in batting list
# row[3]: TOR
# enemy Smoak not in batting list
# row[3]: TOR
# enemy Pillar not in batting list
# row[3]: TOR
# enemy Martin not in batting list
# row[3]: TOR
# enemy Grichuk not in batting list
# row[3]: TOR
# enemy Diaz not in batting list
# row[3]: TOR
# enemy Travis not in batting list
# could not append
# 81
# row[3]: TOR
# enemy Grichuk not in batting list
# row[3]: TOR
# enemy Hernandez not in batting list
# row[3]: TOR
# enemy Solarte not in batting list
# row[3]: TOR
# enemy Pearce not in batting list
# row[3]: TOR
# enemy Morales not in batting list
# row[3]: TOR
# enemy Pillar not in batting list
# row[3]: TOR
# enemy Diaz not in batting list
# row[3]: TOR
# enemy Maile not in batting list
# row[3]: TOR
# enemy Travis not in batting list
# could not append
# 82
# row[3]: TBR
# enemy Kiermaier not in batting list
# row[3]: TBR
# enemy Duffy not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Ramos not in batting list
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Cron not in batting list
# row[3]: TBR
# enemy Smith not in batting list
# row[3]: TBR
# enemy Gomez not in batting list
# row[3]: TBR
# enemy Adames not in batting list
# could not append
# 83
# row[3]: TBR
# enemy Kiermaier not in batting list
# row[3]: TBR
# enemy Duffy not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Ramos not in batting list
# row[3]: TBR
# enemy Robertson not in batting list
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Hechavarria not in batting list
# row[3]: TBR
# enemy Smith not in batting list
# row[3]: TBR
# enemy Adames not in batting list
# could not append
# 84
# row[3]: TBR
# enemy Kiermaier not in batting list
# row[3]: TBR
# enemy Duffy not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Ramos not in batting list
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Robertson not in batting list
# row[3]: TBR
# enemy Cron not in batting list
# row[3]: TBR
# enemy Gomez not in batting list
# row[3]: TBR
# enemy Hechavarria not in batting list
# could not append
# 85
# row[3]: TBR
# enemy Wendle not in batting list
# row[3]: TBR
# enemy Duffy not in batting list
# row[3]: TBR
# enemy Bauers not in batting list
# row[3]: TBR
# enemy Robertson not in batting list
# row[3]: TBR
# enemy Gomez not in batting list
# row[3]: TBR
# enemy Smith not in batting list
# row[3]: TBR
# enemy Adames not in batting list
# row[3]: TBR
# enemy Sucre not in batting list
# row[3]: TBR
# enemy Field not in batting list
# could not append
# 86
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# could not append
# 87
# Federowicz not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# could not append
# 88
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Palka not in batting list
# row[3]: CHW
# enemy Davidson not in batting list
# row[3]: CHW
# enemy Narvaez not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Anderson not in batting list
# could not append
# 89
# Federowicz not in batting list
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Palka not in batting list
# row[3]: CHW
# enemy Davidson not in batting list
# row[3]: CHW
# enemy Smith not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Engel not in batting list
# could not append
# 90
# Tucker not in batting list
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Palka not in batting list
# row[3]: CHW
# enemy Davidson not in batting list
# row[3]: CHW
# enemy Narvaez not in batting list
# row[3]: CHW
# enemy Anderson not in batting list
# row[3]: CHW
# enemy Engel not in batting list
# could not append
# 91
# Tucker not in batting list
# row[3]: CHW
# enemy Anderson not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Abreu not in batting list
# row[3]: CHW
# enemy Davidson not in batting list
# row[3]: CHW
# enemy Smith not in batting list
# row[3]: CHW
# enemy Garcia not in batting list
# row[3]: CHW
# enemy Moncada not in batting list
# row[3]: CHW
# enemy Sanchez not in batting list
# row[3]: CHW
# enemy Engel not in batting list
# could not append
# 92
# Tucker not in batting list
# Federowicz not in batting list
# row[3]: OAK
# enemy Fowler not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 93
# Tucker not in batting list
# row[3]: OAK
# enemy Fowler not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 94
# Tucker not in batting list
# Federowicz not in batting list
# row[3]: OAK
# enemy Fowler not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Phegley not in batting list
# could not append
# 95
# row[3]: OAK
# enemy Martini not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 96
# Tucker not in batting list
# row[3]: DET
# enemy Goodrum not in batting list
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# enemy Rodriguez not in batting list
# row[3]: DET
# enemy Candelario not in batting list
# row[3]: DET
# could not append
# 97
# Tucker not in batting list
# Federowicz not in batting list
# row[3]: DET
# row[3]: DET
# enemy Goodrum not in batting list
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# enemy Candelario not in batting list
# row[3]: DET
# row[3]: DET
# enemy Reyes not in batting list
# could not append
# 98
# row[3]: DET
# row[3]: DET
# enemy Goodrum not in batting list
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# enemy Rodriguez not in batting list
# row[3]: DET
# enemy Candelario not in batting list
# row[3]: DET
# row[3]: DET
# enemy Reyes not in batting list
# could not append
# 99
# Tucker not in batting list
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Blash not in batting list
# could not append
# 100
# Tucker not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# could not append
# 101
# Federowicz not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Kinsler not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Briceno not in batting list
# row[3]: LAA
# enemy Fletcher not in batting list
# could not append
# 102
# Cole not in batting list
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# enemy Hampson not in batting list
# row[3]: COL
# enemy Iannetta not in batting list
# row[3]: COL
# could not append
# 103
# Tucker not in batting list
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# enemy Hampson not in batting list
# row[3]: COL
# row[3]: COL
# could not append
# 104
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# enemy Tocci not in batting list
# could not append
# 105
# Tucker not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# row[3]: TEX
# enemy Tocci not in batting list
# could not append
# 106
# Maldonado not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# enemy Kiner not in batting list
# row[3]: TEX
# enemy Guzman not in batting list
# row[3]: TEX
# row[3]: TEX
# row[3]: TEX
# could not append
# 107
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Romine not in batting list
# could not append
# 108
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Herrmann not in batting list
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Romine not in batting list
# could not append
# 109
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Maybin not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Romine not in batting list
# row[3]: SEA
# enemy Vincej not in batting list
# could not append
# 110
# Maldonado not in batting list
# Verlander not in batting list
# row[3]: LAD
# enemy Pederson not in batting list
# row[3]: LAD
# enemy Machado not in batting list
# row[3]: LAD
# enemy Turner not in batting list
# row[3]: LAD
# enemy Grandal not in batting list
# row[3]: LAD
# enemy Bellinger not in batting list
# row[3]: LAD
# enemy Kemp not in batting list
# row[3]: LAD
# enemy Muncy not in batting list
# row[3]: LAD
# enemy Taylor not in batting list
# row[3]: LAD
# enemy Wood not in batting list
# could not append
# 111
# Maldonado not in batting list
# row[3]: LAD
# enemy Taylor not in batting list
# row[3]: LAD
# enemy Machado not in batting list
# row[3]: LAD
# enemy Turner not in batting list
# row[3]: LAD
# enemy Kemp not in batting list
# row[3]: LAD
# enemy Dozier not in batting list
# row[3]: LAD
# enemy Puig not in batting list
# row[3]: LAD
# enemy Hernandez not in batting list
# row[3]: LAD
# enemy Barnes not in batting list
# row[3]: LAD
# enemy Maeda not in batting list
# could not append
# 112
# Cole not in batting list
# row[3]: LAD
# enemy Pederson not in batting list
# row[3]: LAD
# enemy Machado not in batting list
# row[3]: LAD
# enemy Grandal not in batting list
# row[3]: LAD
# enemy Bellinger not in batting list
# row[3]: LAD
# enemy Dozier not in batting list
# row[3]: LAD
# enemy Muncy not in batting list
# row[3]: LAD
# enemy Taylor not in batting list
# row[3]: LAD
# enemy Hernandez not in batting list
# row[3]: LAD
# enemy Buehler not in batting list
# could not append
# 113
# Maldonado not in batting list
# row[3]: SFG
# enemy McCutchen not in batting list
# row[3]: SFG
# enemy Posey not in batting list
# row[3]: SFG
# enemy Longoria not in batting list
# row[3]: SFG
# enemy Crawford not in batting list
# row[3]: SFG
# enemy Slater not in batting list
# row[3]: SFG
# enemy Panik not in batting list
# row[3]: SFG
# enemy Duggar not in batting list
# row[3]: SFG
# enemy Hernandez not in batting list
# row[3]: SFG
# enemy Rodriguez not in batting list
# could not append
# 114
# row[3]: SFG
# enemy McCutchen not in batting list
# row[3]: SFG
# enemy Posey not in batting list
# row[3]: SFG
# enemy Longoria not in batting list
# row[3]: SFG
# enemy Crawford not in batting list
# row[3]: SFG
# enemy Hundley not in batting list
# row[3]: SFG
# enemy Slater not in batting list
# row[3]: SFG
# enemy d'Arnaud not in batting list
# row[3]: SFG
# enemy Duggar not in batting list
# row[3]: SFG
# enemy Bumgarner not in batting list
# could not append
# 115
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# enemy Maybin not in batting list
# row[3]: SEA
# could not append
# 116
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# enemy Maybin not in batting list
# row[3]: SEA
# could not append
# 117
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Herrmann not in batting list
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# could not append
# 118
# Tucker not in batting list
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Maybin not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Romine not in batting list
# could not append
# 119
# Tucker not in batting list
# Maldonado not in batting list
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# could not append
# 120
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# row[3]: COL
# enemy Dahl not in batting list
# row[3]: COL
# row[3]: COL
# row[3]: COL
# enemy Iannetta not in batting list
# could not append
# 121
# Maldonado not in batting list
# row[3]: OAK
# enemy Martini not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 122
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Laureano not in batting list
# row[3]: OAK
# enemy Phegley not in batting list
# could not append
# 123
# Maldonado not in batting list
# row[3]: OAK
# enemy Martini not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Canha not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 124
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# could not append
# 125
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Herrmann not in batting list
# row[3]: SEA
# could not append
# 126
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# could not append
# 127
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Rivera not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# could not append
# 128
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Arcia not in batting list
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# could not append
# 129
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Rivera not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# could not append
# 130
# Maldonado not in batting list
# row[3]: OAK
# enemy Martini not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# row[3]: OAK
# enemy Laureano not in batting list
# could not append
# 131
# Maldonado not in batting list
# row[3]: OAK
# enemy Martini not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Laureano not in batting list
# row[3]: OAK
# enemy Lucroy not in batting list
# could not append
# 132
# row[3]: OAK
# enemy Semien not in batting list
# row[3]: OAK
# enemy Chapman not in batting list
# row[3]: OAK
# enemy Lowrie not in batting list
# row[3]: OAK
# enemy Davis not in batting list
# row[3]: OAK
# enemy Piscotty not in batting list
# row[3]: OAK
# enemy Olson not in batting list
# row[3]: OAK
# enemy Pinder not in batting list
# row[3]: OAK
# enemy Laureano not in batting list
# row[3]: OAK
# enemy Phegley not in batting list
# could not append
# 133
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Arcia not in batting list
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# could not append
# 134
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# enemy Briceno not in batting list
# could not append
# 135
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fernandez not in batting list
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# enemy Arcia not in batting list
# row[3]: LAA
# could not append
# 136
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fletcher not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Fernandez not in batting list
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# enemy Arcia not in batting list
# row[3]: LAA
# row[3]: LAA
# could not append
# 137
# row[3]: MIN
# row[3]: MIN
# enemy Forsythe not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Cave not in batting list
# row[3]: MIN
# enemy Austin not in batting list
# row[3]: MIN
# enemy Field not in batting list
# could not append
# 138
# Maldonado not in batting list
# row[3]: MIN
# row[3]: MIN
# enemy Forsythe not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Cave not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# could not append
# 139
# row[3]: MIN
# enemy Forsythe not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Austin not in batting list
# row[3]: MIN
# row[3]: MIN
# row[3]: MIN
# enemy Astudillo not in batting list
# row[3]: MIN
# enemy Field not in batting list
# could not append
# 140
# Maldonado not in batting list
# row[3]: BOS
# enemy Betts not in batting list
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Moreland not in batting list
# row[3]: BOS
# enemy Kinsler not in batting list
# row[3]: BOS
# enemy Nunez not in batting list
# row[3]: BOS
# enemy Leon not in batting list
# row[3]: BOS
# enemy Bradley not in batting list
# could not append
# 141
# Maldonado not in batting list
# row[3]: BOS
# enemy Betts not in batting list
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Moreland not in batting list
# row[3]: BOS
# enemy Kinsler not in batting list
# row[3]: BOS
# enemy Devers not in batting list
# row[3]: BOS
# enemy Vazquez not in batting list
# row[3]: BOS
# enemy Bradley not in batting list
# could not append
# 142
# row[3]: BOS
# enemy Betts not in batting list
# row[3]: BOS
# enemy Benintendi not in batting list
# row[3]: BOS
# enemy Martinez not in batting list
# row[3]: BOS
# enemy Bogaerts not in batting list
# row[3]: BOS
# enemy Pearce not in batting list
# row[3]: BOS
# enemy Kinsler not in batting list
# row[3]: BOS
# enemy Phillips not in batting list
# row[3]: BOS
# enemy Nunez not in batting list
# row[3]: BOS
# enemy Leon not in batting list
# could not append
# 143
# Maldonado not in batting list
# row[3]: DET
# enemy Candelario not in batting list
# row[3]: DET
# enemy Stewart not in batting list
# row[3]: DET
# row[3]: DET
# row[3]: DET
# enemy Goodrum not in batting list
# row[3]: DET
# enemy Rodriguez not in batting list
# row[3]: DET
# row[3]: DET
# enemy Lugo not in batting list
# row[3]: DET
# could not append
# 144
# row[3]: DET
# enemy Candelario not in batting list
# row[3]: DET
# enemy Stewart not in batting list
# row[3]: DET
# row[3]: DET
# row[3]: DET
# enemy Goodrum not in batting list
# row[3]: DET
# enemy Greiner not in batting list
# row[3]: DET
# enemy Rodriguez not in batting list
# row[3]: DET
# enemy Lugo not in batting list
# row[3]: DET
# could not append
# 145
# Maldonado not in batting list
# row[3]: DET
# enemy Candelario not in batting list
# row[3]: DET
# enemy Stewart not in batting list
# row[3]: DET
# row[3]: DET
# enemy Goodrum not in batting list
# row[3]: DET
# row[3]: DET
# row[3]: DET
# row[3]: DET
# enemy Lugo not in batting list
# row[3]: DET
# enemy Reyes not in batting list
# could not append
# 146
# Maldonado not in batting list
# row[3]: ARI
# enemy Pollock not in batting list
# row[3]: ARI
# enemy Escobar not in batting list
# row[3]: ARI
# enemy Goldschmidt not in batting list
# row[3]: ARI
# enemy Peralta not in batting list
# row[3]: ARI
# enemy Walker not in batting list
# row[3]: ARI
# enemy Souza not in batting list
# row[3]: ARI
# enemy Ahmed not in batting list
# row[3]: ARI
# enemy Marte not in batting list
# row[3]: ARI
# enemy Mathis not in batting list
# could not append
# 147
# row[3]: ARI
# enemy Pollock not in batting list
# row[3]: ARI
# enemy Escobar not in batting list
# row[3]: ARI
# enemy Peralta not in batting list
# row[3]: ARI
# enemy Goldschmidt not in batting list
# row[3]: ARI
# enemy Descalso not in batting list
# row[3]: ARI
# enemy Souza not in batting list
# row[3]: ARI
# enemy Marte not in batting list
# row[3]: ARI
# enemy Ahmed not in batting list
# row[3]: ARI
# enemy Avila not in batting list
# could not append
# 148
# Maldonado not in batting list
# row[3]: ARI
# enemy Jay not in batting list
# row[3]: ARI
# enemy Pollock not in batting list
# row[3]: ARI
# enemy Peralta not in batting list
# row[3]: ARI
# enemy Goldschmidt not in batting list
# row[3]: ARI
# enemy Escobar not in batting list
# row[3]: ARI
# enemy Descalso not in batting list
# row[3]: ARI
# enemy Marte not in batting list
# row[3]: ARI
# enemy Ahmed not in batting list
# row[3]: ARI
# enemy Mathis not in batting list
# could not append
# 149
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# enemy Maybin not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# could not append
# 150
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Span not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Herrmann not in batting list
# row[3]: SEA
# could not append
# 151
# Maldonado not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# enemy Healy not in batting list
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# row[3]: SEA
# could not append
# 152
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Fernandez not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Arcia not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ward not in batting list
# could not append
# 153
# row[3]: LAA
# row[3]: LAA
# enemy Fernandez not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Ward not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Briceno not in batting list
# could not append
# 154
# Maldonado not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Upton not in batting list
# row[3]: LAA
# enemy Ohtani not in batting list
# row[3]: LAA
# row[3]: LAA
# enemy Arcia not in batting list
# row[3]: LAA
# row[3]: LAA
# row[3]: LAA
# enemy Hermosillo not in batting list
# row[3]: LAA
# enemy Johnson not in batting list
# could not append
# 155
# row[3]: TOR
# enemy Davis not in batting list
# row[3]: TOR
# enemy Gurriel not in batting list
# row[3]: TOR
# enemy Smoak not in batting list
# row[3]: TOR
# enemy Grichuk not in batting list
# row[3]: TOR
# enemy Pillar not in batting list
# row[3]: TOR
# enemy Diaz not in batting list
# row[3]: TOR
# enemy Hernandez not in batting list
# row[3]: TOR
# enemy Maile not in batting list
# row[3]: TOR
# enemy Urena not in batting list
# could not append
# 156
# Maldonado not in batting list
# row[3]: TOR
# enemy Davis not in batting list
# row[3]: TOR
# enemy McKinney not in batting list
# row[3]: TOR
# enemy Tellez not in batting list
# row[3]: TOR
# enemy Morales not in batting list
# row[3]: TOR
# enemy Solarte not in batting list
# row[3]: TOR
# enemy Diaz not in batting list
# row[3]: TOR
# enemy Smith not in batting list
# row[3]: TOR
# enemy Jansen not in batting list
# row[3]: TOR
# enemy Urena not in batting list
# could not append
# 157
# Tucker not in batting list
# Straw not in batting list
# row[3]: TOR
# enemy McKinney not in batting list
# row[3]: TOR
# enemy Pillar not in batting list
# row[3]: TOR
# enemy Smoak not in batting list
# row[3]: TOR
# enemy Grichuk not in batting list
# row[3]: TOR
# enemy Tellez not in batting list
# row[3]: TOR
# enemy Diaz not in batting list
# row[3]: TOR
# enemy McGuire not in batting list
# row[3]: TOR
# enemy Urena not in batting list
# row[3]: TOR
# enemy Berti not in batting list
# could not append
# 158
# Maldonado not in batting list
# row[3]: BAL
# enemy Mullins not in batting list
# row[3]: BAL
# enemy Villar not in batting list
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Stewart not in batting list
# row[3]: BAL
# row[3]: BAL
# enemy Wilkerson not in batting list
# row[3]: BAL
# enemy Peterson not in batting list
# row[3]: BAL
# enemy Wynns not in batting list
# could not append
# 159
# Maldonado not in batting list
# row[3]: BAL
# enemy Mullins not in batting list
# row[3]: BAL
# enemy Villar not in batting list
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Beckham not in batting list
# row[3]: BAL
# enemy Nunez not in batting list
# row[3]: BAL
# enemy Stewart not in batting list
# row[3]: BAL
# row[3]: BAL
# could not append
# 160
# Maldonado not in batting list
# row[3]: BAL
# enemy Mullins not in batting list
# row[3]: BAL
# enemy Villar not in batting list
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Beckham not in batting list
# row[3]: BAL
# enemy Nunez not in batting list
# row[3]: BAL
# enemy Stewart not in batting list
# row[3]: BAL
# row[3]: BAL
# could not append
# 161
# row[3]: BAL
# enemy Mullins not in batting list
# row[3]: BAL
# enemy Villar not in batting list
# row[3]: BAL
# row[3]: BAL
# row[3]: BAL
# enemy Beckham not in batting list
# row[3]: BAL
# enemy Nunez not in batting list
# row[3]: BAL
# enemy Stewart not in batting list
# row[3]: BAL
# enemy Wilkerson not in batting list
# row[3]: BAL
# could not append
#    index  Season             Name    Team   Age      G     AB     PA      H  \
# 0     79  2017.0  George Springer  Astros  27.0  140.0  548.0  629.0  155.0
# 1     79  2017.0  George Springer  Astros  27.0  140.0  548.0  629.0  155.0
# 2     79  2017.0  George Springer  Astros  27.0  140.0  548.0  629.0  155.0
#
#      1B  ...  wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  \
# 0  92.0  ...       -0.41       -5.21          0.346          0.608
# 1  92.0  ...       -0.41       -5.21          0.346          0.608
# 2  92.0  ...        0.33         NaN          0.274          0.628
#
#    Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  \
# 0        0.461            0.509            0.752          0.650       0.440
# 1        0.461            0.509            0.752          0.650       0.440
# 2        0.434            0.560            0.781          0.704       0.451
#
#    Pace (pi)
# 0       22.3
# 1       22.3
# 2       26.1
#
# [3 rows x 5184 columns]

# %%
all_data_2017 = batting_stats(2017)

# %%
team = get_key_from_dict(team_dict, "San Diego")
print(team)
teams = set(all_data_2017["Team"])
teams
# Out:
# None
# {'- - -',
#  'Angels',
#  'Astros',
#  'Athletics',
#  'Blue Jays',
#  'Braves',
#  'Brewers',
#  'Cardinals',
#  'Cubs',
#  'Diamondbacks',
#  'Dodgers',
#  'Giants',
#  'Indians',
#  'Mariners',
#  'Marlins',
#  'Mets',
#  'Nationals',
#  'Orioles',
#  'Padres',
#  'Phillies',
#  'Pirates',
#  'Rangers',
#  'Rays',
#  'Red Sox',
#  'Reds',
#  'Rockies',
#  'Royals',
#  'Tigers',
#  'Twins',
#  'White Sox',
#  'Yankees'}

# %%
def create_trining_df(year = (dt.datetime.today().year-1), team = "HOU" ):
                       
    
    players_df = get_players_per_game(year, team)
    #print(players_df.tail(10))    
    stats_players_start_lineup = get_stats_startingplayer_by_game(players_df, team, year)
    
    return pd.concat([players_df.iloc[:,[0,1,2,3,4,5]],stats_players_start_lineup], axis=1, join='inner')
       
    
    
    
    #dates_played = get_dates_played(last_season_games_played, year)

# %%
stats_players_start_lineup = create_trining_df()
stats_players_start_lineup
# Out:
# opp: KCR
# opp: DET
# opp: TBR
# opp: BOS
# opp: OAK
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1130-7e2134587ee0> in <module>
# ----> 1 stats_players_start_lineup = create_trining_df()
#       2 stats_players_start_lineup
#
# <ipython-input-1129-bfce6d57461e> in create_trining_df(year, team)
#       2
#       3
# ----> 4     players_df = get_players_per_game(year, team)
#       5     #print(players_df.tail(10))
#       6     stats_players_start_lineup = get_stats_startingplayer_by_game(players_df, team, year)
#
# <ipython-input-1107-4a8b6abd064e> in get_players_per_game(year, team)
#      16         opp_all_lineups_season = pd.read_csv(opp_lineups_path)
#      17         print(f"opp: {opponent}")
# ---> 18         opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
#      19         opponents_lineups.update({opponent:opp_all_lineups_season})
#      20
#
# <ipython-input-1100-d8e44ff5051e> in format_lineups_df(df, year)
#       2 def format_lineups_df(df, year):
#       3     df  =  modify_date_col_from_lineups(df, year)
# ----> 4     df = clean_lineups(df)
#       5     df.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
#       6     df.set_index("index", inplace=True, drop=True)
#
# <ipython-input-1099-498ed8a1c3af> in clean_lineups(df)
#       5             name = original_name.split("-")
#       6             name = name[0]
# ----> 7             df.replace(original_name,name, inplace=True)
#       8             #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
#       9             #has the same names over and over. We just need to grab all the different names and replace them
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4040                                               value=value, inplace=inplace,
#    4041                                               limit=limit, regex=regex,
# -> 4042                                               method=method)
#    4043
#    4044     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6577                     new_data = self._data.replace(to_replace=to_replace,
#    6578                                                   value=value, inplace=inplace,
# -> 6579                                                   regex=regex)
#    6580                 else:
#    6581                     msg = ('Invalid "to_replace" type: '
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace(self, **kwargs)
#     535
#     536     def replace(self, **kwargs):
# --> 537         return self.apply('replace', **kwargs)
#     538
#     539     def replace_list(self, src_list, dest_list, inplace=False, regex=False):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#    2761                                                     inplace=inplace,
#    2762                                                     filter=filter, regex=regex,
# -> 2763                                                     convert=convert)
#    2764         elif both_lists:
#    2765             for to_rep, v in zip(to_replace, value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     777             if convert:
#     778                 blocks = [b.convert(by_item=True, numeric=False,
# --> 779                                     copy=not inplace) for b in blocks]
#     780             return blocks
#     781         except (TypeError, ValueError):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#     777             if convert:
#     778                 blocks = [b.convert(by_item=True, numeric=False,
# --> 779                                     copy=not inplace) for b in blocks]
#     780             return blocks
#     781         except (TypeError, ValueError):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in convert(self, *args, **kwargs)
#    2679
#    2680         if by_item and not self._is_single_block:
# -> 2681             blocks = self.split_and_operate(None, f, False)
#    2682         else:
#    2683             values = f(None, self.values.ravel(), None)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace)
#     466             # need a new block
#     467             if m.any():
# --> 468                 nv = f(m, v, i)
#     469             else:
#     470                 nv = v if inplace else v.copy()
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in f(m, v, i)
#    2669         def f(m, v, i):
#    2670             shape = v.shape
# -> 2671             values = fn(v.ravel(), **fn_kwargs)
#    2672             try:
#    2673                 values = values.reshape(shape)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/dtypes/cast.py in soft_convert_objects(values, datetime, numeric, timedelta, coerce, copy)
#     809         try:
#     810             values = lib.maybe_convert_objects(values,
# --> 811                                                convert_datetime=datetime)
#     812         except OutOfBoundsDatetime:
#     813             pass
#
# KeyboardInterrupt:

# %%
stats_players_start_lineup.head()

# %%
names = stats_players_start_lineup.loc[:]["Name"].isna()

# %%
names.isnull().values.any()
