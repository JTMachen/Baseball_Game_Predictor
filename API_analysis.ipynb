# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-dd3467ef4cc1> in <module>
#       5 from datetime import datetime, timedelta
#       6 from sklearn.preprocessing import LabelEncoder, StandardScaler
# ----> 7 from pybaseball import batting_stats
#       8 from pybaseball import batting_stats_range
#       9 from pybaseball import pitching_stats_range
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# /anaconda3/lib/python3.7/site-packages/pybaseball-1.0.8-py3.7.egg/pybaseball/__init__.py in <module>
#       5 from .statcast_pitcher import statcast_pitcher
#       6 from .statcast_batter import statcast_batter
# ----> 7 from .league_batting_stats import batting_stats_bref
#       8 from .league_batting_stats import batting_stats_range
#       9 from .league_batting_stats import bwar_bat
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_backward_compatible(spec)
#
# /anaconda3/lib/python3.7/site-packages/pybaseball-1.0.8-py3.7.egg/pybaseball/league_batting_stats.py in <module>
#       3 import datetime
#       4 import io
# ----> 5 from bs4 import BeautifulSoup
#       6
#       7
#
# /anaconda3/lib/python3.7/site-packages/bs4/__init__.py in <module>
#      32 import warnings
#      33
# ---> 34 from .builder import builder_registry, ParserRejectedMarkup
#      35 from .dammit import UnicodeDammit
#      36 from .element import (
#
# /anaconda3/lib/python3.7/site-packages/bs4/builder/__init__.py in <module>
#     333 register_treebuilders_from(_htmlparser)
#     334 try:
# --> 335     from . import _html5lib
#     336     register_treebuilders_from(_html5lib)
#     337 except ImportError:
#
# /anaconda3/lib/python3.7/site-packages/bs4/builder/_html5lib.py in <module>
#      18     nonwhitespace_re,
#      19 )
# ---> 20 import html5lib
#      21 from html5lib.constants import (
#      22     namespaces,
#
# /anaconda3/lib/python3.7/site-packages/html5lib/__init__.py in <module>
#      23 from __future__ import absolute_import, division, unicode_literals
#      24
# ---> 25 from .html5parser import HTMLParser, parse, parseFragment
#      26 from .treebuilders import getTreeBuilder
#      27 from .treewalkers import getTreeWalker
#
# /anaconda3/lib/python3.7/site-packages/html5lib/html5parser.py in <module>
#       6
#       7 from . import _inputstream
# ----> 8 from . import _tokenizer
#       9
#      10 from . import treebuilders
#
# /anaconda3/lib/python3.7/site-packages/html5lib/_tokenizer.py in <module>
#      14 from ._inputstream import HTMLInputStream
#      15
# ---> 16 from ._trie import Trie
#      17
#      18 entitiesTrie = Trie(entities)
#
# /anaconda3/lib/python3.7/site-packages/html5lib/_trie/__init__.py in <module>
#       1 from __future__ import absolute_import, division, unicode_literals
#       2
# ----> 3 from .py import Trie as PyTrie
#       4
#       5 Trie = PyTrie
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _find_and_load_unlocked(name, import_)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap.py in _load_unlocked(spec)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap_external.py in exec_module(self, module)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap_external.py in get_code(self, fullname)
#
# /anaconda3/lib/python3.7/importlib/_bootstrap_external.py in _compile_bytecode(data, name, bytecode_path, source_path)
#
# KeyboardInterrupt:

# %% [markdown]
# ### Analysing *batting_stats()* with different paramters

# %%
all_data_2019 = batting_stats(2019)

# %%
all_data_2019 = batting_stats(2019)
players_with_more_than_50 = batting_stats(2019, qual=50)
all_data_since_2015 = batting_stats(2015, 2019)
aggregated_data = batting_stats(2010, 2016, ind=0)

print(all_data_2019.head())
print(players_with_more_than_50.head())
print(all_data_since_2015.head())
print(aggregated_data.head())

# %% [markdown]
# # Conclusion for batting_stats()
# Very versitile function that can take one or two years as parameters (single season or multiple seasons). It would return a dataframe with 287 columns with all the batting statistics for every single player for the whole season/seasons. A lot of statistics!
#
# ### Analysing *schedule_and_record()*

# %%
from pybaseball import schedule_and_record

Astros_record = schedule_and_record(2019, "HOU")
Astros_record.head(20)

# %%
Astros_record.columns

# %% [markdown]
# ### Conclusion for schedule_and_record()
# Very useful function that can get the players who played in each game, and also all the dates in which each a team played in a season, among others. It only has 19 columns, but this will be used as a *link* table between the others.
#
# ## Analysing *batting_stats_range()*

# %%
data_range = batting_stats_range("2019-09-01","2019-09-30")
data_range

# %%
print(data_range.columns)
print(all_data_2019.columns)

# %% [markdown]
# ### Conclusion for *batting_stats_range()*
#
# this functions returns a much smaller dataframe with only 27 columns. This will be useful to get the most recent information for each player right before each game.
#
# # Let's look at all the columns for batting_stats() and batting_stats_range()

# %%
print(all_data_2019.columns[:95])

# %%
print(all_data_2019.columns[95:190])

# %%
print(all_data_2019.columns[190:])

# %%
len(all_data_2019.columns)

# %%
len(data_range.columns)

# %% [markdown]
# ### Let's see what columns in the smaller dataframe are also in the larger df

# %%
shared_columns = list(data_range.columns & all_data_2019.columns)

# %%
shared_columns

# %%
len(shared_columns)

# %% [markdown]
# ### basically all of them. Only 4 are not included. Let's see which one are not in the larger df.

# %%
range_columns_not_in_all_data = list(data_range.columns.difference(all_data_2019.columns))
range_columns_not_in_all_data

# %% [markdown]
# # So #days is a useless column, BA is the same as AVG, Lev is useless too, and Tm is the same as Team. As a conclusion, all the columns are included.

# %%
Astros_2019stats  =  all_data_2019[all_data_2019["Team"]=="Astros"]

# %%
Astros_2019stats.count()

# %%
#Thursday, Mar 28
#"2019-03-28"
game_march_28_2019 = batting_stats_range("2019-03-28",)

# %%
game_march_28_2019["Tm"].unique

# %%
game_march_28_2019[game_march_28_2019["Tm"]=="Houston"]

# %% [markdown]
# ## ...We can see who played in every game ^

# %%
game_march_28_2019.columns

# %%
game_march_28_2019.iloc[:,6]

# %% [markdown]
# ### *"@"* means they're playing as *visitors*.

# %% [markdown]
# # Startegy:
# ### General Strategy:
# Retrieve data for each player in each game played. Feed the model with data from past year for each player and past month. Build a dataframe where each row represents the features to train the model and to make predictions out of the model.
#
# Each row would have the full 283 features from past season plus the 23 from past month for each player that played the particular game plus 2 team features.
#
# ### Specific Tasks
#
# Usually there are 9 players, so there would be 9 times 283 features only to account for past season statistics of 1 team. So this number would be later mulitply also by 2 since each game involves 2 teams. We will use **schedule_and_record()** function to get the players who played in a game, so we can later use **batting_stats()** function to get those 283 features from last season for each player that played a particular game.
#
# There will be also recent statistics from last month for each player as well, which is 22 features. Again this number would be multiply by 9 and then by 2. We will use **schedule_and_record()** function to get the players who played in that game, so we can later retrieve the past month statistics for each one of those players from **batting_stats_range()**.
#
# There will be also statistics from the team to be included in each record such as streak, and GB, also gotten from **schedule_and_record()**.
#
# ### Conclusion
# The training DataFrame will contain a record for each game of a single team and its opponent. This leads us to  **DataFrame with dimensions of 5494 columns by *Games-Played-By-The-Team* rows**. This is only batting statistics so far.

# %% [markdown]
# ## Analysing *pitching_stats()*

# %%
from pybaseball import pitching_stats

pitching_stats_2019 = pitching_stats("2019")
pitching_stats_2019.head(15)

# %%
pitching_stats_2019.columns

# %%
pitching_stats_2019.columns[:100]

# %%
pitching_stats_2019.columns[100:200]

# %%
pitching_stats_2019.columns[200:]

# %% [markdown]
# ### Aparanetly, we should use only the *(pi)* variables. They are calculated using a new algorythm that eliminates what Brooks Baseball considers errors from Pitch FX (pfx).
#
# link: https://www.reddit.com/r/Sabermetrics/comments/6qepoa/what_is_the_data_source_for_nonattributed_plate/

# %%
pfx_col = [x for x in pitching_stats_2019.columns if "(pfx)" in x ]
pfx_col

# %%
pitching_stats_2019.drop( columns = pfx_col, inplace=True )
pitching_stats_2019.columns

# %%
from pybaseball import pitching_stats_range

pitching_range_1day = pitching_stats_range("2019-03-28",)

# %%
pitching_range_1day.head()

# %%
pitchers_Astros_on_20190328 = pitching_range_1day[pitching_range_1day.Tm == "Houston"]
pitchers_Astros_on_20190328

# %% [markdown]
# ## So! we can know who pitched on a certain game ^

# %%
pitchers_Astros_on_20190328.columns

# %% [markdown]
# #### An idea is to keep columns that represent % of other columns. For example, keeping IFFB% but droping IFFB, since a percentage tells more of a story that an isolated scalar value. In this way, we can reduce redundancy in our features and, therefore, the total size of our features array.

# %%
bat_col_not_to_drop = [x for x in all_data_2019.columns if "%" in x and x[:-1] in all_data_2019.columns]
bat_col_not_to_drop

# %%
bat_col_to_drop = [x[:-1] for x in bat_col_not_to_drop]
bat_col_to_drop

# %%
pitch_col_not_to_drop = [x for x in pitching_stats_2019.columns if "%" in x and x[:-1] in pitching_stats_2019.columns]
pitch_col_not_to_drop

# %%
pitch_col_to_drop = [x[:-1] for x in pitch_col_not_to_drop]
pitch_col_to_drop

# %%
all_data_2019.drop(columns=bat_col_to_drop, inplace=True)
pitching_stats_2019.drop(columns=pitch_col_to_drop, inplace=True)
print(f"Total columns in bat_statistics: {len(all_data_2019.columns)}\nTotal columns in pitch_statistics: {len(pitching_stats_2019.columns)} ")

# %% [markdown]
# ### ...We still have loooots of columns.
#
#
# ##### We will have to get rid of some columns manually that we consider unnecesary such as "Age" or "Team", etc. However, some of these columns might be useful during concatenation, so we will handle this in within the function that creates the dataframe.
#
# ## Let's explore how many pitcher there are per game usually

# %%
# let's grab our datframe created through record_and_schedule() previously for The Astros season 2019:
Astros_record.head()

# %% [markdown]
# ### We will have to convert the date format cuz these guys are assholes

# %%
date = Astros_record.Date[1]
#date = date.split(",")
date = re.findall(r"\w* [0-9][0-9]|[0-9]", date)
date = date[0]
print(date)
year = "2019"
date = year + " " + date
date

# %%
import datetime as dt

# %%
date_formatted = dt.datetime.strptime(date,"%Y %b %d")
date_formatted

# %%
date_formatted.month

# %% [markdown]
# ### it worked out, so now we know how

# %%
type(date_formatted)

# %% [markdown]
# # %%%%%%%    Building the Training DataFrame    %%%%%%%%

# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report
from pybaseball import schedule_and_record
import re
from pybaseball import pitching_stats
import datetime as dt

# %%
team_dict = {'Angels':'LAA',
            'Athletics': 'OAK',
            'Astros': 'HOU',
            'Braves': 'ATL',
            'Brewers': 'MIL',
            'Cards': 'STL',
            'Cubs': 'CUB',
            'Diamondbacks': 'ARI',
            'Dodgers': 'LAD',
            'Giants': 'SFG',
            'Indians': 'CLE',
            'Blue Jays': 'TOR',
            'Mariners': 'SEA',
            'Marlins': 'MIA',
            'Mets': 'NYM',
            'Nats': 'WAS',
            'Orioles': 'BAL',
            'Padres': 'SDP',
            'Phillies': 'PHI',
            'Pirates': 'PIT',
            'Rangers': 'TEX',
            'Rays': 'TBR',
            'Red Sox': 'BOS',
            'Reds': 'CIN',
            'Rockies': 'COL',
            'Royals': 'KCR',
            'Tigers': 'DET',
            'Twins': 'MIN',
            'White_Sox': 'CHW',
            'Yankees': 'NYY'
             
           }
def get_key_from_dict(dictionary, val): 
    for key, value in dictionary.items(): 
         if val == value: 
            return key

# %%
"""
Not necesary anymore.
"""
def switch_key_val_dict(dictionary): 
    new_dict = {}
    
    for key, value in dictionary.items():
        new_dict.update({value:key})
    
    return new_dict

# %%
acr_team_dict = {}
acr_team_dict.update({'CHC':'CUB'})
acr_team_dict.update({'LAD':'LOS'})
acr_team_dict.update({'SFG':'SFO'})
acr_team_dict.update({'SDP':'SDG'})
acr_team_dict.update({'TBR':'TAM'} )
acr_team_dict.update({'KCR':'KAN'})
acr_team_dict.update({'CHW':'CWS'})
print(acr_team_dict.keys())
# Out:
# dict_keys(['CHC', 'LAD', 'SFG', 'SDP', 'TBR', 'KCR', 'CHW'])

# %%
def format_dates_to_dt(un_date="Monday, Dec 31", year=1999):
    date = re.findall(r"\W\w\w\w\s\d+", un_date)
    date = date[0]
    date = str(year) + date
    date_formatted = dt.datetime.strptime(date,"%Y %b %d")
    return date_formatted

# %%
def modify_dates_from_lineups(date="1. Thu,3/29 at TEX W (4-1)#", year = 2018):
    date = re.findall(r"\d+/\d+", date)
    try: date = date[0]
    except: return
    date = str(year) +" " + date
    return date

# %%
def modify_date_col_from_lineups(df, year):
    df["0"] = df.apply(lambda x: modify_dates_from_lineups(x["0"],year), axis=1)
    df["0"] = pd.to_datetime(df["0"])
    return df

# %%
def clean_lineups(df):
    for row in range(0,len(df)):
        for column in range(2,11):
            original_name = df.iloc[row,column]
            name = original_name.split("-")
            name = name[0]
            df.replace(original_name,name, inplace=True)
            #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
            #has the same names over and over. We just need to grab all the different names and replace them
    return df

# %%
def format_lineups_df(df, year):
    df  =  modify_date_col_from_lineups(df, year)
    df = clean_lineups(df)
    df.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
    df.set_index("index", inplace=True, drop=True)
    return df

# %%
def get_dates_played(df=None,year=None):
    
    dates_played = [format_dates_to_dt(date, year) for date in df.Date]
    return dates_played

# %%
def get_team_schedule(year=None, team = "HOU"):
    
    teams_df  = schedule_and_record(year, team)
    teams_df  = teams_df.iloc[ : , [0,1,2,3,4,10,17] ]
    teams_df["Date"] = teams_df.apply(lambda x: format_dates_to_dt(x["Date"],year), axis=1)
    teams_df.replace("@",1, inplace=True)
    teams_df.replace("Home",0, inplace=True)
    return teams_df

# %%
def get_players_per_game(year = None, team = None):
    
    schedule_df = get_team_schedule(year, team)
    opponents = set(schedule_df["Opp"])
    
    bat_stat_path = Path(f"Data/Batting/Clean_Data/clean_batting_data_{year}.csv")
    all_bat_stats = pd.read_csv(bat_stat_path)
    
    pitchers_path = Path(f"Starting_Pitchers/Starting_Pitchers_{year}.csv")
    starting_pitchers = pd.read_csv(pitchers_path)
    #print(f"head of PITCHER STATS: \n{starting_pitchers.head()}")
    
    lineups_path = Path(f"Lineups/{team}_lineups_{year}.csv")
    all_lineups_season = pd.read_csv(lineups_path)
    all_lineups_season = format_lineups_df(all_lineups_season, year)
    
    opponents_lineups = {}
    for opponent in opponents:
        opp_lineups_path = Path(f"Lineups/{opponent}_lineups_{year}.csv")
        opp_all_lineups_season = pd.read_csv(opp_lineups_path)
        #print(f"opp: {opponent}")
        opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
        opponents_lineups.update({opponent:opp_all_lineups_season})
    
    players_df = pd.DataFrame()
    
    i = 0
    for date in schedule_df["Date"]:
        
        
        adversary = schedule_df[schedule_df["Date"]==date.strftime("%Y-%m-%d")]["Opp"].values[0]
        
        temp_dict = {"Date":date}

        ##Line ups for the team
        try: all_players_on_date = all_lineups_season[all_lineups_season["Date"]==date.strftime("%Y-%m-%d")]
            
        except:
            print(f"No game on this date {date} for team")
            continue
            
        count = 1  
        all_players_team = all_players_on_date.iloc[0]       
        for player in all_players_team[1:]:            
            temp_dict.update({f"player_{count:02}" : player})           
            count+=1
        
        ##Line ups for the adversary
        try:
            opp_lineups_df = opponents_lineups[adversary]
            all_opponents_on_date = opp_lineups_df[opp_lineups_df["Date"]==date.strftime("%Y-%m-%d")]
            all_opponents_on_date.columns = ["Date","10","11","12","12","14","15","16","17","18"]
        except:
            print(f"No game on this date {date} for opponent")
            continue

        count = 10  
        all_players_opp = all_opponents_on_date.iloc[0]       
        for enemy in all_players_opp[1:]:            
            temp_dict.update({f"player_{count:02}" : enemy})           
            count+=1
         
        pitcher_on_date = starting_pitchers[starting_pitchers["Date"]==date.strftime("%Y-%m-%d")]
        #print(f"PITCHERS ON DATE: \n{pitcher_on_date}")     
        
        try:
            team_pitcher = pitcher_on_date[pitcher_on_date["Team"]==team]["PITCHER"].values[0]
            #print(f"TEAM PITCHER: \n{team_pitcher}")   
            temp_dict.update({"pitcher_team": team_pitcher })
        except:
            #print(f"No pitcher found for {adversary} on {date}")
            opponent_pitcher = "Unknown"
        
        if adversary in acr_team_dict.keys(): 
            print("Adversary in list of conflicting acronyms")
            print(f"\n acronym received {adversary}")
            adversary = acr_team_dict[adversary]
            print(f"\n acronym after process {adversary}")
        print(f"adversary: {adversary}\n")
        
        try:
            opponent_pitcher = pitcher_on_date[pitcher_on_date["Team"]==adversary]["PITCHER"].values[0] 
            print(f"OPPONENT PITCHER: \n{opponent_pitcher}") 
            temp_dict.update({"pitcher_opp": opponent_pitcher})
        except:
            print(f"No pitcher found for {adversary} on {date}")
            opponent_pitcher = "Unknown"
        
        temp_df = pd.DataFrame(temp_dict, index =[i])
        players_df = pd.concat([players_df,temp_df], axis=0, sort = True )
        i+=1
        
    schedule_df.set_index("Date", inplace=True)
    players_df.set_index("Date", inplace=True)
    teams_df = pd.concat([schedule_df,players_df], axis=1, join="inner")
    teams_df.reset_index(inplace=True, drop=False)
    
    return teams_df

# %%
players_per_game_for_HOU_2019 = get_players_per_game(year = 2019, team = "HOU")
# Out:
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Snell
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Morton
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Glasnow
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Chirinos
# adversary: TEX
#
# OPPONENT PITCHER:
# Smyly
# adversary: TEX
#
# OPPONENT PITCHER:
# Miller
# adversary: TEX
#
# OPPONENT PITCHER:
# Minor
# adversary: OAK
#
# OPPONENT PITCHER:
# Montas
# adversary: OAK
#
# OPPONENT PITCHER:
# Brooks
# adversary: OAK
#
# OPPONENT PITCHER:
# Fiers
# adversary: NYY
#
# OPPONENT PITCHER:
# Tanaka
# adversary: NYY
#
# OPPONENT PITCHER:
# Loaisiga
# adversary: NYY
#
# OPPONENT PITCHER:
# Paxton
# adversary: SEA
#
# OPPONENT PITCHER:
# Leblanc
# adversary: SEA
#
# OPPONENT PITCHER:
# Hernandez
# adversary: SEA
#
# OPPONENT PITCHER:
# Gonzales
# adversary: OAK
#
# OPPONENT PITCHER:
# Estrada
# adversary: OAK
#
# OPPONENT PITCHER:
# Montas
# adversary: TEX
#
# OPPONENT PITCHER:
# Smyly
# adversary: TEX
#
# OPPONENT PITCHER:
# Sampson
# adversary: TEX
#
# OPPONENT PITCHER:
# Miller
# adversary: MIN
#
# OPPONENT PITCHER:
# Odorizzi
# adversary: MIN
#
# OPPONENT PITCHER:
# Pineda
# adversary: MIN
#
# OPPONENT PITCHER:
# Stewart
# adversary: CLE
#
# OPPONENT PITCHER:
# Bauer
# adversary: CLE
#
# OPPONENT PITCHER:
# Kluber
# adversary: CLE
#
# OPPONENT PITCHER:
# Bieber
# adversary: CLE
#
# OPPONENT PITCHER:
# Carrasco
# adversary: MIN
#
# OPPONENT PITCHER:
# Odorizzi
# adversary: MIN
#
# OPPONENT PITCHER:
# Pineda
# adversary: MIN
#
# OPPONENT PITCHER:
# Perez
# adversary: MIN
#
# OPPONENT PITCHER:
# Berrios
# adversary: LAA
#
# OPPONENT PITCHER:
# Cahill
# adversary: LAA
#
# OPPONENT PITCHER:
# Harvey
# Adversary in list of conflicting acronyms
#
#  acronym received KCR
#
#  acronym after process KAN
# adversary: KAN
#
# OPPONENT PITCHER:
# Junis
# Adversary in list of conflicting acronyms
#
#  acronym received KCR
#
#  acronym after process KAN
# adversary: KAN
#
# OPPONENT PITCHER:
# Duffy
# Adversary in list of conflicting acronyms
#
#  acronym received KCR
#
#  acronym after process KAN
# adversary: KAN
#
# OPPONENT PITCHER:
# Lopez
# adversary: TEX
#
# OPPONENT PITCHER:
# Minor
# adversary: TEX
#
# OPPONENT PITCHER:
# Lynn
# adversary: TEX
#
# OPPONENT PITCHER:
# Chavez
# adversary: TEX
#
# OPPONENT PITCHER:
# Sampson
# adversary: DET
#
# OPPONENT PITCHER:
# Boyd
# adversary: DET
#
# OPPONENT PITCHER:
# Carpenter
# adversary: DET
#
# OPPONENT PITCHER:
# Soto
# adversary: BOS
#
# OPPONENT PITCHER:
# Porcello
# adversary: BOS
#
# OPPONENT PITCHER:
# Velazquez
# adversary: BOS
#
# OPPONENT PITCHER:
# Sale
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Burr
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Covey
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Nova
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Giolito
# adversary: BOS
#
# OPPONENT PITCHER:
# Sale
# adversary: BOS
#
# OPPONENT PITCHER:
# Price
# adversary: BOS
#
# OPPONENT PITCHER:
# Rodriguez
# Adversary in list of conflicting acronyms
#
#  acronym received CHC
#
#  acronym after process CUB
# adversary: CUB
#
# OPPONENT PITCHER:
# Hamels
# Adversary in list of conflicting acronyms
#
#  acronym received CHC
#
#  acronym after process CUB
# adversary: CUB
#
# OPPONENT PITCHER:
# Lester
# Adversary in list of conflicting acronyms
#
#  acronym received CHC
#
#  acronym after process CUB
# adversary: CUB
#
# OPPONENT PITCHER:
# Hendricks
# adversary: OAK
#
# OPPONENT PITCHER:
# Fiers
# adversary: OAK
#
# OPPONENT PITCHER:
# Anderson
# adversary: OAK
#
# OPPONENT PITCHER:
# Bassitt
# adversary: SEA
#
# OPPONENT PITCHER:
# Gearrin
# adversary: SEA
#
# OPPONENT PITCHER:
# Moore
# adversary: SEA
#
# OPPONENT PITCHER:
# Leake
# adversary: SEA
#
# OPPONENT PITCHER:
# Adams
# adversary: BAL
#
# OPPONENT PITCHER:
# Ynoa
# adversary: BAL
#
# OPPONENT PITCHER:
# Cashner
# adversary: BAL
#
# OPPONENT PITCHER:
# Bundy
# adversary: MIL
#
# OPPONENT PITCHER:
# Peralta
# adversary: MIL
#
# OPPONENT PITCHER:
# Woodruff
# adversary: TOR
#
# OPPONENT PITCHER:
# Sanchez
# adversary: TOR
#
# OPPONENT PITCHER:
# Richard
# adversary: TOR
#
# OPPONENT PITCHER:
# Thornton
# adversary: CIN
#
# OPPONENT PITCHER:
# Castillo
# adversary: CIN
#
# OPPONENT PITCHER:
# Desclafani
# adversary: CIN
#
# OPPONENT PITCHER:
# Mahle
# adversary: NYY
#
# OPPONENT PITCHER:
# Green
# adversary: NYY
#
# OPPONENT PITCHER:
# Paxton
# adversary: NYY
#
# OPPONENT PITCHER:
# Tanaka
# adversary: NYY
#
# OPPONENT PITCHER:
# Happ
# adversary: PIT
#
# OPPONENT PITCHER:
# Williams
# adversary: PIT
#
# OPPONENT PITCHER:
# Agrazal
# adversary: PIT
#
# OPPONENT PITCHER:
# Musgrove
# adversary: SEA
#
# OPPONENT PITCHER:
# Carasiti
# adversary: SEA
#
# OPPONENT PITCHER:
# Kikuchi
# adversary: SEA
#
# OPPONENT PITCHER:
# Gonzales
# adversary: COL
#
# OPPONENT PITCHER:
# Marquez
# adversary: COL
#
# OPPONENT PITCHER:
# Lambert
# adversary: LAA
#
# OPPONENT PITCHER:
# Ramirez
# adversary: LAA
#
# OPPONENT PITCHER:
# Heaney
# adversary: LAA
#
# OPPONENT PITCHER:
# Suarez
# adversary: TEX
#
# OPPONENT PITCHER:
# Lynn
# adversary: TEX
#
# OPPONENT PITCHER:
# Chavez
# adversary: TEX
#
# OPPONENT PITCHER:
# Minor
# adversary: TEX
#
# OPPONENT PITCHER:
# Jurado
# adversary: LAA
#
# OPPONENT PITCHER:
# Canning
# adversary: LAA
#
# OPPONENT PITCHER:
# Heaney
# adversary: LAA
#
# OPPONENT PITCHER:
# Pena
# adversary: LAA
#
# OPPONENT PITCHER:
# Harvey
# adversary: TEX
#
# OPPONENT PITCHER:
# Minor
# adversary: TEX
#
# OPPONENT PITCHER:
# Jurado
# adversary: TEX
#
# OPPONENT PITCHER:
# Lynn
# adversary: OAK
#
# OPPONENT PITCHER:
# Minor
# adversary: OAK
#
# OPPONENT PITCHER:
# Fiers
# adversary: OAK
#
# OPPONENT PITCHER:
# Bassitt
# adversary: STL
#
# OPPONENT PITCHER:
# Flaherty
# adversary: STL
#
# OPPONENT PITCHER:
# Poncedeleon
# adversary: STL
#
# OPPONENT PITCHER:
# Hudson
# adversary: CLE
#
# OPPONENT PITCHER:
# Bieber
# adversary: CLE
#
# OPPONENT PITCHER:
# Plesac
# adversary: CLE
#
# OPPONENT PITCHER:
# Salazar
# adversary: SEA
#
# OPPONENT PITCHER:
# Kikuchi
# adversary: SEA
#
# OPPONENT PITCHER:
# Gonzales
# adversary: SEA
#
# OPPONENT PITCHER:
# Ndecid
# adversary: COL
#
# OPPONENT PITCHER:
# Marquez
# adversary: COL
#
# OPPONENT PITCHER:
# Lambert
# adversary: BAL
#
# OPPONENT PITCHER:
# Bundy
# adversary: BAL
#
# OPPONENT PITCHER:
# Brooks
# adversary: BAL
#
# OPPONENT PITCHER:
# Wojciechowski
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Nova
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Nova
# Adversary in list of conflicting acronyms
#
#  acronym received CHW
#
#  acronym after process CWS
# adversary: CWS
#
# OPPONENT PITCHER:
# Detwiler
# adversary: OAK
#
# OPPONENT PITCHER:
# Fiers
# adversary: OAK
#
# OPPONENT PITCHER:
# Roark
# adversary: OAK
#
# OPPONENT PITCHER:
# Bassitt
# adversary: OAK
#
# OPPONENT PITCHER:
# Anderson
# adversary: DET
#
# OPPONENT PITCHER:
# Jackson
# adversary: DET
#
# OPPONENT PITCHER:
# Turnbull
# adversary: DET
#
# OPPONENT PITCHER:
# Norris
# adversary: DET
#
# OPPONENT PITCHER:
# Zimmermann
# adversary: LAA
#
# OPPONENT PITCHER:
# Suarez
# adversary: LAA
#
# OPPONENT PITCHER:
# Peters
# adversary: LAA
#
# OPPONENT PITCHER:
# Barria
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Morton
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Yarbrough
# Adversary in list of conflicting acronyms
#
#  acronym received TBR
#
#  acronym after process TAM
# adversary: TAM
#
# OPPONENT PITCHER:
# Kittredge
# adversary: TOR
#
# OPPONENT PITCHER:
# Thornton
# adversary: TOR
#
# OPPONENT PITCHER:
# Buchholz
# adversary: TOR
#
# OPPONENT PITCHER:
# Font
# adversary: MIL
#
# OPPONENT PITCHER:
# Houser
# adversary: MIL
#
# OPPONENT PITCHER:
# Lyles
# adversary: SEA
#
# OPPONENT PITCHER:
# Gonzales
# adversary: SEA
#
# OPPONENT PITCHER:
# Mcclain
# adversary: SEA
#
# OPPONENT PITCHER:
# Kikuchi
# adversary: SEA
#
# OPPONENT PITCHER:
# Hernandez
# adversary: OAK
#
# OPPONENT PITCHER:
# Fiers
# adversary: OAK
#
# OPPONENT PITCHER:
# Roark
# adversary: OAK
#
# OPPONENT PITCHER:
# Anderson
# adversary: OAK
#
# OPPONENT PITCHER:
# Bailey
# Adversary in list of conflicting acronyms
#
#  acronym received KCR
#
#  acronym after process KAN
# adversary: KAN
#
# OPPONENT PITCHER:
# Duffy
# Adversary in list of conflicting acronyms
#
#  acronym received KCR
#
#  acronym after process KAN
# adversary: KAN
#
# OPPONENT PITCHER:
# Montgomery
# Adversary in list of conflicting acronyms
#
#  acronym received KCR
#
#  acronym after process KAN
# adversary: KAN
#
# OPPONENT PITCHER:
# Junis
# adversary: TEX
#
# OPPONENT PITCHER:
# Lynn
# adversary: TEX
#
# OPPONENT PITCHER:
# Allard
# adversary: LAA
#
# OPPONENT PITCHER:
# Barria
# adversary: LAA
#
# OPPONENT PITCHER:
# Sandoval
# adversary: LAA
#
# OPPONENT PITCHER:
# Rodriguez
# adversary: SEA
#
# OPPONENT PITCHER:
# Dunn
# adversary: SEA
#
# OPPONENT PITCHER:
# Kikuchi
# adversary: LAA
#
# OPPONENT PITCHER:
# Barria
# adversary: LAA
#
# OPPONENT PITCHER:
# Sandoval
# adversary: LAA
#
# OPPONENT PITCHER:
# Suarez
# adversary: LAA
#
# OPPONENT PITCHER:
# Peters

# %%
players_per_game_for_HOU_2019.tail(20)
# Out:
#           Date   Tm  Home_Away  Opp   W/L      GB  Streak pitcher_opp  \
# 142 2019-09-07  HOU          0  SEA     W  up 9.5       3     Kikuchi
# 143 2019-09-08  HOU          0  SEA     W  up 9.5       4   Hernandez
# 144 2019-09-09  HOU          0  OAK     W  up10.5       5       Fiers
# 145 2019-09-10  HOU          0  OAK     L  up 9.5      -1       Roark
# 146 2019-09-11  HOU          0  OAK     L  up 8.5      -2    Anderson
# 147 2019-09-12  HOU          0  OAK     L  up 7.5      -3      Bailey
# 148 2019-09-13  HOU          1  KCR     W  up 7.5       1       Duffy
# 149 2019-09-14  HOU          1  KCR     W  up 7.5       2  Montgomery
# 150 2019-09-15  HOU          1  KCR     W  up 7.5       3       Junis
# 151 2019-09-17  HOU          0  TEX     W  up 8.0       4        Lynn
# 152 2019-09-18  HOU          0  TEX     W  up 8.0       5      Allard
# 153 2019-09-20  HOU          0  LAA     W  up 8.0       6      Barria
# 154 2019-09-21  HOU          0  LAA     L  up 7.0      -1    Sandoval
# 155 2019-09-22  HOU          0  LAA     W  up 8.0       1   Rodriguez
# 156 2019-09-24  HOU          1  SEA     W  up 9.0       2        Dunn
# 157 2019-09-25  HOU          1  SEA     W  up 9.0       3     Kikuchi
# 158 2019-09-26  HOU          1  LAA  L-wo  up 8.0      -1      Barria
# 159 2019-09-27  HOU          1  LAA     W  up 9.0       1    Sandoval
# 160 2019-09-28  HOU          1  LAA     W  up 9.0       2      Suarez
# 161 2019-09-29  HOU          1  LAA     W  up10.0       3      Peters
#
#     pitcher_team player_01  ...  player_09   player_10  player_11 player_12  \
# 142    Verlander    Altuve  ...    Reddick       Moore      Smith    Seager
# 143         Cole  Springer  ...  Marisnick      Gordon       Long      Nola
# 144      Greinke  Springer  ...    Reddick      Semien   Grossman   Chapman
# 145        Miley  Springer  ...    Reddick      Semien    Chapman     Olson
# 146      Urquidy  Springer  ...      Straw      Semien    Chapman     Olson
# 147    Verlander  Springer  ...    Reddick      Semien    Chapman     Olson
# 148         Cole  Springer  ...  Marisnick  Merrifield    Mondesi     Soler
# 149      Greinke  Springer  ...    Reddick  Merrifield    Mondesi     Soler
# 150        Miley    Tucker  ...  Maldonado  Merrifield    Mondesi     Soler
# 151    Verlander  Springer  ...    Reddick        Choo     Andrus   Calhoun
# 152         Cole  Springer  ...  Maldonado        Choo     Andrus   Calhoun
# 153      Greinke    Altuve  ...  Marisnick    Fletcher    Goodwin    Pujols
# 154        Miley  Springer  ...      Straw    Fletcher    Simmons    Pujols
# 155    Verlander  Springer  ...    Reddick    Fletcher    Goodwin    Pujols
# 156         Cole  Springer  ...    Reddick        Long   Crawford     Lewis
# 157      Greinke  Springer  ...  Marisnick        Long   Crawford    Seager
# 158        Miley     Straw  ...   Mayfield    Fletcher    Simmons    Pujols
# 159      Urquidy  Springer  ...   Mayfield    Fletcher  La Stella    Pujols
# 160    Verlander  Springer  ...  Marisnick    Fletcher    Goodwin    Pujols
# 161         Cole  Springer  ...      Straw   La Stella   Fletcher   Goodwin
#
#     player_13  player_14  player_15   player_16   player_17   player_18
# 142   Narvaez  Vogelbach     Murphy        Long      Fraley      Gordon
# 143    Seager    Narvaez  Vogelbach       Lopes      Bishop     Broxton
# 144     Olson      Canha      Brown       Davis      Profar     Phegley
# 145     Canha     Pinder      Davis      Profar      Murphy    Grossman
# 146     Canha      Brown      Davis    Laureano      Profar      Murphy
# 147     Canha      Brown      Davis      Profar    Grossman     Phegley
# 148    Dozier     Gordon    McBroom     O'Hearn    Starling     Viloria
# 149    Dozier     Gordon    McBroom     O'Hearn     Viloria       Lopez
# 150    Dozier    McBroom   Cuthbert    Starling        Dini       Lopez
# 151    Mazara    Santana      Solak        Odor   DeShields     Trevino
# 152   Santana      Solak       Odor      Guzman    Heineman     Trevino
# 153   Calhoun    Simmons      Walsh       Smith      Thaiss  Hermosillo
# 154   Calhoun      Smith       Ward        Bour  Hermosillo      Cowart
# 155   Calhoun    Simmons      Walsh  Hermosillo      Thaiss     Bemboom
# 156    Seager    Narvaez       Nola   Vogelbach      Gordon       Smith
# 157     Lewis    Narvaez  Vogelbach      Murphy      Gordon       Lopes
# 158   Calhoun      Smith       Ward     Goodwin      Cowart  Hermosillo
# 159   Calhoun    Simmons     Cowart      Thaiss  Hermosillo     Bemboom
# 160   Calhoun    Simmons      Smith       Walsh        Ward      Cowart
# 161    Pujols    Calhoun    Simmons        Ward      Thaiss     Bemboom
#
# [20 rows x 27 columns]

# %%
players_per_game_for_HOU_2019.columns
# Out:
# Index(['Date', 'Tm', 'Home_Away', 'Opp', 'W/L', 'GB', 'Streak', 'pitcher_opp',
#        'pitcher_team', 'player_01', 'player_02', 'player_03', 'player_04',
#        'player_05', 'player_06', 'player_07', 'player_08', 'player_09',
#        'player_10', 'player_11', 'player_12', 'player_13', 'player_14',
#        'player_15', 'player_16', 'player_17', 'player_18'],
#       dtype='object')

# %%
players_per_game_for_HOU_2019[players_per_game_for_HOU_2019["pitcher_opp"].isna()]
# Out:
# Empty DataFrame
# Columns: [Date, Tm, Home_Away, Opp, W/L, GB, Streak, pitcher_opp, pitcher_team, player_01, player_02, player_03, player_04, player_05, player_06, player_07, player_08, player_09, player_10, player_11, player_12, player_13, player_14, player_15, player_16, player_17, player_18]
# Index: []
#
# [0 rows x 27 columns]

# %%
def get_col_explanation(col1,col2):
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    try: col1 = [x.split("_")[1] for x in col1 if x is not "index"]
    except: pass
    try: col2 = [x.split("_")[1] for x in col2 if x is not "index"]
    except: pass   
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    if(len(col1)>len(col2)):missing_col = list(set(col1).difference(set(col2)))
    else:missing_col = list(set(col2).difference(set(col1)))
    return missing_col

# %%
get_col_explanation(["1_a","222_b","2_c"],["222_b","1_c"])
# Out:
# column 1: ['1_a', '222_b', '2_c']
# column2: ['222_b', '1_c']
# column 1: ['a', 'b', 'c']
# column2: ['b', 'c']
# ['a']

# %%
type(players_per_game_for_HOU_2018.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
def stats_single_game_x_team(players=None, team=None, stats_df=None, counter=1, pitching_stats = False):
    
    all_players_team_stats = pd.DataFrame()
    
    for player in players:

            if("00:00:00" in str(player)): continue #If it's a date, Skip it.
                
            try: 
                all_team_stats = stats_df[stats_df.Team==get_key_from_dict( team_dict ,team )]
                player_full_name = [x for x in all_team_stats.Name if player in x]
                player_stats = all_team_stats[all_team_stats.Name==player_full_name[0]]
              
            except: 
                print(f"{player} from {get_key_from_dict( team_dict ,team )}, {team} not in batting list")
                
                try:
                    #nanlist = np.empty((1,len(player_stats.columns)))
                    nanlist = np.empty((1,len(stats_df.columns)))
                except Exception as e:
                    print(f"Not able to get columns from last player\n{e}")
                    continue
                nanlist.fill(np.nan)
                """
                fake_columns = []
                for col in player_stats.columns:
                    try: fake_columns.append(col.split("_")[1])
                    except: fake_columns.append(col)
                """
                fake_columns = stats_df.columns
                player_stats = pd.DataFrame(data = nanlist, columns = fake_columns)
                #player_stats.drop(columns=["index"], inplace=True)
                
            new_col = []
            for col in player_stats.columns:
                new_col.append(f"{counter:02}_{col}")
            player_stats.columns = new_col
            player_stats.reset_index(inplace=True)
            all_players_team_stats = pd.concat([ all_players_team_stats, player_stats ] ,   axis=1)
            
            counter+=1
            
    return all_players_team_stats

# %%
def get_stats_startingplayer_by_game(players_df, team, year):
    
    batting_season_data = batting_stats(year-1)   
    pitching_season_data = pitching_stats(year)
    #print(pitching_season_data.head()) 
    
    stats_players_start_lineup = pd.DataFrame()
    
    for row in range(0,len(players_df)):
        
        all_players_stats = pd.DataFrame()
        
        all_players_team_stats = stats_single_game_x_team(players = players_df.iloc[row][9:18], 
                                                                  team = team, 
                                                                  stats_df = batting_season_data)
        
        all_players_opp_stats = stats_single_game_x_team(players = players_df.iloc[row][18:], 
                                                                  team = players_df.iloc[row][3], 
                                                                  stats_df = batting_season_data,
                                                                  counter = 10)           
        try:
            all_players_stats = pd.concat([ all_players_team_stats, all_players_opp_stats] ,   axis=1)    
        except Exception as e: 
            print(f"could not concatenate team with opponent stats\n{e}")
            continue
            
        try: 
            stats_players_start_lineup = stats_players_start_lineup.append(all_players_stats, ignore_index=True)
        except Exception as e: 
            print(f"could not append {e}")
            print(f"explanation: \n{get_col_explanation(stats_players_start_lineup.columns,all_players_stats.columns)}")
            
            continue
        
    
    return stats_players_start_lineup

# %%
test = get_stats_startingplayer_by_game(players_per_game_for_HOU_2019, "HOU", 2019)
test
# Out:
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Meadows from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Choi from Rays, TBR not in batting list
# Diaz from Rays, TBR not in batting list
# Zunino from Rays, TBR not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Meadows from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Choi from Rays, TBR not in batting list
# Diaz from Rays, TBR not in batting list
# Garcia from Rays, TBR not in batting list
# Zunino from Rays, TBR not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Meadows from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Choi from Rays, TBR not in batting list
# Diaz from Rays, TBR not in batting list
# Garcia from Rays, TBR not in batting list
# Diaz from Astros, HOU not in batting list
# Diaz from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Garcia from Rays, TBR not in batting list
# Meadows from Rays, TBR not in batting list
# Zunino from Rays, TBR not in batting list
# Heredia from Rays, TBR not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cabrera from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cabrera from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Cabrera from Rangers, TEX not in batting list
# Pence from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Morales from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Hundley from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Morales from Athletics, OAK not in batting list
# Hundley from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Morales from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Voit from Yankees, NYY not in batting list
# LeMahieu from Yankees, NYY not in batting list
# Urshela from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Voit from Yankees, NYY not in batting list
# LeMahieu from Yankees, NYY not in batting list
# Urshela from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Voit from Yankees, NYY not in batting list
# LeMahieu from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Encarnacion from Mariners, SEA not in batting list
# Bruce from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Bruce from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Santana from Mariners, SEA not in batting list
# Encarnacion from Mariners, SEA not in batting list
# Bruce from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Morales from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Hundley from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Forsythe from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Forsythe from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Pence from Rangers, TEX not in batting list
# Forsythe from Rangers, TEX not in batting list
# Wisdom from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cruz from Twins, MIN not in batting list
# Cron from Twins, MIN not in batting list
# Gonzalez from Twins, MIN not in batting list
# Schoop from Twins, MIN not in batting list
# Brantley from Astros, HOU not in batting list
# Cruz from Twins, MIN not in batting list
# Cron from Twins, MIN not in batting list
# Gonzalez from Twins, MIN not in batting list
# Schoop from Twins, MIN not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cruz from Twins, MIN not in batting list
# Cron from Twins, MIN not in batting list
# Gonzalez from Twins, MIN not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Martin from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Bauers from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Martin from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Bauers from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Martin from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Bauers from Indians, CLE not in batting list
# Plawecki from Indians, CLE not in batting list
# Freeman from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Martin from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Luplow from Indians, CLE not in batting list
# Bauers from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Gonzalez from Twins, MIN not in batting list
# Schoop from Twins, MIN not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cruz from Twins, MIN not in batting list
# Cron from Twins, MIN not in batting list
# Schoop from Twins, MIN not in batting list
# Diaz from Astros, HOU not in batting list
# Cruz from Twins, MIN not in batting list
# Cron from Twins, MIN not in batting list
# Gonzalez from Twins, MIN not in batting list
# Schoop from Twins, MIN not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cruz from Twins, MIN not in batting list
# Cron from Twins, MIN not in batting list
# Gonzalez from Twins, MIN not in batting list
# Schoop from Twins, MIN not in batting list
# Brantley from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Lucroy from Angels, LAA not in batting list
# Smith from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Lucroy from Angels, LAA not in batting list
# Bour from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Gutierrez from Royals, KCR not in batting list
# Maldonado from Royals, KCR not in batting list
# Hamilton from Royals, KCR not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Owings from Royals, KCR not in batting list
# Maldonado from Royals, KCR not in batting list
# Hamilton from Royals, KCR not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Owings from Royals, KCR not in batting list
# Maldonado from Royals, KCR not in batting list
# Gore from Royals, KCR not in batting list
# Hamilton from Royals, KCR not in batting list
# Chirinos from Astros, HOU not in batting list
# Pence from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Pence from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Pence from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Pence from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Forsythe from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Harrison from Tigers, DET not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Harrison from Tigers, DET not in batting list
# Beckham from Tigers, DET not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Harrison from Tigers, DET not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Chavis from Red Sox, BOS not in batting list
# Brantley from Astros, HOU not in batting list
# Chavis from Red Sox, BOS not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Chavis from Red Sox, BOS not in batting list
# Pearce from Red Sox, BOS not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Garcia from White_Sox, CHW not in batting list
# Moncada from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# Alonso from White_Sox, CHW not in batting list
# McCann from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Tilson from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Garcia from White_Sox, CHW not in batting list
# Moncada from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# Castillo from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Alonso from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Tilson from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Garcia from White_Sox, CHW not in batting list
# Moncada from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# McCann from White_Sox, CHW not in batting list
# Alonso from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Tilson from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Moncada from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# McCann from White_Sox, CHW not in batting list
# Garcia from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Alonso from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Tilson from White_Sox, CHW not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Chavis from Red Sox, BOS not in batting list
# Pearce from Red Sox, BOS not in batting list
# Diaz from Astros, HOU not in batting list
# Brantley from Astros, HOU not in batting list
# Chavis from Red Sox, BOS not in batting list
# Diaz from Astros, HOU not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Chavis from Red Sox, BOS not in batting list
# Pearce from Red Sox, BOS not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Schwarber from None, CHC not in batting list
# Baez from None, CHC not in batting list
# Rizzo from None, CHC not in batting list
# Contreras from None, CHC not in batting list
# Adduci from None, CHC not in batting list
# Almora from None, CHC not in batting list
# Descalso from None, CHC not in batting list
# Russell from None, CHC not in batting list
# Bote from None, CHC not in batting list
# Brantley from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Stubbs from Astros, HOU not in batting list
# Schwarber from None, CHC not in batting list
# Baez from None, CHC not in batting list
# Rizzo from None, CHC not in batting list
# Contreras from None, CHC not in batting list
# Almora from None, CHC not in batting list
# Heyward from None, CHC not in batting list
# Russell from None, CHC not in batting list
# Descalso from None, CHC not in batting list
# Bote from None, CHC not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Schwarber from None, CHC not in batting list
# Bryant from None, CHC not in batting list
# Rizzo from None, CHC not in batting list
# Baez from None, CHC not in batting list
# Contreras from None, CHC not in batting list
# Almora from None, CHC not in batting list
# Heyward from None, CHC not in batting list
# Russell from None, CHC not in batting list
# Bote from None, CHC not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Stubbs from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Hundley from Athletics, OAK not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Encarnacion from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Long from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Bishop from Mariners, SEA not in batting list
# Encarnacion from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Long from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Stubbs from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Encarnacion from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Long from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Encarnacion from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Long from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Alberto from Orioles, BAL not in batting list
# Ruiz from Orioles, BAL not in batting list
# Broxton from Orioles, BAL not in batting list
# Martin from Orioles, BAL not in batting list
# Brantley from Astros, HOU not in batting list
# Stubbs from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Alberto from Orioles, BAL not in batting list
# Nunez from Orioles, BAL not in batting list
# Severino from Orioles, BAL not in batting list
# Villar from Orioles, BAL not in batting list
# Broxton from Orioles, BAL not in batting list
# Martin from Orioles, BAL not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Alberto from Orioles, BAL not in batting list
# Nunez from Orioles, BAL not in batting list
# Severino from Orioles, BAL not in batting list
# Villar from Orioles, BAL not in batting list
# Broxton from Orioles, BAL not in batting list
# Martin from Orioles, BAL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Gamel from Brewers, MIL not in batting list
# Moustakas from Brewers, MIL not in batting list
# Grandal from Brewers, MIL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Moustakas from Brewers, MIL not in batting list
# Grandal from Brewers, MIL not in batting list
# Gamel from Brewers, MIL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Biggio from Blue Jays, TOR not in batting list
# Guerrero from Blue Jays, TOR not in batting list
# Galvis from Blue Jays, TOR not in batting list
# Drury from Blue Jays, TOR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Stubbs from Astros, HOU not in batting list
# Sogard from Blue Jays, TOR not in batting list
# Galvis from Blue Jays, TOR not in batting list
# Biggio from Blue Jays, TOR not in batting list
# Drury from Blue Jays, TOR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Sogard from Blue Jays, TOR not in batting list
# Guerrero from Blue Jays, TOR not in batting list
# Biggio from Blue Jays, TOR not in batting list
# Galvis from Blue Jays, TOR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Miley from Astros, HOU not in batting list
# Senzel from Reds, CIN not in batting list
# Puig from Reds, CIN not in batting list
# Farmer from Reds, CIN not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Dietrich from Reds, CIN not in batting list
# Senzel from Reds, CIN not in batting list
# Puig from Reds, CIN not in batting list
# Brantley from Astros, HOU not in batting list
# Stubbs from Astros, HOU not in batting list
# Senzel from Reds, CIN not in batting list
# Dietrich from Reds, CIN not in batting list
# Puig from Reds, CIN not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# LeMahieu from Yankees, NYY not in batting list
# Voit from Yankees, NYY not in batting list
# Encarnacion from Yankees, NYY not in batting list
# Maybin from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Encarnacion from Yankees, NYY not in batting list
# Urshela from Yankees, NYY not in batting list
# Maybin from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# LeMahieu from Yankees, NYY not in batting list
# Voit from Yankees, NYY not in batting list
# Encarnacion from Yankees, NYY not in batting list
# Urshela from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# LeMahieu from Yankees, NYY not in batting list
# Voit from Yankees, NYY not in batting list
# Encarnacion from Yankees, NYY not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cabrera from Pirates, PIT not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cabrera from Pirates, PIT not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Reynolds from Pirates, PIT not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Williamson from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Alvarez from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Urquidy from Astros, HOU not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Miley from Astros, HOU not in batting list
# Lambert from Rockies, COL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Parker from Angels, LAA not in batting list
# Lucroy from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Bour from Angels, LAA not in batting list
# Parker from Angels, LAA not in batting list
# Garneau from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Thaiss from Angels, LAA not in batting list
# Lucroy from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Federowicz from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Forsythe from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Cabrera from Rangers, TEX not in batting list
# Federowicz from Rangers, TEX not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Smith from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Smith from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Thaiss from Angels, LAA not in batting list
# Garneau from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Rengifo from Angels, LAA not in batting list
# Goodwin from Angels, LAA not in batting list
# Garneau from Angels, LAA not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Pence from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Pence from Rangers, TEX not in batting list
# Cabrera from Rangers, TEX not in batting list
# Federowicz from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Forsythe from Rangers, TEX not in batting list
# Mathis from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Herrmann from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Urquidy from Astros, HOU not in batting list
# Munoz from Cards, STL not in batting list
# Fowler from Cards, STL not in batting list
# Martinez from Cards, STL not in batting list
# Goldschmidt from Cards, STL not in batting list
# DeJong from Cards, STL not in batting list
# O'Neill from Cards, STL not in batting list
# Wong from Cards, STL not in batting list
# Wieters from Cards, STL not in batting list
# Flaherty from Cards, STL not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Edman from Cards, STL not in batting list
# Munoz from Cards, STL not in batting list
# Martinez from Cards, STL not in batting list
# Goldschmidt from Cards, STL not in batting list
# DeJong from Cards, STL not in batting list
# Wong from Cards, STL not in batting list
# O'Neill from Cards, STL not in batting list
# Knizner from Cards, STL not in batting list
# Ponce de Leon from Cards, STL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Miley from Astros, HOU not in batting list
# Edman from Cards, STL not in batting list
# Martinez from Cards, STL not in batting list
# Goldschmidt from Cards, STL not in batting list
# O'Neill from Cards, STL not in batting list
# DeJong from Cards, STL not in batting list
# Wieters from Cards, STL not in batting list
# Bader from Cards, STL not in batting list
# Wong from Cards, STL not in batting list
# Hudson from Cards, STL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mercado from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Bauers from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mercado from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Luplow from Indians, CLE not in batting list
# Bauers from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Mercado from Indians, CLE not in batting list
# Santana from Indians, CLE not in batting list
# Puig from Indians, CLE not in batting list
# Reyes from Indians, CLE not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Broxton from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Court from Mariners, SEA not in batting list
# Broxton from Mariners, SEA not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Smith from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Santana from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Moore from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Alonso from Rockies, COL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Alonso from Rockies, COL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Alberto from Orioles, BAL not in batting list
# Nunez from Orioles, BAL not in batting list
# Villar from Orioles, BAL not in batting list
# Severino from Orioles, BAL not in batting list
# Peterson from Orioles, BAL not in batting list
# Martin from Orioles, BAL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Villar from Orioles, BAL not in batting list
# Nunez from Orioles, BAL not in batting list
# Peterson from Orioles, BAL not in batting list
# Alberto from Orioles, BAL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Villar from Orioles, BAL not in batting list
# Severino from Orioles, BAL not in batting list
# Peterson from Orioles, BAL not in batting list
# Alberto from Orioles, BAL not in batting list
# Ruiz from Orioles, BAL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Jay from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# Castillo from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Goins from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Skole from White_Sox, CHW not in batting list
# Engel from White_Sox, CHW not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Jay from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# Castillo from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Goins from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Skole from White_Sox, CHW not in batting list
# Engel from White_Sox, CHW not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Jay from White_Sox, CHW not in batting list
# Anderson from White_Sox, CHW not in batting list
# Abreu from White_Sox, CHW not in batting list
# McCann from White_Sox, CHW not in batting list
# Jimenez from White_Sox, CHW not in batting list
# Castillo from White_Sox, CHW not in batting list
# Goins from White_Sox, CHW not in batting list
# Engel from White_Sox, CHW not in batting list
# Sanchez from White_Sox, CHW not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Joseph from Athletics, OAK not in batting list
# Herrmann from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Joseph from Athletics, OAK not in batting list
# Herrmann from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Joseph from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Joseph from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Demeritte from Tigers, DET not in batting list
# Rogers from Tigers, DET not in batting list
# Mercer from Tigers, DET not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Mercer from Tigers, DET not in batting list
# Rogers from Tigers, DET not in batting list
# Beckham from Tigers, DET not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Mayfield from Astros, HOU not in batting list
# Demeritte from Tigers, DET not in batting list
# Mercer from Tigers, DET not in batting list
# Beckham from Tigers, DET not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Demeritte from Tigers, DET not in batting list
# Rogers from Tigers, DET not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Thaiss from Angels, LAA not in batting list
# Bemboom from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Rengifo from Angels, LAA not in batting list
# Thaiss from Angels, LAA not in batting list
# Stassi from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Smith from Angels, LAA not in batting list
# Rengifo from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Sogard from Rays, TBR not in batting list
# Meadows from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Choi from Rays, TBR not in batting list
# Garcia from Rays, TBR not in batting list
# d'Arnaud from Rays, TBR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Sogard from Rays, TBR not in batting list
# Meadows from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Choi from Rays, TBR not in batting list
# Garcia from Rays, TBR not in batting list
# Aguilar from Rays, TBR not in batting list
# Zunino from Rays, TBR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Sogard from Rays, TBR not in batting list
# Meadows from Rays, TBR not in batting list
# Pham from Rays, TBR not in batting list
# Choi from Rays, TBR not in batting list
# Garcia from Rays, TBR not in batting list
# d'Arnaud from Rays, TBR not in batting list
# Aguilar from Rays, TBR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Bichette from Blue Jays, TOR not in batting list
# Biggio from Blue Jays, TOR not in batting list
# Guerrero from Blue Jays, TOR not in batting list
# Drury from Blue Jays, TOR not in batting list
# Fisher from Blue Jays, TOR not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Bichette from Blue Jays, TOR not in batting list
# Biggio from Blue Jays, TOR not in batting list
# Guerrero from Blue Jays, TOR not in batting list
# Drury from Blue Jays, TOR not in batting list
# Fisher from Blue Jays, TOR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Bichette from Blue Jays, TOR not in batting list
# Biggio from Blue Jays, TOR not in batting list
# Guerrero from Blue Jays, TOR not in batting list
# McKinney from Blue Jays, TOR not in batting list
# Drury from Blue Jays, TOR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Grisham from Brewers, MIL not in batting list
# Grandal from Brewers, MIL not in batting list
# Moustakas from Brewers, MIL not in batting list
# Spangenberg from Brewers, MIL not in batting list
# Houser from Brewers, MIL not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Greinke from Astros, HOU not in batting list
# Grisham from Brewers, MIL not in batting list
# Grandal from Brewers, MIL not in batting list
# Spangenberg from Brewers, MIL not in batting list
# Lyles from Brewers, MIL not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Moore from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Lopes from Mariners, SEA not in batting list
# Fraley from Mariners, SEA not in batting list
# Bishop from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Moore from Mariners, SEA not in batting list
# Smith from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Lopes from Mariners, SEA not in batting list
# Long from Mariners, SEA not in batting list
# Bishop from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Moore from Mariners, SEA not in batting list
# Smith from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Murphy from Mariners, SEA not in batting list
# Long from Mariners, SEA not in batting list
# Fraley from Mariners, SEA not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Long from Mariners, SEA not in batting list
# Nola from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# Lopes from Mariners, SEA not in batting list
# Bishop from Mariners, SEA not in batting list
# Broxton from Mariners, SEA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Grossman from Athletics, OAK not in batting list
# Brown from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Profar from Athletics, OAK not in batting list
# Murphy from Athletics, OAK not in batting list
# Grossman from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Brown from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Murphy from Athletics, OAK not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Brown from Athletics, OAK not in batting list
# Profar from Athletics, OAK not in batting list
# Grossman from Athletics, OAK not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# McBroom from Royals, KCR not in batting list
# Starling from Royals, KCR not in batting list
# Brantley from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# McBroom from Royals, KCR not in batting list
# Lopez from Royals, KCR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Toro from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# McBroom from Royals, KCR not in batting list
# Starling from Royals, KCR not in batting list
# Dini from Royals, KCR not in batting list
# Lopez from Royals, KCR not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Solak from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Santana from Rangers, TEX not in batting list
# Solak from Rangers, TEX not in batting list
# Heineman from Rangers, TEX not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Walsh from Angels, LAA not in batting list
# Smith from Angels, LAA not in batting list
# Thaiss from Angels, LAA not in batting list
# Alvarez from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Smith from Angels, LAA not in batting list
# Bour from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Alvarez from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Chirinos from Astros, HOU not in batting list
# Goodwin from Angels, LAA not in batting list
# Walsh from Angels, LAA not in batting list
# Thaiss from Angels, LAA not in batting list
# Bemboom from Angels, LAA not in batting list
# Brantley from Astros, HOU not in batting list
# Diaz from Astros, HOU not in batting list
# Maldonado from Astros, HOU not in batting list
# Long from Mariners, SEA not in batting list
# Crawford from Mariners, SEA not in batting list
# Lewis from Mariners, SEA not in batting list
# Narvaez from Mariners, SEA not in batting list
# ...
# 23     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 24     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 25     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 26     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 27     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 28      84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 29     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# ..     ...        ...              ...     ...     ...    ...    ...    ...
# 132    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 133    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 134    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 135    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 136    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 137     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 138    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 139    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 140     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 141     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 142     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 143    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 144    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 145    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 146    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 147    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 148    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 149    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 150    627     2018.0      Kyle Tucker  Astros    21.0   28.0   64.0   72.0
# 151    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 152    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 153     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 154    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 155    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 156    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 157    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 158     20     2018.0      Myles Straw  Astros    23.0    9.0    9.0   10.0
# 159    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 160    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 161    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
#
#       01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0    144.0   96.0  ...            NaN            NaN               NaN
# 1    144.0   96.0  ...            NaN            NaN               NaN
# 2    144.0   96.0  ...          -4.51            NaN             0.281
# 3    144.0   96.0  ...          -1.37            NaN             0.277
# 4    144.0   96.0  ...          -2.35            NaN             0.225
# 5    144.0   96.0  ...          -2.35            NaN             0.225
# 6    144.0   96.0  ...            NaN            NaN               NaN
# 7    144.0   96.0  ...            NaN            NaN               NaN
# 8    144.0   96.0  ...            NaN            NaN               NaN
# 9    144.0   96.0  ...           0.11            NaN             0.343
# 10   144.0   96.0  ...            NaN            NaN               NaN
# 11   144.0   96.0  ...          -1.32            NaN             0.344
# 12   144.0   96.0  ...          -4.47            NaN             0.295
# 13   144.0   96.0  ...          -1.39            NaN             0.410
# 14   144.0   96.0  ...          -1.39            NaN             0.410
# 15   144.0   96.0  ...            NaN            NaN               NaN
# 16   144.0   96.0  ...            NaN            NaN               NaN
# 17   144.0   96.0  ...           0.11            NaN             0.343
# 18   144.0   96.0  ...          -2.35            NaN             0.225
# 19   144.0   96.0  ...          -2.35            NaN             0.225
# 20   144.0   96.0  ...          -2.35            NaN             0.225
# 21   144.0   96.0  ...          -1.59            NaN             0.367
# 22   144.0   96.0  ...          -1.59            NaN             0.367
# 23   144.0   96.0  ...           1.43            NaN             0.225
# 24   144.0   96.0  ...          -1.08            NaN             0.297
# 25   144.0   96.0  ...           2.04            NaN             0.371
# 26   144.0   96.0  ...            NaN            NaN               NaN
# 27   144.0   96.0  ...            NaN            NaN               NaN
# 28   169.0  125.0  ...          -1.59            NaN             0.367
# 29   144.0   96.0  ...          -1.59            NaN             0.367
# ..     ...    ...  ...            ...            ...               ...
# 132  144.0   96.0  ...          -1.37            NaN             0.277
# 133  144.0   96.0  ...            NaN            NaN               NaN
# 134  144.0   96.0  ...          -0.84           3.71             0.273
# 135  144.0   96.0  ...           7.76            NaN             0.322
# 136  144.0   96.0  ...            NaN            NaN               NaN
# 137  169.0  125.0  ...           7.76            NaN             0.322
# 138  144.0   96.0  ...            NaN            NaN               NaN
# 139  144.0   96.0  ...            NaN            NaN               NaN
# 140  169.0  125.0  ...            NaN            NaN               NaN
# 141  169.0  125.0  ...            NaN            NaN               NaN
# 142  169.0  125.0  ...          -1.39            NaN             0.410
# 143  144.0   96.0  ...            NaN            NaN               NaN
# 144  144.0   96.0  ...           0.11            NaN             0.343
# 145  144.0   96.0  ...            NaN            NaN               NaN
# 146  144.0   96.0  ...            NaN            NaN               NaN
# 147  144.0   96.0  ...           0.11            NaN             0.343
# 148  144.0   96.0  ...          -9.38            NaN             0.289
# 149  144.0   96.0  ...            NaN            NaN               NaN
# 150    9.0    6.0  ...            NaN            NaN               NaN
# 151  144.0   96.0  ...          -4.33            NaN             0.263
# 152  144.0   96.0  ...          -4.33            NaN             0.263
# 153  169.0  125.0  ...           3.03            NaN             0.279
# 154  144.0   96.0  ...           2.88            NaN             0.352
# 155  144.0   96.0  ...            NaN            NaN               NaN
# 156  144.0   96.0  ...            NaN            NaN               NaN
# 157  144.0   96.0  ...            NaN            NaN               NaN
# 158    3.0    2.0  ...           3.03            NaN             0.279
# 159  144.0   96.0  ...            NaN            NaN               NaN
# 160  144.0   96.0  ...           2.88            NaN             0.352
# 161  144.0   96.0  ...            NaN            NaN               NaN
#
#      18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0                 NaN             NaN                 NaN                 NaN
# 1                 NaN             NaN                 NaN                 NaN
# 2               0.717           0.503               0.439               0.853
# 3               0.667           0.467               0.561               0.819
# 4               0.559           0.390               0.620               0.894
# 5               0.559           0.390               0.620               0.894
# 6                 NaN             NaN                 NaN                 NaN
# 7                 NaN             NaN                 NaN                 NaN
# 8                 NaN             NaN                 NaN                 NaN
# 9               0.592           0.461               0.643               0.853
# 10                NaN             NaN                 NaN                 NaN
# 11              0.671           0.495               0.584               0.870
# 12              0.634           0.462               0.512               0.835
# 13              0.665           0.537               0.745               0.924
# 14              0.665           0.537               0.745               0.924
# 15                NaN             NaN                 NaN                 NaN
# 16                NaN             NaN                 NaN                 NaN
# 17              0.592           0.461               0.643               0.853
# 18              0.559           0.390               0.620               0.894
# 19              0.559           0.390               0.620               0.894
# 20              0.559           0.390               0.620               0.894
# 21              0.694           0.532               0.554               0.832
# 22              0.694           0.532               0.554               0.832
# 23              0.630           0.416               0.559               0.812
# 24              0.608           0.456               0.667               0.894
# 25              0.668           0.519               0.756               0.874
# 26                NaN             NaN                 NaN                 NaN
# 27                NaN             NaN                 NaN                 NaN
# 28              0.694           0.532               0.554               0.832
# 29              0.694           0.532               0.554               0.832
# ..                ...             ...                 ...                 ...
# 132             0.667           0.467               0.561               0.819
# 133               NaN             NaN                 NaN                 NaN
# 134             0.653           0.463               0.643               0.923
# 135             0.625           0.480               0.579               0.750
# 136               NaN             NaN                 NaN                 NaN
# 137             0.625           0.480               0.579               0.750
# 138               NaN             NaN                 NaN                 NaN
# 139               NaN             NaN                 NaN                 NaN
# 140               NaN             NaN                 NaN                 NaN
# 141               NaN             NaN                 NaN                 NaN
# 142             0.665           0.537               0.745               0.924
# 143               NaN             NaN                 NaN                 NaN
# 144             0.592           0.461               0.643               0.853
# 145               NaN             NaN                 NaN                 NaN
# 146               NaN             NaN                 NaN                 NaN
# 147             0.592           0.461               0.643               0.853
# 148             0.579           0.440               0.400               0.818
# 149               NaN             NaN                 NaN                 NaN
# 150               NaN             NaN                 NaN                 NaN
# 151             0.588           0.417               0.800               1.000
# 152             0.588           0.417               0.800               1.000
# 153             0.626           0.448               0.528               0.831
# 154             0.664           0.492               0.527               0.739
# 155               NaN             NaN                 NaN                 NaN
# 156               NaN             NaN                 NaN                 NaN
# 157               NaN             NaN                 NaN                 NaN
# 158             0.626           0.448               0.528               0.831
# 159               NaN             NaN                 NaN                 NaN
# 160             0.664           0.492               0.527               0.739
# 161               NaN             NaN                 NaN                 NaN
#
#      18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0                 NaN            NaN           NaN
# 1                 NaN            NaN           NaN
# 2               0.740          0.510          23.5
# 3               0.740          0.486          23.2
# 4               0.814          0.494          22.6
# 5               0.814          0.494          22.6
# 6                 NaN            NaN           NaN
# 7                 NaN            NaN           NaN
# 8                 NaN            NaN           NaN
# 9               0.771          0.474          25.7
# 10                NaN            NaN           NaN
# 11              0.763          0.460          24.7
# 12              0.730          0.491          23.4
# 13              0.855          0.497          22.9
# 14              0.855          0.497          22.9
# 15                NaN            NaN           NaN
# 16                NaN            NaN           NaN
# 17              0.771          0.474          25.7
# 18              0.814          0.494          22.6
# 19              0.814          0.494          22.6
# 20              0.814          0.494          22.6
# 21              0.737          0.504          22.6
# 22              0.737          0.504          22.6
# 23              0.740          0.472          24.9
# 24              0.822          0.513          22.6
# 25              0.832          0.501          24.7
# 26                NaN            NaN           NaN
# 27                NaN            NaN           NaN
# 28              0.737          0.504          22.6
# 29              0.737          0.504          22.6
# ..                ...            ...           ...
# 132             0.740          0.486          23.2
# 133               NaN            NaN           NaN
# 134             0.840          0.499          24.6
# 135             0.695          0.520          22.6
# 136               NaN            NaN           NaN
# 137             0.695          0.520          22.6
# 138               NaN            NaN           NaN
# 139               NaN            NaN           NaN
# 140               NaN            NaN           NaN
# 141               NaN            NaN           NaN
# 142             0.855          0.497          22.9
# 143               NaN            NaN           NaN
# 144             0.771          0.474          25.7
# 145               NaN            NaN           NaN
# 146               NaN            NaN           NaN
# 147             0.771          0.474          25.7
# 148             0.688          0.523          23.5
# 149               NaN            NaN           NaN
# 150               NaN            NaN           NaN
# 151             0.933          0.472          21.3
# 152             0.933          0.472          21.3
# 153             0.735          0.488          22.0
# 154             0.655          0.448          23.8
# 155               NaN            NaN           NaN
# 156               NaN            NaN           NaN
# 157               NaN            NaN           NaN
# 158             0.735          0.488          22.0
# 159               NaN            NaN           NaN
# 160             0.655          0.448          23.8
# 161               NaN            NaN           NaN
#
# [162 rows x 5184 columns]

# %%
#test.columns[-1]
col = "18_Name"
test[test[col].isna()]
# Out:
#      index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 1      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 6      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 7      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 8      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 10     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 15     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 16     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 26     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 27     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 32     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 33     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 34     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 35     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 36     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 37     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 39     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 47     296     2018.0     Josh Reddick  Astros    31.0  134.0  433.0  487.0
# 48     296     2018.0     Josh Reddick  Astros    31.0  134.0  433.0  487.0
# 49     296     2018.0     Josh Reddick  Astros    31.0  134.0  433.0  487.0
# 50     296     2018.0     Josh Reddick  Astros    31.0  134.0  433.0  487.0
# 54     296     2018.0     Josh Reddick  Astros    31.0  134.0  433.0  487.0
# 55     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 56     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 59     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 60     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 61     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 62     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 63     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# 64     536     2018.0     Derek Fisher  Astros    24.0   42.0   79.0   86.0
# ..     ...        ...              ...     ...     ...    ...    ...    ...
# 115    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 117    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 118    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 119    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 120    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 121    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 122    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 125    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 126    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 127    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 128    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 129    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 130    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 131     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 133    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 136    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 138    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 139    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 140     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 141     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 143    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 145    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 146    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 149    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 150    627     2018.0      Kyle Tucker  Astros    21.0   28.0   64.0   72.0
# 155    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 156    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 157    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 159    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 161    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
#
#       01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0    144.0   96.0  ...            NaN            NaN               NaN
# 1    144.0   96.0  ...            NaN            NaN               NaN
# 6    144.0   96.0  ...            NaN            NaN               NaN
# 7    144.0   96.0  ...            NaN            NaN               NaN
# 8    144.0   96.0  ...            NaN            NaN               NaN
# 10   144.0   96.0  ...            NaN            NaN               NaN
# 15   144.0   96.0  ...            NaN            NaN               NaN
# 16   144.0   96.0  ...            NaN            NaN               NaN
# 26   144.0   96.0  ...            NaN            NaN               NaN
# 27   144.0   96.0  ...            NaN            NaN               NaN
# 32   144.0   96.0  ...            NaN            NaN               NaN
# 33   144.0   96.0  ...            NaN            NaN               NaN
# 34   144.0   96.0  ...            NaN            NaN               NaN
# 35   144.0   96.0  ...            NaN            NaN               NaN
# 36   144.0   96.0  ...            NaN            NaN               NaN
# 37   144.0   96.0  ...            NaN            NaN               NaN
# 39   144.0   96.0  ...            NaN            NaN               NaN
# 47   105.0   73.0  ...            NaN            NaN               NaN
# 48   105.0   73.0  ...            NaN            NaN               NaN
# 49   105.0   73.0  ...            NaN            NaN               NaN
# 50   105.0   73.0  ...            NaN            NaN               NaN
# 54   105.0   73.0  ...            NaN            NaN               NaN
# 55    13.0    5.0  ...            NaN            NaN               NaN
# 56    13.0    5.0  ...            NaN            NaN               NaN
# 59    13.0    5.0  ...            NaN            NaN               NaN
# 60    13.0    5.0  ...            NaN            NaN               NaN
# 61    13.0    5.0  ...            NaN            NaN               NaN
# 62    13.0    5.0  ...            NaN            NaN               NaN
# 63    13.0    5.0  ...            NaN            NaN               NaN
# 64    13.0    5.0  ...            NaN            NaN               NaN
# ..     ...    ...  ...            ...            ...               ...
# 115  144.0   96.0  ...            NaN            NaN               NaN
# 117  144.0   96.0  ...            NaN            NaN               NaN
# 118  144.0   96.0  ...            NaN            NaN               NaN
# 119  144.0   96.0  ...            NaN            NaN               NaN
# 120  144.0   96.0  ...            NaN            NaN               NaN
# 121  144.0   96.0  ...            NaN            NaN               NaN
# 122  144.0   96.0  ...            NaN            NaN               NaN
# 125  144.0   96.0  ...            NaN            NaN               NaN
# 126  144.0   96.0  ...            NaN            NaN               NaN
# 127  144.0   96.0  ...            NaN            NaN               NaN
# 128  144.0   96.0  ...            NaN            NaN               NaN
# 129  144.0   96.0  ...            NaN            NaN               NaN
# 130  144.0   96.0  ...            NaN            NaN               NaN
# 131  169.0  125.0  ...            NaN            NaN               NaN
# 133  144.0   96.0  ...            NaN            NaN               NaN
# 136  144.0   96.0  ...            NaN            NaN               NaN
# 138  144.0   96.0  ...            NaN            NaN               NaN
# 139  144.0   96.0  ...            NaN            NaN               NaN
# 140  169.0  125.0  ...            NaN            NaN               NaN
# 141  169.0  125.0  ...            NaN            NaN               NaN
# 143  144.0   96.0  ...            NaN            NaN               NaN
# 145  144.0   96.0  ...            NaN            NaN               NaN
# 146  144.0   96.0  ...            NaN            NaN               NaN
# 149  144.0   96.0  ...            NaN            NaN               NaN
# 150    9.0    6.0  ...            NaN            NaN               NaN
# 155  144.0   96.0  ...            NaN            NaN               NaN
# 156  144.0   96.0  ...            NaN            NaN               NaN
# 157  144.0   96.0  ...            NaN            NaN               NaN
# 159  144.0   96.0  ...            NaN            NaN               NaN
# 161  144.0   96.0  ...            NaN            NaN               NaN
#
#      18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0                 NaN             NaN                 NaN                 NaN
# 1                 NaN             NaN                 NaN                 NaN
# 6                 NaN             NaN                 NaN                 NaN
# 7                 NaN             NaN                 NaN                 NaN
# 8                 NaN             NaN                 NaN                 NaN
# 10                NaN             NaN                 NaN                 NaN
# 15                NaN             NaN                 NaN                 NaN
# 16                NaN             NaN                 NaN                 NaN
# 26                NaN             NaN                 NaN                 NaN
# 27                NaN             NaN                 NaN                 NaN
# 32                NaN             NaN                 NaN                 NaN
# 33                NaN             NaN                 NaN                 NaN
# 34                NaN             NaN                 NaN                 NaN
# 35                NaN             NaN                 NaN                 NaN
# 36                NaN             NaN                 NaN                 NaN
# 37                NaN             NaN                 NaN                 NaN
# 39                NaN             NaN                 NaN                 NaN
# 47                NaN             NaN                 NaN                 NaN
# 48                NaN             NaN                 NaN                 NaN
# 49                NaN             NaN                 NaN                 NaN
# 50                NaN             NaN                 NaN                 NaN
# 54                NaN             NaN                 NaN                 NaN
# 55                NaN             NaN                 NaN                 NaN
# 56                NaN             NaN                 NaN                 NaN
# 59                NaN             NaN                 NaN                 NaN
# 60                NaN             NaN                 NaN                 NaN
# 61                NaN             NaN                 NaN                 NaN
# 62                NaN             NaN                 NaN                 NaN
# 63                NaN             NaN                 NaN                 NaN
# 64                NaN             NaN                 NaN                 NaN
# ..                ...             ...                 ...                 ...
# 115               NaN             NaN                 NaN                 NaN
# 117               NaN             NaN                 NaN                 NaN
# 118               NaN             NaN                 NaN                 NaN
# 119               NaN             NaN                 NaN                 NaN
# 120               NaN             NaN                 NaN                 NaN
# 121               NaN             NaN                 NaN                 NaN
# 122               NaN             NaN                 NaN                 NaN
# 125               NaN             NaN                 NaN                 NaN
# 126               NaN             NaN                 NaN                 NaN
# 127               NaN             NaN                 NaN                 NaN
# 128               NaN             NaN                 NaN                 NaN
# 129               NaN             NaN                 NaN                 NaN
# 130               NaN             NaN                 NaN                 NaN
# 131               NaN             NaN                 NaN                 NaN
# 133               NaN             NaN                 NaN                 NaN
# 136               NaN             NaN                 NaN                 NaN
# 138               NaN             NaN                 NaN                 NaN
# 139               NaN             NaN                 NaN                 NaN
# 140               NaN             NaN                 NaN                 NaN
# 141               NaN             NaN                 NaN                 NaN
# 143               NaN             NaN                 NaN                 NaN
# 145               NaN             NaN                 NaN                 NaN
# 146               NaN             NaN                 NaN                 NaN
# 149               NaN             NaN                 NaN                 NaN
# 150               NaN             NaN                 NaN                 NaN
# 155               NaN             NaN                 NaN                 NaN
# 156               NaN             NaN                 NaN                 NaN
# 157               NaN             NaN                 NaN                 NaN
# 159               NaN             NaN                 NaN                 NaN
# 161               NaN             NaN                 NaN                 NaN
#
#      18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0                 NaN            NaN           NaN
# 1                 NaN            NaN           NaN
# 6                 NaN            NaN           NaN
# 7                 NaN            NaN           NaN
# 8                 NaN            NaN           NaN
# 10                NaN            NaN           NaN
# 15                NaN            NaN           NaN
# 16                NaN            NaN           NaN
# 26                NaN            NaN           NaN
# 27                NaN            NaN           NaN
# 32                NaN            NaN           NaN
# 33                NaN            NaN           NaN
# 34                NaN            NaN           NaN
# 35                NaN            NaN           NaN
# 36                NaN            NaN           NaN
# 37                NaN            NaN           NaN
# 39                NaN            NaN           NaN
# 47                NaN            NaN           NaN
# 48                NaN            NaN           NaN
# 49                NaN            NaN           NaN
# 50                NaN            NaN           NaN
# 54                NaN            NaN           NaN
# 55                NaN            NaN           NaN
# 56                NaN            NaN           NaN
# 59                NaN            NaN           NaN
# 60                NaN            NaN           NaN
# 61                NaN            NaN           NaN
# 62                NaN            NaN           NaN
# 63                NaN            NaN           NaN
# 64                NaN            NaN           NaN
# ..                ...            ...           ...
# 115               NaN            NaN           NaN
# 117               NaN            NaN           NaN
# 118               NaN            NaN           NaN
# 119               NaN            NaN           NaN
# 120               NaN            NaN           NaN
# 121               NaN            NaN           NaN
# 122               NaN            NaN           NaN
# 125               NaN            NaN           NaN
# 126               NaN            NaN           NaN
# 127               NaN            NaN           NaN
# 128               NaN            NaN           NaN
# 129               NaN            NaN           NaN
# 130               NaN            NaN           NaN
# 131               NaN            NaN           NaN
# 133               NaN            NaN           NaN
# 136               NaN            NaN           NaN
# 138               NaN            NaN           NaN
# 139               NaN            NaN           NaN
# 140               NaN            NaN           NaN
# 141               NaN            NaN           NaN
# 143               NaN            NaN           NaN
# 145               NaN            NaN           NaN
# 146               NaN            NaN           NaN
# 149               NaN            NaN           NaN
# 150               NaN            NaN           NaN
# 155               NaN            NaN           NaN
# 156               NaN            NaN           NaN
# 157               NaN            NaN           NaN
# 159               NaN            NaN           NaN
# 161               NaN            NaN           NaN
#
# [85 rows x 5184 columns]

# %%
batting_season_2018 = batting_stats(2018)

# %%
p_name = "Chirinos"
p_full_name = [x for x in batting_season_2018.Name if p_name in x]
p_full_name
players_st = [batting_season_2018[batting_season_2018["Name"]==x] for x in p_full_name]

# %%
Possible_player = pd.DataFrame()
for p in players_st:
    Possible_player = Possible_player.append(p)
Possible_player
# Out:
#      Season               Name     Team   Age      G     AB     PA     H  \
# 193  2018.0  Robinson Chirinos  Rangers  34.0  113.0  360.0  426.0  80.0
# 957  2018.0     Yonny Chirinos     Rays  24.0   18.0    1.0    1.0   0.0
#
#        1B    2B  ...  wSL/C (pi)  wXX/C (pi)  O-Swing% (pi)  Z-Swing% (pi)  \
# 193  46.0  15.0  ...        0.69         NaN          0.276          0.628
# 957   0.0   0.0  ...       -1.83         NaN          0.000          0.333
#
#      Swing% (pi)  O-Contact% (pi)  Z-Contact% (pi)  Contact% (pi)  Zone% (pi)  \
# 193        0.441            0.538            0.757          0.684        0.47
# 957        0.250              NaN            0.000          0.000        0.75
#
#      Pace (pi)
# 193       26.2
# 957       16.3
#
# [2 rows x 287 columns]

# %%
def create_trining_df(year = (dt.datetime.today().year-1), team = "HOU" ):
                       
    
    players_df = get_players_per_game(year, team)
    #print(players_df.tail(10))    
    stats_players_start_lineup = get_stats_startingplayer_by_game(players_df, team, year)
    
    return pd.concat([players_df.iloc[:,[0,1,2,3,4,5,6]],stats_players_start_lineup], axis=1, join='inner')
       
    
    
    
    #dates_played = get_dates_played(last_season_games_played, year)

# %%
stats_players_start_lineup = create_trining_df()
stats_players_start_lineup
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-68-7e2134587ee0> in <module>
# ----> 1 stats_players_start_lineup = create_trining_df()
#       2 stats_players_start_lineup
#
# <ipython-input-67-8f5c0089e33e> in create_trining_df(year, team)
#       2
#       3
# ----> 4     players_df = get_players_per_game(year, team)
#       5     #print(players_df.tail(10))
#       6     stats_players_start_lineup = get_stats_startingplayer_by_game(players_df, team, year)
#
# <ipython-input-14-aab3e3046dd7> in get_players_per_game(year, team)
#      20         opp_all_lineups_season = pd.read_csv(opp_lineups_path)
#      21         #print(f"opp: {opponent}")
# ---> 22         opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
#      23         opponents_lineups.update({opponent:opp_all_lineups_season})
#      24
#
# <ipython-input-11-d8e44ff5051e> in format_lineups_df(df, year)
#       2 def format_lineups_df(df, year):
#       3     df  =  modify_date_col_from_lineups(df, year)
# ----> 4     df = clean_lineups(df)
#       5     df.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
#       6     df.set_index("index", inplace=True, drop=True)
#
# <ipython-input-10-498ed8a1c3af> in clean_lineups(df)
#       5             name = original_name.split("-")
#       6             name = name[0]
# ----> 7             df.replace(original_name,name, inplace=True)
#       8             #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
#       9             #has the same names over and over. We just need to grab all the different names and replace them
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/frame.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    4040                                               value=value, inplace=inplace,
#    4041                                               limit=limit, regex=regex,
# -> 4042                                               method=method)
#    4043
#    4044     @Appender(_shared_docs['shift'] % _shared_doc_kwargs)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/generic.py in replace(self, to_replace, value, inplace, limit, regex, method)
#    6577                     new_data = self._data.replace(to_replace=to_replace,
#    6578                                                   value=value, inplace=inplace,
# -> 6579                                                   regex=regex)
#    6580                 else:
#    6581                     msg = ('Invalid "to_replace" type: '
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in replace(self, **kwargs)
#     535
#     536     def replace(self, **kwargs):
# --> 537         return self.apply('replace', **kwargs)
#     538
#     539     def replace_list(self, src_list, dest_list, inplace=False, regex=False):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/managers.py in apply(self, f, axes, filter, do_integrity_check, consolidate, **kwargs)
#     393                                             copy=align_copy)
#     394
# --> 395             applied = getattr(b, f)(**kwargs)
#     396             result_blocks = _extend_blocks(applied, result_blocks)
#     397
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#    2761                                                     inplace=inplace,
#    2762                                                     filter=filter, regex=regex,
# -> 2763                                                     convert=convert)
#    2764         elif both_lists:
#    2765             for to_rep, v in zip(to_replace, value):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in replace(self, to_replace, value, inplace, filter, regex, convert)
#     777             if convert:
#     778                 blocks = [b.convert(by_item=True, numeric=False,
# --> 779                                     copy=not inplace) for b in blocks]
#     780             return blocks
#     781         except (TypeError, ValueError):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in <listcomp>(.0)
#     777             if convert:
#     778                 blocks = [b.convert(by_item=True, numeric=False,
# --> 779                                     copy=not inplace) for b in blocks]
#     780             return blocks
#     781         except (TypeError, ValueError):
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in convert(self, *args, **kwargs)
#    2679
#    2680         if by_item and not self._is_single_block:
# -> 2681             blocks = self.split_and_operate(None, f, False)
#    2682         else:
#    2683             values = f(None, self.values.ravel(), None)
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in split_and_operate(self, mask, f, inplace)
#     470                 nv = v if inplace else v.copy()
#     471
# --> 472             block = make_a_block(nv, [ref_loc])
#     473             new_blocks.append(block)
#     474
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_a_block(nv, ref_loc)
#     446                     pass
#     447                 block = self.make_block(values=nv,
# --> 448                                         placement=ref_loc)
#     449             return block
#     450
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(self, values, placement, ndim)
#     221             ndim = self.ndim
#     222
# --> 223         return make_block(values, placement=placement, ndim=ndim)
#     224
#     225     def make_block_same_class(self, values, placement=None, ndim=None,
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in make_block(values, placement, klass, ndim, dtype, fastpath)
#    3093         values = DatetimeArray._simple_new(values, dtype=dtype)
#    3094
# -> 3095     return klass(values, ndim=ndim, placement=placement)
#    3096
#    3097
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#    2629
#    2630         super(ObjectBlock, self).__init__(values, ndim=ndim,
# -> 2631                                           placement=placement)
#    2632
#    2633     @property
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in __init__(self, values, placement, ndim)
#      78     def __init__(self, values, placement, ndim=None):
#      79         self.ndim = self._check_ndim(values, ndim)
# ---> 80         self.mgr_locs = placement
#      81         self.values = values
#      82
#
# /anaconda3/lib/python3.7/site-packages/pandas/core/internals/blocks.py in mgr_locs(self, new_mgr_locs)
#     200     def mgr_locs(self, new_mgr_locs):
#     201         if not isinstance(new_mgr_locs, libinternals.BlockPlacement):
# --> 202             new_mgr_locs = libinternals.BlockPlacement(new_mgr_locs)
#     203
#     204         self._mgr_locs = new_mgr_locs
#
# pandas/_libs/internals.pyx in pandas._libs.internals.BlockPlacement.__init__()
#
# /anaconda3/lib/python3.7/site-packages/numpy/core/numeric.py in require(a, dtype, requirements)
#     764         requirements.remove('C')
#     765
# --> 766     arr = array(a, dtype=dtype, order=order, copy=False, subok=subok)
#     767
#     768     for prop in requirements:
#
# KeyboardInterrupt:

# %%
stats_players_start_lineup.head()

# %%
names = stats_players_start_lineup.loc[:]["Name"].isna()

# %%
names.isnull().values.any()
