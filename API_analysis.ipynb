# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %% [markdown]
# ### Analysing *batting_stats()* with different paramters

# %%
all_data_2019 = batting_stats(2019)

# %%
all_data_2019 = batting_stats(2019)
players_with_more_than_50 = batting_stats(2019, qual=50)
all_data_since_2015 = batting_stats(2015, 2019)
aggregated_data = batting_stats(2010, 2016, ind=0)

print(all_data_2019.head())
print(players_with_more_than_50.head())
print(all_data_since_2015.head())
print(aggregated_data.head())

# %% [markdown]
# # Conclusion for batting_stats()
# Very versitile function that can take one or two years as parameters (single season or multiple seasons). It would return a dataframe with 287 columns with all the batting statistics for every single player for the whole season/seasons. A lot of statistics!
#
# ### Analysing *schedule_and_record()*

# %%
from pybaseball import schedule_and_record

Astros_record = schedule_and_record(2019, "HOU")
Astros_record.head(20)

# %%
Astros_record.columns

# %% [markdown]
# ### Conclusion for schedule_and_record()
# Very useful function that can get the players who played in each game, and also all the dates in which each a team played in a season, among others. It only has 19 columns, but this will be used as a *link* table between the others.
#
# ## Analysing *batting_stats_range()*

# %%
data_range = batting_stats_range("2019-09-01","2019-09-30")
data_range

# %%
print(data_range.columns)
print(all_data_2019.columns)

# %% [markdown]
# ### Conclusion for *batting_stats_range()*
#
# this functions returns a much smaller dataframe with only 27 columns. This will be useful to get the most recent information for each player right before each game.
#
# # Let's look at all the columns for batting_stats() and batting_stats_range()

# %%
print(all_data_2019.columns[:95])

# %%
print(all_data_2019.columns[95:190])

# %%
print(all_data_2019.columns[190:])

# %%
len(all_data_2019.columns)

# %%
len(data_range.columns)

# %% [markdown]
# ### Let's see what columns in the smaller dataframe are also in the larger df

# %%
shared_columns = list(data_range.columns & all_data_2019.columns)

# %%
shared_columns

# %%
len(shared_columns)

# %% [markdown]
# ### basically all of them. Only 4 are not included. Let's see which one are not in the larger df.

# %%
range_columns_not_in_all_data = list(data_range.columns.difference(all_data_2019.columns))
range_columns_not_in_all_data

# %% [markdown]
# # So #days is a useless column, BA is the same as AVG, Lev is useless too, and Tm is the same as Team. As a conclusion, all the columns are included.

# %%
Astros_2019stats  =  all_data_2019[all_data_2019["Team"]=="Astros"]

# %%
Astros_2019stats.count()

# %%
#Thursday, Mar 28
#"2019-03-28"
game_march_28_2019 = batting_stats_range("2019-03-28",)

# %%
game_march_28_2019["Tm"].unique

# %%
game_march_28_2019[game_march_28_2019["Tm"]=="Houston"]

# %% [markdown]
# ## ...We can see who played in every game ^

# %%
game_march_28_2019.columns

# %%
game_march_28_2019.iloc[:,6]

# %% [markdown]
# ### *"@"* means they're playing as *visitors*.

# %% [markdown]
# # Startegy:
# ### General Strategy:
# Retrieve data for each player in each game played. Feed the model with data from past year for each player and past month. Build a dataframe where each row represents the features to train the model and to make predictions out of the model.
#
# Each row would have the full 283 features from past season plus the 23 from past month for each player that played the particular game plus 2 team features.
#
# ### Specific Tasks
#
# Usually there are 9 players, so there would be 9 times 283 features only to account for past season statistics of 1 team. So this number would be later mulitply also by 2 since each game involves 2 teams. We will use **schedule_and_record()** function to get the players who played in a game, so we can later use **batting_stats()** function to get those 283 features from last season for each player that played a particular game.
#
# There will be also recent statistics from last month for each player as well, which is 22 features. Again this number would be multiply by 9 and then by 2. We will use **schedule_and_record()** function to get the players who played in that game, so we can later retrieve the past month statistics for each one of those players from **batting_stats_range()**.
#
# There will be also statistics from the team to be included in each record such as streak, and GB, also gotten from **schedule_and_record()**.
#
# ### Conclusion
# The training DataFrame will contain a record for each game of a single team and its opponent. This leads us to  **DataFrame with dimensions of 5494 columns by *Games-Played-By-The-Team* rows**. This is only batting statistics so far.

# %% [markdown]
# ## Analysing *pitching_stats()*

# %%
from pybaseball import pitching_stats

pitching_stats_2019 = pitching_stats("2019")
pitching_stats_2019.head(15)

# %%
pitching_stats_2019.columns

# %%
pitching_stats_2019.columns[:100]

# %%
pitching_stats_2019.columns[100:200]

# %%
pitching_stats_2019.columns[200:]

# %% [markdown]
# ### Aparanetly, we should use only the *(pi)* variables. They are calculated using a new algorythm that eliminates what Brooks Baseball considers errors from Pitch FX (pfx).
#
# link: https://www.reddit.com/r/Sabermetrics/comments/6qepoa/what_is_the_data_source_for_nonattributed_plate/

# %%
pfx_col = [x for x in pitching_stats_2019.columns if "(pfx)" in x ]
pfx_col

# %%
pitching_stats_2019.drop( columns = pfx_col, inplace=True )
pitching_stats_2019.columns

# %%
from pybaseball import pitching_stats_range

pitching_range_1day = pitching_stats_range("2019-03-28",)

# %%
pitching_range_1day.head()

# %%
pitchers_Astros_on_20190328 = pitching_range_1day[pitching_range_1day.Tm == "Houston"]
pitchers_Astros_on_20190328

# %% [markdown]
# ## So! we can know who pitched on a certain game ^

# %%
pitchers_Astros_on_20190328.columns

# %% [markdown]
# #### An idea is to keep columns that represent % of other columns. For example, keeping IFFB% but droping IFFB, since a percentage tells more of a story that an isolated scalar value. In this way, we can reduce redundancy in our features and, therefore, the total size of our features array.

# %%
bat_col_not_to_drop = [x for x in all_data_2019.columns if "%" in x and x[:-1] in all_data_2019.columns]
bat_col_not_to_drop

# %%
bat_col_to_drop = [x[:-1] for x in bat_col_not_to_drop]
bat_col_to_drop

# %%
pitch_col_not_to_drop = [x for x in pitching_stats_2019.columns if "%" in x and x[:-1] in pitching_stats_2019.columns]
pitch_col_not_to_drop

# %%
pitch_col_to_drop = [x[:-1] for x in pitch_col_not_to_drop]
pitch_col_to_drop

# %%
all_data_2019.drop(columns=bat_col_to_drop, inplace=True)
pitching_stats_2019.drop(columns=pitch_col_to_drop, inplace=True)
print(f"Total columns in bat_statistics: {len(all_data_2019.columns)}\nTotal columns in pitch_statistics: {len(pitching_stats_2019.columns)} ")

# %% [markdown]
# ### ...We still have loooots of columns.
#
#
# ##### We will have to get rid of some columns manually that we consider unnecesary such as "Age" or "Team", etc. However, some of these columns might be useful during concatenation, so we will handle this in within the function that creates the dataframe.
#
# ## Let's explore how many pitcher there are per game usually

# %%
# let's grab our datframe created through record_and_schedule() previously for The Astros season 2019:
Astros_record.head()

# %% [markdown]
# ### We will have to convert the date format cuz these guys are assholes

# %%
date = Astros_record.Date[1]
#date = date.split(",")
date = re.findall(r"\w* [0-9][0-9]|[0-9]", date)
date = date[0]
print(date)
year = "2019"
date = year + " " + date
date

# %%
import datetime as dt

# %%
date_formatted = dt.datetime.strptime(date,"%Y %b %d")
date_formatted

# %%
date_formatted.month

# %% [markdown]
# ### it worked out, so now we know how

# %%
type(date_formatted)

# %% [markdown]
# # %%%%%%%    Building the Training DataFrame    %%%%%%%%

# %%
# Import required libraries
from path import Path
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
from sklearn.preprocessing import LabelEncoder, StandardScaler
from pybaseball import batting_stats
from pybaseball import batting_stats_range
from pybaseball import pitching_stats_range
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix, accuracy_score, classification_report

# %%
teams = set(all_data_2017["Team"])
teams
# Out:
# {'- - -',
#  'Angels',
#  'Astros',
#  'Athletics',
#  'Blue Jays',
#  'Braves',
#  'Brewers',
#  'Cardinals',
#  'Cubs',
#  'Diamondbacks',
#  'Dodgers',
#  'Giants',
#  'Indians',
#  'Mariners',
#  'Marlins',
#  'Mets',
#  'Nationals',
#  'Orioles',
#  'Padres',
#  'Phillies',
#  'Pirates',
#  'Rangers',
#  'Rays',
#  'Red Sox',
#  'Reds',
#  'Rockies',
#  'Royals',
#  'Tigers',
#  'Twins',
#  'White Sox',
#  'Yankees'}

# %%
team_dict = {'Angels':'LAA',
            'Athletics': 'OAK',
            'Astros': 'HOU',
            'Braves': 'ATL',
            'Brewers': 'MIL',
            'Cards': 'STL',
            'Cubs': 'CUB',
            'Diamondbacks': 'ARI',
            'Dodgers': 'LAD',
            'Giants': 'SFG',
            'Indians': 'CLE',
            'Blue Jays': 'TOR',
            'Mariners': 'SEA',
            'Marlins': 'MIA',
            'Mets': 'NYM',
            'Nats': 'WAS',
            'Orioles': 'BAL',
            'Padres': 'SDP',
            'Phillies': 'PHI',
            'Pirates': 'PIT',
            'Rangers': 'TEX',
            'Rays': 'TBR',
            'Red Sox': 'BOS',
            'Reds': 'CIN',
            'Rockies': 'COL',
            'Royals': 'KCR',
            'Tigers': 'DET',
            'Twins': 'MIN',
            'White_Sox': 'CHW',
            'Yankees': 'NYY'
             
           }
def get_key_from_dict(dictionary, val): 
    for key, value in dictionary.items(): 
         if val == value: 
            return key

# %%
from pybaseball import pitching_stats

def format_dates_to_dt(un_date="Monday, Dec 31", year=1999):
    date = re.findall(r"\W\w\w\w\s\d+", un_date)
    date = date[0]
    date = str(year) + date
    date_formatted = dt.datetime.strptime(date,"%Y %b %d")
    return date_formatted

# %%
def modify_dates_from_lineups(date="1. Thu,3/29 at TEX W (4-1)#", year = 2018):
    date = re.findall(r"\d+/\d+", date)
    try: date = date[0]
    except: return
    date = str(year) +" " + date
    return date

# %%
def modify_date_col_from_lineups(df, year):
    df["0"] = df.apply(lambda x: modify_dates_from_lineups(x["0"],year), axis=1)
    df["0"] = pd.to_datetime(df["0"])
    return df

# %%
def clean_lineups(df):
    for row in range(0,len(df)):
        for column in range(2,11):
            original_name = df.iloc[row,column]
            name = original_name.split("-")
            name = name[0]
            df.replace(original_name,name, inplace=True)
            #WE CAN IMPROVE THIS LATER so we don't need to iterate all the dataframe since most of it
            #has the same names over and over. We just need to grab all the different names and replace them
    return df

# %%
def format_lineups_df(df, year):
    df  =  modify_date_col_from_lineups(df, year)
    df = clean_lineups(df)
    df.columns = ["index","Date","1","2","3","4","5","6","7","8","9"]
    df.set_index("index", inplace=True, drop=True)
    return df

# %%
def get_dates_played(df=None,year=None):
    
    dates_played = [format_dates_to_dt(date, year) for date in df.Date]
    return dates_played

# %%
def get_team_schedule(year=None, team = "HOU"):
    
    teams_df  = schedule_and_record(year, team)
    teams_df  = teams_df.iloc[ : , [0,1,2,3,10,17] ]
    teams_df["Date"] = teams_df.apply(lambda x: format_dates_to_dt(x["Date"],year), axis=1)
    teams_df.replace("@",1, inplace=True)
    teams_df.replace("Home",0, inplace=True)
    return teams_df

# %%
def get_players_per_game(year = None, team = None):
    
    schedule_df = get_team_schedule(year, team)
    opponents = set(schedule_df["Opp"])
    
    bat_stat_path = Path(f"Data/Batting/Clean_Data/clean_batting_data_{year}.csv")
    all_bat_stats = pd.read_csv(bat_stat_path)
    
    pitchers_path = Path(f"Starting_Pitchers/Starting_Pitchers_{}")
    
    lineups_path = Path(f"Lineups/{team}_lineups_{year}.csv")
    all_lineups_season = pd.read_csv(lineups_path)
    all_lineups_season = format_lineups_df(all_lineups_season, year)
    
    opponents_lineups = {}
    for opponent in opponents:
        opp_lineups_path = Path(f"Lineups/{opponent}_lineups_{year}.csv")
        opp_all_lineups_season = pd.read_csv(opp_lineups_path)
        #print(f"opp: {opponent}")
        opp_all_lineups_season = format_lineups_df(opp_all_lineups_season, year)
        opponents_lineups.update({opponent:opp_all_lineups_season})
    
    players_df = pd.DataFrame()
    
    i = 0
    for date in schedule_df["Date"]:
        
        
        adversary = schedule_df[schedule_df["Date"]==date.strftime("%Y-%m-%d")]["Opp"].values[0]

        temp_dict = {"Date":date}

        ##Line ups for the team
        try: all_players_on_date = all_lineups_season[all_lineups_season["Date"]==date.strftime("%Y-%m-%d")]
            
        except:
            print(f"No game on this date {date} for team")
            continue
            
        count = 1  
        all_players_team = all_players_on_date.iloc[0]       
        for player in all_players_team[1:]:            
            temp_dict.update({f"player_{count:02}" : player})           
            count+=1
            
        ##Line ups for the adversary
        try:
            opp_lineups_df = opponents_lineups[adversary]
            all_opponents_on_date = opp_lineups_df[opp_lineups_df["Date"]==date.strftime("%Y-%m-%d")]
            all_opponents_on_date.columns = ["Date","10","11","12","12","14","15","16","17","18"]
        except:
            print(f"No game on this date {date} for opponent")
            continue

        count = 10  
        all_players_opp = all_opponents_on_date.iloc[0]       
        for enemy in all_players_opp[1:]:            
            temp_dict.update({f"player_{count:02}" : enemy})           
            count+=1
         
              
        temp_df = pd.DataFrame(temp_dict, index =[i])
        players_df = pd.concat([players_df,temp_df], axis=0, sort = True )
        i+=1
        
    schedule_df.set_index("Date", inplace=True)
    players_df.set_index("Date", inplace=True)
    teams_df = pd.concat([schedule_df,players_df], axis=1, join="inner")
    teams_df.reset_index(inplace=True, drop=False)
    
    return teams_df

# %%
players_per_game_for_HOU_2018 = get_players_per_game(year = 2018, team = "HOU")
players_per_game_for_HOU_2018.head(20)
# Out:
# opp: KCR
# opp: DET
# opp: TBR
# opp: BOS
# opp: OAK
# opp: CHW
# opp: LAD
# opp: TOR
# opp: MIN
# opp: TEX
# opp: CLE
# opp: LAA
# opp: SDP
# opp: ARI
# opp: SFG
# opp: NYY
# opp: COL
# opp: BAL
# opp: SEA
#          Date   Tm  Home_Away  Opp      GB  Streak player_01 player_02  \
# 0  2018-03-29  HOU          1  TEX    Tied       1  Springer   Bregman
# 1  2018-03-30  HOU          1  TEX     0.5      -1  Springer   Reddick
# 2  2018-03-31  HOU          1  TEX    Tied       1  Springer   Bregman
# 3  2018-04-01  HOU          1  TEX    Tied       2  Springer   Bregman
# 4  2018-04-02  HOU          0  BAL  up 1.0       3  Springer   Bregman
# 5  2018-04-03  HOU          0  BAL  up 1.0       4  Springer   Bregman
# 6  2018-04-04  HOU          0  BAL  up 1.0       5  Springer   Bregman
# 7  2018-04-06  HOU          0  SDP    Tied      -1  Springer   Bregman
# 8  2018-04-07  HOU          0  SDP  up 1.0       1  Springer   Bregman
# 9  2018-04-08  HOU          0  SDP  up 1.0       2  Springer   Bregman
# 10 2018-04-09  HOU          1  MIN  up 1.0       3  Springer   Bregman
# 11 2018-04-10  HOU          1  MIN    Tied      -1  Springer   Bregman
# 12 2018-04-11  HOU          1  MIN     1.0      -2  Springer   Bregman
# 13 2018-04-13  HOU          0  TEX     1.5       1  Springer   Bregman
# 14 2018-04-14  HOU          0  TEX     2.5      -1  Springer   Bregman
# 15 2018-04-15  HOU          0  TEX     3.0      -2  Springer   Bregman
# 16 2018-04-16  HOU          1  SEA     3.5      -3  Springer   Bregman
# 17 2018-04-17  HOU          1  SEA     2.5       1  Springer    Altuve
# 18 2018-04-18  HOU          1  SEA     1.5       2  Springer    Altuve
# 19 2018-04-19  HOU          1  SEA     0.5       3  Springer    Altuve
#
#    player_03 player_04  ...  player_09  player_10 player_11 player_12  \
# 0     Altuve    Correa  ...     McCann  DeShields     Gallo    Andrus
# 1     Altuve    Correa  ...     Stassi  DeShields     Gallo    Andrus
# 2     Altuve    Correa  ...  Marisnick     Andrus     Gallo    Beltre
# 3     Altuve    Correa  ...     Fisher     Andrus     Gallo    Beltre
# 4     Altuve    Correa  ...     Fisher      Davis   Machado    Schoop
# 5     Altuve    Correa  ...     Fisher      Davis   Machado    Schoop
# 6     Altuve   Reddick  ...     Fisher    Beckham   Machado    Schoop
# 7     Altuve    Correa  ...     Fisher     Margot    Pirela    Hosmer
# 8     Altuve    Correa  ...  Marisnick     Pirela    Galvis    Hosmer
# 9     Altuve    Correa  ...     Fisher     Asuaje    Hosmer    Pirela
# 10    Altuve    Correa  ...     Fisher     Dozier     Mauer      Sano
# 11    Altuve    Correa  ...  Marisnick     Dozier     Mauer      Sano
# 12    Altuve    Correa  ...     Fisher     Dozier     Mauer   Rosario
# 13    Altuve    Correa  ...  Marisnick       Choo    Profar    Mazara
# 14    Altuve    Correa  ...     Stassi       Choo    Profar     Gallo
# 15    Altuve    Correa  ...     Fisher       Choo    Profar    Mazara
# 16    Altuve    Correa  ...  Marisnick     Gordon    Segura      Cano
# 17    Correa   Gurriel  ...  Marisnick     Gordon    Segura      Cano
# 18    Correa   Reddick  ...     Fisher     Gordon    Segura      Cano
# 19    Correa    Gattis  ...  Marisnick     Gordon    Segura      Cano
#
#      player_13 player_14 player_15    player_16    player_17  player_18
# 0       Beltre    Mazara      Choo     Chirinos         Odor        Rua
# 1       Beltre    Mazara      Choo     Chirinos         Odor        Rua
# 2       Mazara      Choo      Odor      Centeno     Robinson      Tocci
# 3       Mazara  Chirinos      Odor          Rua       Profar   Robinson
# 4        Jones   Mancini    Rasmus      Beckham      Alvarez     Joseph
# 5        Jones   Mancini    Rasmus      Beckham        Sisco  Santander
# 6        Jones   Mancini  Valencia    Santander       Joseph     Gentry
# 7   Villanueva   Renfroe    Asuaje       Galvis  Spangenberg     Hedges
# 8   Villanueva    Asuaje   Renfroe  Spangenberg        Ellis     Margot
# 9   Villanueva   Headley   Renfroe       Galvis       Hedges     Margot
# 10     Rosario  Morrison   Escobar       Kepler       Buxton     Castro
# 11     Escobar  Grossman  Morrison       Garver       Buxton    LaMarre
# 12    Morrison   Escobar    Kepler       Buxton       Castro   Adrianza
# 13      Beltre     Gallo    Guzman     Chirinos     Robinson      Kiner
# 14      Beltre    Guzman       Rua      Centeno        Kiner   Robinson
# 15      Beltre     Gallo    Guzman     Chirinos        Kiner      Tocci
# 16        Cruz    Seager   Haniger      Heredia       Motter    Freitas
# 17        Cruz    Seager   Haniger    Vogelbach       Suzuki    Marjama
# 18        Cruz    Seager   Haniger        Gamel    Vogelbach    Freitas
# 19        Cruz    Seager   Haniger        Gamel    Vogelbach    Freitas
#
# [20 rows x 24 columns]

# %%
x = players_per_game_for_HOU_2018.iloc[0][3]
x
# Out:
# 'TEX'

# %%
def get_col_explanation(col1,col2):
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    try: col1 = [x.split("_")[1] for x in col1 if x is not "index"]
    except: pass
    try: col2 = [x.split("_")[1] for x in col2 if x is not "index"]
    except: pass   
    print(f"column 1: {col1[:10]}\ncolumn2: {col2[:10]}")
    if(len(col1)>len(col2)):missing_col = list(set(col1).difference(set(col2)))
    else:missing_col = list(set(col2).difference(set(col1)))
    return missing_col

# %%
get_col_explanation(["1_a","222_b","2_c"],["222_b","1_c"])
# Out:
# column 1: ['1_a', '222_b', '2_c']
# column2: ['222_b', '1_c']
# column 1: ['a', 'b', 'c']
# column2: ['b', 'c']
# ['a']

# %%
type(players_per_game_for_HOU_2018.columns)
# Out:
# pandas.core.indexes.base.Index

# %%
def stats_single_game_x_team(players=None, team=None, stats_df=None, counter=1, pitching_stats = False):
    
    all_players_team_stats = pd.DataFrame()
    
    for player in players:

            if("00:00:00" in str(player)): continue #If it's a date, Skip it.
                
            try: 
                all_team_stats = stats_df[stats_df.Team==get_key_from_dict( team_dict ,team )]
                player_full_name = [x for x in all_team_stats.Name if player in x]
                player_stats = all_team_stats[all_team_stats.Name==player_full_name[0]]
              
            except: 
                print(f"{player} not in batting list")
                
                try:
                    nanlist = np.empty((1,len(player_stats.columns)))
                except Exception as e:
                    print(f"Not able to get columns from last player\n{e}")
                    continue
                nanlist.fill(np.nan)
                fake_columns = []
                for col in player_stats.columns:
                    try: fake_columns.append(col.split("_")[1])
                    except: fake_columns.append(col)
                player_stats = pd.DataFrame(data = nanlist, columns = fake_columns)
                player_stats.drop(columns=["index"], inplace=True)
                
            new_col = []
            for col in player_stats.columns:
                new_col.append(f"{counter:02}_{col}")
            player_stats.columns = new_col
            player_stats.reset_index(inplace=True)
            all_players_team_stats = pd.concat([ all_players_team_stats, player_stats ] ,   axis=1)
            
            counter+=1
            
    return all_players_team_stats

# %%
def get_stats_startingplayer_by_game(players_df, team, year):
    
    batting_season_data = batting_stats(year-1)   
    pitching_season_data = pitching_stats(year)
    #print(pitching_season_data.head()) 
    
    stats_players_start_lineup = pd.DataFrame()
    
    for row in range(0,len(players_df)):
        
        all_players_stats = pd.DataFrame()
        
        all_players_team_stats = stats_single_game_x_team(players = players_df.iloc[row][6:15], 
                                                                  team = team, 
                                                                  stats_df = batting_season_data)
        
        all_players_opp_stats = stats_single_game_x_team(players = players_df.iloc[row][15:24], 
                                                                  team = players_df.iloc[row][3], 
                                                                  stats_df = batting_season_data,
                                                                  counter = 10)           
        try:
            all_players_stats = pd.concat([ all_players_team_stats, all_players_opp_stats] ,   axis=1)    
        except Exception as e: 
            print(f"could not concatenate team with opponent stats\n{e}")
            continue
            
        try: 
            stats_players_start_lineup = stats_players_start_lineup.append(all_players_stats, ignore_index=True)
        except Exception as e: 
            print(f"could not append {e}")
            print(f"explanation: \n{get_col_explanation(stats_players_start_lineup.columns,all_players_stats.columns)}")
            
            continue
        
    
    return stats_players_start_lineup

# %%
test = get_stats_startingplayer_by_game(players_per_game_for_HOU_2018, "HOU", 2018)
test
# Out:
# Machado not in batting list
# Schoop not in batting list
# Machado not in batting list
# Schoop not in batting list
# Machado not in batting list
# Schoop not in batting list
# Dozier not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Escobar not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Dozier not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Escobar not in batting list
# LaMarre not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Dozier not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Escobar not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Motter not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Delmonico not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Castillo not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Narvaez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Castillo not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Thompson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Delmonico not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Castillo not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Maldonado not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Maldonado not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Rivera not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Maldonado not in batting list
# Kinsler not in batting list
# Rivera not in batting list
# Kinsler not in batting list
# Maldonado not in batting list
# McCutchen not in batting list
# Jackson not in batting list
# McCutchen not in batting list
# Federowicz not in batting list
# Federowicz not in batting list
# Span not in batting list
# Moustakas not in batting list
# Moustakas not in batting list
# Butera not in batting list
# Moustakas not in batting list
# Ramos not in batting list
# Field not in batting list
# Ramos not in batting list
# Hechavarria not in batting list
# Hechavarria not in batting list
# Ramos not in batting list
# Field not in batting list
# Herrera not in batting list
# Moustakas not in batting list
# Herrera not in batting list
# Moustakas not in batting list
# Duda not in batting list
# Herrera not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Moustakas not in batting list
# Duda not in batting list
# Butera not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Granderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Granderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Pearce not in batting list
# Ramos not in batting list
# Ramos not in batting list
# Hechavarria not in batting list
# Ramos not in batting list
# Hechavarria not in batting list
# Field not in batting list
# Federowicz not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Palka not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Narvaez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Federowicz not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Palka not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Smith not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Palka not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Narvaez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Smith not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Federowicz not in batting list
# Federowicz not in batting list
# Federowicz not in batting list
# Kinsler not in batting list
# Maldonado not in batting list
# Kinsler not in batting list
# Maldonado not in batting list
# Federowicz not in batting list
# Kinsler not in batting list
# Maldonado not in batting list
# Span not in batting list
# Maldonado not in batting list
# Span not in batting list
# Maybin not in batting list
# Maldonado not in batting list
# Machado not in batting list
# Maldonado not in batting list
# Machado not in batting list
# Dozier not in batting list
# Machado not in batting list
# Dozier not in batting list
# Maldonado not in batting list
# McCutchen not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# McCutchen not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Span not in batting list
# Maybin not in batting list
# Maldonado not in batting list
# Span not in batting list
# Maybin not in batting list
# Span not in batting list
# Maldonado not in batting list
# Maybin not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Span not in batting list
# Span not in batting list
# Maldonado not in batting list
# Span not in batting list
# Maldonado not in batting list
# Rivera not in batting list
# Maldonado not in batting list
# Rivera not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Forsythe not in batting list
# Austin not in batting list
# Field not in batting list
# Maldonado not in batting list
# Forsythe not in batting list
# Gimenez not in batting list
# Forsythe not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Austin not in batting list
# Field not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Kinsler not in batting list
# Maldonado not in batting list
# Kinsler not in batting list
# Pearce not in batting list
# Kinsler not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Escobar not in batting list
# Escobar not in batting list
# Maldonado not in batting list
# Jay not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# Escobar not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Maybin not in batting list
# Span not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# Maldonado not in batting list
# McKinney not in batting list
# McKinney not in batting list
# Not able to get columns from last player
# local variable 'player_bat_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Villar not in batting list
# Peterson not in batting list
# Maldonado not in batting list
# Villar not in batting list
# Nunez not in batting list
# Maldonado not in batting list
# Villar not in batting list
# Nunez not in batting list
# Villar not in batting list
# Nunez not in batting list
#      index  01_Season          01_Name 01_Team  01_Age   01_G  01_AB  01_PA  \
# 0      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 1      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 2      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 3      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 4      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 5      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 6      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 7      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 8      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 9      168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 10     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 11     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 12     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 13     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 14     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 15     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 16     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 17     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 18     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 19     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 20     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 21     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 22     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 23     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 24     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 25     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 26     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 27     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 28     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 29     168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# ..     ...        ...              ...     ...     ...    ...    ...    ...
# 111     40     2018.0     Alex Bregman  Astros    24.0  157.0  594.0  705.0
# 112    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 113    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 114    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 115    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 116    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 117    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 118    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 119    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 120    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 121    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 122    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 123    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 124    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 125     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 126    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 127    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 128    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 129    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 130    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 131    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 132    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 133    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 134     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 135    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 136    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 137     84     2018.0      Jose Altuve  Astros    28.0  137.0  534.0  599.0
# 138    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 139    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
# 140    168     2018.0  George Springer  Astros    28.0  140.0  544.0  620.0
#
#       01_H  01_1B  ...  18_wSL/C (pi)  18_wXX/C (pi)  18_O-Swing% (pi)  \
# 0    144.0   96.0  ...          -2.27            NaN             0.341
# 1    144.0   96.0  ...          -2.27            NaN             0.341
# 2    144.0   96.0  ...          -3.10            NaN             0.356
# 3    144.0   96.0  ...           0.69            NaN             0.276
# 4    144.0   96.0  ...          -3.74            NaN             0.410
# 5    144.0   96.0  ...           1.72            NaN             0.390
# 6    144.0   96.0  ...           2.51            NaN             0.224
# 7    144.0   96.0  ...           0.37            NaN             0.352
# 8    144.0   96.0  ...          -0.03            NaN             0.273
# 9    144.0   96.0  ...          -0.03            NaN             0.273
# 10   144.0   96.0  ...          -0.64            NaN             0.247
# 11   144.0   96.0  ...           0.69            NaN             0.276
# 12   144.0   96.0  ...          -3.10            NaN             0.356
# 13   144.0   96.0  ...          -2.07            NaN             0.249
# 14   144.0   96.0  ...         -10.55            NaN             0.308
# 15   144.0   96.0  ...          -2.07            NaN             0.249
# 16   144.0   96.0  ...          -2.07            NaN             0.249
# 17   144.0   96.0  ...          -1.72            NaN             0.309
# 18   144.0   96.0  ...          -7.07            NaN             0.267
# 19   144.0   96.0  ...          -1.72            NaN             0.309
# 20   144.0   96.0  ...          -1.32            NaN             0.344
# 21   144.0   96.0  ...          -0.65            NaN             0.337
# 22   144.0   96.0  ...          -0.65            NaN             0.337
# 23   144.0   96.0  ...          -0.65            NaN             0.337
# 24   144.0   96.0  ...            NaN            NaN               NaN
# 25   144.0   96.0  ...          -4.52            NaN             0.402
# 26   144.0   96.0  ...          -3.18            NaN             0.200
# 27   144.0   96.0  ...           2.13            NaN             0.317
# 28   144.0   96.0  ...          -7.07            NaN             0.267
# 29   144.0   96.0  ...          -0.25            NaN             0.282
# ..     ...    ...  ...            ...            ...               ...
# 111  170.0   87.0  ...           0.35            NaN             0.291
# 112  144.0   96.0  ...          -1.32            NaN             0.273
# 113  144.0   96.0  ...          -1.72            NaN             0.309
# 114  144.0   96.0  ...           0.11            NaN             0.343
# 115  144.0   96.0  ...           2.88            NaN             0.352
# 116  144.0   96.0  ...          -1.10            NaN             0.434
# 117  144.0   96.0  ...           0.35            NaN             0.291
# 118  144.0   96.0  ...           0.35            NaN             0.291
# 119  144.0   96.0  ...            NaN            NaN               NaN
# 120  144.0   96.0  ...            NaN            NaN               NaN
# 121  144.0   96.0  ...          -1.38            NaN             0.273
# 122  144.0   96.0  ...          -1.38            NaN             0.273
# 123  144.0   96.0  ...           0.56            NaN             0.347
# 124  144.0   96.0  ...          -0.33            NaN             0.388
# 125  169.0  125.0  ...          -0.33            NaN             0.388
# 126  144.0   96.0  ...          -1.74            NaN             0.480
# 127  144.0   96.0  ...          -1.18            NaN             0.267
# 128  144.0   96.0  ...          -4.32            NaN             0.171
# 129  144.0   96.0  ...          -1.39            NaN             0.410
# 130  144.0   96.0  ...          -1.39            NaN             0.410
# 131  144.0   96.0  ...          -1.39            NaN             0.410
# 132  144.0   96.0  ...          -1.49            NaN             0.239
# 133  144.0   96.0  ...          -1.10            NaN             0.434
# 134  169.0  125.0  ...          -7.70            NaN             0.235
# 135  144.0   96.0  ...           2.92            NaN             0.404
# 136  144.0   96.0  ...           2.92            NaN             0.404
# 137  169.0  125.0  ...          -5.73            NaN             0.322
# 138  144.0   96.0  ...          -3.74            NaN             0.410
# 139  144.0   96.0  ...          -3.74            NaN             0.410
# 140  144.0   96.0  ...          -3.74            NaN             0.410
#
#      18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  18_Z-Contact% (pi)  \
# 0               0.621           0.475               0.552               0.754
# 1               0.621           0.475               0.552               0.754
# 2               0.562           0.454               0.616               0.929
# 3               0.628           0.441               0.538               0.757
# 4               0.618           0.507               0.438               0.905
# 5               0.661           0.507               0.677               0.846
# 6               0.673           0.450               0.569               0.882
# 7               0.627           0.490               0.544               0.843
# 8               0.629           0.460               0.605               0.882
# 9               0.629           0.460               0.605               0.882
# 10              0.567           0.410               0.652               0.945
# 11              0.628           0.441               0.538               0.757
# 12              0.562           0.454               0.616               0.929
# 13              0.728           0.489               0.706               0.833
# 14              0.692           0.500               0.438               0.833
# 15              0.728           0.489               0.706               0.833
# 16              0.728           0.489               0.706               0.833
# 17              0.550           0.436               0.783               0.931
# 18              0.658           0.468               0.643               0.836
# 19              0.550           0.436               0.783               0.931
# 20              0.671           0.495               0.584               0.870
# 21              0.662           0.486               0.554               0.802
# 22              0.662           0.486               0.554               0.802
# 23              0.662           0.486               0.554               0.802
# 24              0.667           0.667                 NaN               0.000
# 25              0.614           0.520               0.634               0.885
# 26              0.436           0.330               0.222               0.708
# 27              0.592           0.449               0.462               0.911
# 28              0.658           0.468               0.643               0.836
# 29              0.616           0.440               0.719               0.866
# ..                ...             ...                 ...                 ...
# 111             0.688           0.494               0.548               0.831
# 112             0.592           0.424               0.485               0.852
# 113             0.550           0.436               0.783               0.931
# 114             0.592           0.461               0.643               0.853
# 115             0.664           0.492               0.527               0.739
# 116             0.718           0.566               0.545               0.788
# 117             0.688           0.494               0.548               0.831
# 118             0.688           0.494               0.548               0.831
# 119               NaN             NaN                 NaN                 NaN
# 120               NaN             NaN                 NaN                 NaN
# 121             0.678           0.471               0.543               0.789
# 122             0.678           0.471               0.543               0.789
# 123             0.604           0.468               0.653               0.870
# 124             0.649           0.512               0.533               0.833
# 125             0.649           0.512               0.533               0.833
# 126             0.704           0.587               0.766               0.850
# 127             0.628           0.440               0.508               0.791
# 128             0.527           0.351               0.369               0.761
# 129             0.665           0.537               0.745               0.924
# 130             0.665           0.537               0.745               0.924
# 131             0.665           0.537               0.745               0.924
# 132             0.554           0.396               0.536               0.881
# 133             0.718           0.566               0.545               0.788
# 134             0.500           0.378               0.500               0.700
# 135             0.718           0.552               0.591               0.764
# 136             0.718           0.552               0.591               0.764
# 137             0.594           0.453               0.568               0.882
# 138             0.618           0.507               0.438               0.905
# 139             0.618           0.507               0.438               0.905
# 140             0.618           0.507               0.438               0.905
#
#      18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0               0.679          0.478          23.5
# 1               0.679          0.478          23.5
# 2               0.799          0.473          24.6
# 3               0.684          0.470          26.2
# 4               0.703          0.466          23.2
# 5               0.772          0.431          25.0
# 6               0.805          0.504          23.7
# 7               0.735          0.500          24.3
# 8               0.804          0.525          22.0
# 9               0.804          0.525          22.0
# 10              0.858          0.510          22.4
# 11              0.684          0.470          26.2
# 12              0.799          0.473          24.6
# 13              0.801          0.501          25.9
# 14              0.712          0.500          21.3
# 15              0.801          0.501          25.9
# 16              0.801          0.501          25.9
# 17              0.881          0.525          24.8
# 18              0.782          0.514          22.6
# 19              0.881          0.525          24.8
# 20              0.763          0.460          24.7
# 21              0.709          0.457          23.5
# 22              0.709          0.457          23.5
# 23              0.709          0.457          23.5
# 24              0.000          1.000          13.0
# 25              0.798          0.555          22.8
# 26              0.576          0.550          16.7
# 27              0.747          0.481          22.2
# 28              0.782          0.514          22.6
# 29              0.816          0.472          26.9
# ..                ...            ...           ...
# 111             0.750          0.513          23.9
# 112             0.729          0.476          22.8
# 113             0.881          0.525          24.8
# 114             0.771          0.474          25.7
# 115             0.655          0.448          23.8
# 116             0.688          0.464          26.9
# 117             0.750          0.513          23.9
# 118             0.750          0.513          23.9
# 119               NaN            NaN           NaN
# 120               NaN            NaN           NaN
# 121             0.715          0.487          23.6
# 122             0.715          0.487          23.6
# 123             0.785          0.471          23.3
# 124             0.713          0.473          22.9
# 125             0.713          0.473          22.9
# 126             0.814          0.477          23.0
# 127             0.701          0.478          24.5
# 128             0.667          0.505          27.5
# 129             0.855          0.497          22.9
# 130             0.855          0.497          22.9
# 131             0.855          0.497          22.9
# 132             0.777          0.500          23.1
# 133             0.688          0.464          26.9
# 134             0.643          0.541          21.0
# 135             0.697          0.472          23.2
# 136             0.697          0.472          23.2
# 137             0.766          0.482          24.1
# 138             0.703          0.466          23.2
# 139             0.703          0.466          23.2
# 140             0.703          0.466          23.2
#
# [141 rows x 5184 columns]

# %%
def create_trining_df(year = (dt.datetime.today().year-1), team = "HOU" ):
                       
    
    players_df = get_players_per_game(year, team)
    #print(players_df.tail(10))    
    stats_players_start_lineup = get_stats_startingplayer_by_game(players_df, team, year)
    
    return pd.concat([players_df.iloc[:,[0,1,2,3,4,5]],stats_players_start_lineup], axis=1, join='inner')
       
    
    
    
    #dates_played = get_dates_played(last_season_games_played, year)

# %%
stats_players_start_lineup = create_trining_df()
stats_players_start_lineup
# Out:
# Centeno not in batting list
# Tocci not in batting list
# Rasmus not in batting list
# Beckham not in batting list
# Rasmus not in batting list
# Beckham not in batting list
# Beckham not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Valencia not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Hosmer not in batting list
# Galvis not in batting list
# Galvis not in batting list
# Hosmer not in batting list
# Ellis not in batting list
# Hosmer not in batting list
# Headley not in batting list
# Galvis not in batting list
# Morrison not in batting list
# Morrison not in batting list
# LaMarre not in batting list
# Morrison not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Guzman not in batting list
# Centeno not in batting list
# Kiner not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Tocci not in batting list
# Freitas not in batting list
# Suzuki not in batting list
# Freitas not in batting list
# Freitas not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Delmonico not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Castillo not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Narvaez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Castillo not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Thompson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Delmonico not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Castillo not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Upton not in batting list
# Cozart not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Upton not in batting list
# Cozart not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Kinsler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Upton not in batting list
# Cozart not in batting list
# Rivera not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Piscotty not in batting list
# Lucroy not in batting list
# Piscotty not in batting list
# Piscotty not in batting list
# Lucroy not in batting list
# Stanton not in batting list
# Walker not in batting list
# Torres not in batting list
# Stanton not in batting list
# Torres not in batting list
# Stanton not in batting list
# Torres not in batting list
# Stanton not in batting list
# Walker not in batting list
# Torres not in batting list
# Cole not in batting list
# Dyson not in batting list
# Avila not in batting list
# Medlen not in batting list
# Souza not in batting list
# Verlander not in batting list
# Souza not in batting list
# Avila not in batting list
# Koch not in batting list
# Lucroy not in batting list
# Piscotty not in batting list
# Lucroy not in batting list
# Piscotty not in batting list
# Guzman not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Cozart not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Upton not in batting list
# Kinsler not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Ohtani not in batting list
# Upton not in batting list
# Kinsler not in batting list
# Rivera not in batting list
# Ohtani not in batting list
# Upton not in batting list
# Cozart not in batting list
# Kinsler not in batting list
# Alonso not in batting list
# Davis not in batting list
# Davis not in batting list
# Alonso not in batting list
# Cabrera not in batting list
# McCutchen not in batting list
# Longoria not in batting list
# Sandoval not in batting list
# Jackson not in batting list
# McCutchen not in batting list
# Longoria not in batting list
# Sandoval not in batting list
# Alonso not in batting list
# Cabrera not in batting list
# Cabrera not in batting list
# Davis not in batting list
# Alonso not in batting list
# Cabrera not in batting list
# Alonso not in batting list
# Cabrera not in batting list
# Torres not in batting list
# Walker not in batting list
# Stanton not in batting list
# Torres not in batting list
# Stanton not in batting list
# Torres not in batting list
# Federowicz not in batting list
# Martinez not in batting list
# Martinez not in batting list
# Nunez not in batting list
# Martinez not in batting list
# Nunez not in batting list
# Martinez not in batting list
# Nunez not in batting list
# Healy not in batting list
# Federowicz not in batting list
# Healy not in batting list
# Span not in batting list
# Kiner not in batting list
# Guzman not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Guzman not in batting list
# Fowler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Fowler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Fowler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Dozier not in batting list
# Almonte not in batting list
# Dozier not in batting list
# Almonte not in batting list
# Goins not in batting list
# Dozier not in batting list
# Goins not in batting list
# Almonte not in batting list
# Duffy not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Bauers not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Cron not in batting list
# Wendle not in batting list
# Adames not in batting list
# Gomez not in batting list
# Field not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Duffy not in batting list
# Bauers not in batting list
# Wendle not in batting list
# Cron not in batting list
# Gomez not in batting list
# Hechavarria not in batting list
# Hechavarria not in batting list
# Bauers not in batting list
# Wendle not in batting list
# Adames not in batting list
# Gomez not in batting list
# Field not in batting list
# Herrera not in batting list
# Dozier not in batting list
# Herrera not in batting list
# Duda not in batting list
# Dozier not in batting list
# Goins not in batting list
# Herrera not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Duda not in batting list
# Dozier not in batting list
# Almonte not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Granderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Hernandez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Solarte not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Grichuk not in batting list
# Diaz not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Granderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Hernandez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Solarte not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Grichuk not in batting list
# Diaz not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Grichuk not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Hernandez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Solarte not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Diaz not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Duffy not in batting list
# Bauers not in batting list
# Wendle not in batting list
# Cron not in batting list
# Gomez not in batting list
# Adames not in batting list
# Duffy not in batting list
# Bauers not in batting list
# Wendle not in batting list
# Hechavarria not in batting list
# Adames not in batting list
# Duffy not in batting list
# Bauers not in batting list
# Wendle not in batting list
# Cron not in batting list
# Gomez not in batting list
# Hechavarria not in batting list
# Wendle not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Duffy not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Bauers not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Gomez not in batting list
# Adames not in batting list
# Field not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Guzman not in batting list
# Federowicz not in batting list
# Guzman not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Palka not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Narvaez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Federowicz not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Palka not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Smith not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Palka not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Narvaez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Anderson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Abreu not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Davidson not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Smith not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Garcia not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Moncada not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Sanchez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Engel not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Federowicz not in batting list
# Fowler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Fowler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Federowicz not in batting list
# Fowler not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Martini not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Goodrum not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Rodriguez not in batting list
# Candelario not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Federowicz not in batting list
# Goodrum not in batting list
# Candelario not in batting list
# Reyes not in batting list
# Goodrum not in batting list
# Rodriguez not in batting list
# Candelario not in batting list
# Reyes not in batting list
# Tucker not in batting list
# Fletcher not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Upton not in batting list
# Ohtani not in batting list
# Kinsler not in batting list
# Blash not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Upton not in batting list
# Ohtani not in batting list
# Kinsler not in batting list
# Fletcher not in batting list
# Federowicz not in batting list
# Upton not in batting list
# Ohtani not in batting list
# Kinsler not in batting list
# Briceno not in batting list
# Fletcher not in batting list
# Cole not in batting list
# Hampson not in batting list
# Iannetta not in batting list
# Tucker not in batting list
# Hampson not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Tocci not in batting list
# Tucker not in batting list
# Guzman not in batting list
# Kiner not in batting list
# Tocci not in batting list
# Maldonado not in batting list
# Kiner not in batting list
# Guzman not in batting list
# Span not in batting list
# Healy not in batting list
# Romine not in batting list
# Maldonado not in batting list
# Span not in batting list
# Herrmann not in batting list
# Healy not in batting list
# Romine not in batting list
# Maybin not in batting list
# Romine not in batting list
# Vincej not in batting list
# Maldonado not in batting list
# Verlander not in batting list
# Machado not in batting list
# Kemp not in batting list
# Muncy not in batting list
# Maldonado not in batting list
# Machado not in batting list
# Kemp not in batting list
# Dozier not in batting list
# Cole not in batting list
# Machado not in batting list
# Dozier not in batting list
# Muncy not in batting list
# Buehler not in batting list
# Maldonado not in batting list
# McCutchen not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Longoria not in batting list
# Duggar not in batting list
# Rodriguez not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# McCutchen not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Longoria not in batting list
# d'Arnaud not in batting list
# Duggar not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Span not in batting list
# Healy not in batting list
# Maybin not in batting list
# Maldonado not in batting list
# Span not in batting list
# Healy not in batting list
# Maybin not in batting list
# Span not in batting list
# Herrmann not in batting list
# Healy not in batting list
# Tucker not in batting list
# Maldonado not in batting list
# Maybin not in batting list
# Healy not in batting list
# Romine not in batting list
# Tucker not in batting list
# Maldonado not in batting list
# Dahl not in batting list
# Iannetta not in batting list
# Maldonado not in batting list
# Martini not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Piscotty not in batting list
# Laureano not in batting list
# Maldonado not in batting list
# Martini not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Span not in batting list
# Span not in batting list
# Healy not in batting list
# Herrmann not in batting list
# Maldonado not in batting list
# Span not in batting list
# Healy not in batting list
# Maldonado not in batting list
# Fletcher not in batting list
# Rivera not in batting list
# Ward not in batting list
# Maldonado not in batting list
# Fletcher not in batting list
# Ohtani not in batting list
# Arcia not in batting list
# Ward not in batting list
# Fletcher not in batting list
# Rivera not in batting list
# Ward not in batting list
# Maldonado not in batting list
# Martini not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Lucroy not in batting list
# Laureano not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Martini not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Piscotty not in batting list
# Laureano not in batting list
# Lucroy not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Piscotty not in batting list
# Laureano not in batting list
# Maldonado not in batting list
# Fletcher not in batting list
# Upton not in batting list
# Ohtani not in batting list
# Arcia not in batting list
# Ward not in batting list
# Maldonado not in batting list
# Fletcher not in batting list
# Upton not in batting list
# Ohtani not in batting list
# Ward not in batting list
# Briceno not in batting list
# Fletcher not in batting list
# Upton not in batting list
# Fernandez not in batting list
# Ward not in batting list
# Arcia not in batting list
# Maldonado not in batting list
# Fletcher not in batting list
# Fernandez not in batting list
# Ward not in batting list
# Arcia not in batting list
# Forsythe not in batting list
# Cave not in batting list
# Austin not in batting list
# Field not in batting list
# Maldonado not in batting list
# Forsythe not in batting list
# Cave not in batting list
# Forsythe not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Austin not in batting list
# Astudillo not in batting list
# Field not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Martinez not in batting list
# Kinsler not in batting list
# Nunez not in batting list
# Maldonado not in batting list
# Martinez not in batting list
# Kinsler not in batting list
# Martinez not in batting list
# Pearce not in batting list
# Kinsler not in batting list
# Phillips not in batting list
# Nunez not in batting list
# Maldonado not in batting list
# Candelario not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Stewart not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Goodrum not in batting list
# Rodriguez not in batting list
# Lugo not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Candelario not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Stewart not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Goodrum not in batting list
# Greiner not in batting list
# Rodriguez not in batting list
# Lugo not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Candelario not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Stewart not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Goodrum not in batting list
# Lugo not in batting list
# Reyes not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Escobar not in batting list
# Souza not in batting list
# Escobar not in batting list
# Souza not in batting list
# Avila not in batting list
# Maldonado not in batting list
# Jay not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Escobar not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Healy not in batting list
# Maybin not in batting list
# Span not in batting list
# Herrmann not in batting list
# Maldonado not in batting list
# Healy not in batting list
# Maldonado not in batting list
# Fernandez not in batting list
# Ohtani not in batting list
# Upton not in batting list
# Arcia not in batting list
# Ward not in batting list
# Fernandez not in batting list
# Ohtani not in batting list
# Upton not in batting list
# Ward not in batting list
# Briceno not in batting list
# Maldonado not in batting list
# Upton not in batting list
# Ohtani not in batting list
# Arcia not in batting list
# Hermosillo not in batting list
# Johnson not in batting list
# Davis not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Gurriel not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Grichuk not in batting list
# Diaz not in batting list
# Hernandez not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Davis not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# McKinney not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Tellez not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Solarte not in batting list
# Diaz not in batting list
# Jansen not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Tucker not in batting list
# Straw not in batting list
# McKinney not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Grichuk not in batting list
# Tellez not in batting list
# Diaz not in batting list
# McGuire not in batting list
# Berti not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# column2: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# explanation:
# []
# Maldonado not in batting list
# Mullins not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Villar not in batting list
# Not able to get columns from last player
# local variable 'player_stats' referenced before assignment
# Stewart not in batting list
# Wilkerson not in batting list
# Peterson not in batting list
# Wynns not in batting list
# could not append Plan shapes are not aligned
# column 1: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column2: Index(['index', '01_Season', '01_Name', '01_Team', '01_Age', '01_G', '01_AB',
#        '01_PA', '01_H', '01_1B'],
#       dtype='object')
# column 1: ['Season', 'Name', 'Team', 'Age', 'G', 'AB', 'PA', 'H', '1B', '2B']
# ...
# 29  2018-04-30  HOU          0  NYY  up 2.5       3     79     2017.0
# ..         ...  ...        ...  ...     ...     ...    ...        ...
# 87  2018-07-04  HOU          1  TEX  up 1.5       2    597     2017.0
# 88  2018-07-05  HOU          0  CHW  up 1.5       3    597     2017.0
# 89  2018-07-06  HOU          0  CHW  up 2.5       4    597     2017.0
# 90  2018-07-07  HOU          0  CHW  up 3.5       5    597     2017.0
# 91  2018-07-08  HOU          0  CHW  up 3.5       6    138     2017.0
# 92  2018-07-09  HOU          0  OAK  up 3.0      -1     79     2017.0
# 93  2018-07-10  HOU          0  OAK  up 4.0       1    138     2017.0
# 94  2018-07-11  HOU          0  OAK  up 3.0      -1    138     2017.0
# 95  2018-07-12  HOU          0  OAK  up 3.0      -2    138     2017.0
# 96  2018-07-13  HOU          0  DET  up 4.0       1    138     2017.0
# 97  2018-07-14  HOU          0  DET  up 5.0       2    138     2017.0
# 98  2018-07-15  HOU          0  DET  up 5.0      -1    138     2017.0
# 99  2018-07-20  HOU          1  LAA  up 5.0       1     79     2017.0
# 100 2018-07-21  HOU          1  LAA  up 6.0       2     79     2017.0
# 101 2018-07-22  HOU          1  LAA  up 5.0      -1     79     2017.0
# 102 2018-07-24  HOU          1  COL  up 6.0       1     79     2017.0
# 103 2018-07-25  HOU          1  COL  up 5.0      -1     79     2017.0
# 104 2018-07-27  HOU          0  TEX  up 5.0      -2     79     2017.0
# 105 2018-07-28  HOU          0  TEX  up 5.0      -3     79     2017.0
# 106 2018-07-29  HOU          0  TEX  up 4.0      -4     79     2017.0
# 107 2018-07-30  HOU          1  SEA  up 3.0      -5     79     2017.0
# 108 2018-07-31  HOU          1  SEA  up 4.0       1     79     2017.0
# 109 2018-08-01  HOU          1  SEA  up 5.0       2     79     2017.0
# 110 2018-08-03  HOU          1  LAD  up 5.0       3     79     2017.0
# 111 2018-08-04  HOU          1  LAD  up 5.0       4     79     2017.0
# 112 2018-08-05  HOU          1  LAD  up 4.0      -1     79     2017.0
# 113 2018-08-06  HOU          1  SFG  up 4.5       1     79     2017.0
# 114 2018-08-07  HOU          1  SFG  up 5.5       2     79     2017.0
# 115 2018-08-09  HOU          0  SEA  up 4.5      -1     79     2017.0
# 116 2018-08-10  HOU          0  SEA  up 4.5      -2     48     2017.0
#
#              01_Name 01_Team  ...  18_wSL/C (pi)  18_wXX/C (pi)  \
# 0    George Springer  Astros  ...          -0.41          -5.21
# 1    George Springer  Astros  ...          -0.41          -5.21
# 2    George Springer  Astros  ...            NaN            NaN
# 3    George Springer  Astros  ...           0.33            NaN
# 4    George Springer  Astros  ...          -0.55            NaN
# 5    George Springer  Astros  ...          -4.53            NaN
# 6    George Springer  Astros  ...          -3.61            NaN
# 7    George Springer  Astros  ...          -0.13            NaN
# 8    George Springer  Astros  ...          -0.13            NaN
# 9    George Springer  Astros  ...          -1.48          -4.27
# 10   George Springer  Astros  ...            NaN            NaN
# 11   George Springer  Astros  ...          -2.04            NaN
# 12   George Springer  Astros  ...            NaN            NaN
# 13   George Springer  Astros  ...           0.33            NaN
# 14   George Springer  Astros  ...            NaN            NaN
# 15   George Springer  Astros  ...            NaN            NaN
# 16   George Springer  Astros  ...         -10.35            NaN
# 17   George Springer  Astros  ...            NaN            NaN
# 18   George Springer  Astros  ...            NaN            NaN
# 19   George Springer  Astros  ...            NaN            NaN
# 20   George Springer  Astros  ...           3.61            NaN
# 21   George Springer  Astros  ...            NaN            NaN
# 22   George Springer  Astros  ...          -1.69            NaN
# 23   George Springer  Astros  ...            NaN            NaN
# 24   George Springer  Astros  ...            NaN            NaN
# 25   George Springer  Astros  ...            NaN            NaN
# 26   George Springer  Astros  ...            NaN            NaN
# 27   George Springer  Astros  ...          -4.69            NaN
# 28   George Springer  Astros  ...            NaN            NaN
# 29   George Springer  Astros  ...          -7.12            NaN
# ..               ...     ...  ...            ...            ...
# 87         Tony Kemp  Astros  ...          -4.01            NaN
# 88         Tony Kemp  Astros  ...           1.81            NaN
# 89         Tony Kemp  Astros  ...            NaN            NaN
# 90         Tony Kemp  Astros  ...          -1.00            NaN
# 91      Alex Bregman  Astros  ...            NaN            NaN
# 92   George Springer  Astros  ...          -0.80            NaN
# 93      Alex Bregman  Astros  ...          -4.01            NaN
# 94      Alex Bregman  Astros  ...          -4.01            NaN
# 95      Alex Bregman  Astros  ...          -4.01            NaN
# 96      Alex Bregman  Astros  ...           7.12            NaN
# 97      Alex Bregman  Astros  ...           7.12            NaN
# 98      Alex Bregman  Astros  ...           7.12            NaN
# 99   George Springer  Astros  ...          -0.80            NaN
# 100  George Springer  Astros  ...          -2.81            NaN
# 101  George Springer  Astros  ...            NaN            NaN
# 102  George Springer  Astros  ...           7.12            NaN
# 103  George Springer  Astros  ...           7.12            NaN
# 104  George Springer  Astros  ...            NaN            NaN
# 105  George Springer  Astros  ...           0.61            NaN
# 106  George Springer  Astros  ...           0.08         -26.29
# 107  George Springer  Astros  ...           0.08         -26.29
# 108  George Springer  Astros  ...          -1.83            NaN
# 109  George Springer  Astros  ...          -2.69           3.90
# 110  George Springer  Astros  ...            NaN            NaN
# 111  George Springer  Astros  ...          -4.01            NaN
# 112  George Springer  Astros  ...          -4.01            NaN
# 113  George Springer  Astros  ...          -4.01            NaN
# 114  George Springer  Astros  ...            NaN            NaN
# 115  George Springer  Astros  ...            NaN            NaN
# 116      Jose Altuve  Astros  ...            NaN            NaN
#
#      18_O-Swing% (pi)  18_Z-Swing% (pi)  18_Swing% (pi)  18_O-Contact% (pi)  \
# 0               0.346             0.608           0.461               0.509
# 1               0.346             0.608           0.461               0.509
# 2                 NaN               NaN             NaN                 NaN
# 3               0.274             0.628           0.434               0.560
# 4               0.358             0.642           0.494               0.660
# 5               0.536             0.726           0.617               0.595
# 6               0.383             0.696           0.530               0.518
# 7               0.283             0.624           0.455               0.623
# 8               0.283             0.624           0.455               0.623
# 9               0.249             0.642           0.445               0.557
# 10                NaN               NaN             NaN                 NaN
# 11              0.230             0.625           0.424               0.798
# 12                NaN               NaN             NaN                 NaN
# 13              0.274             0.628           0.434               0.560
# 14                NaN               NaN             NaN                 NaN
# 15                NaN               NaN             NaN                 NaN
# 16              0.286             0.750           0.609               0.500
# 17                NaN               NaN             NaN                 NaN
# 18                NaN               NaN             NaN                 NaN
# 19                NaN               NaN             NaN                 NaN
# 20              0.259             0.563           0.415               0.732
# 21                NaN               NaN             NaN                 NaN
# 22              0.365             0.630           0.487               0.636
# 23                NaN               NaN             NaN                 NaN
# 24                NaN               NaN             NaN                 NaN
# 25                NaN               NaN             NaN                 NaN
# 26                NaN               NaN             NaN                 NaN
# 27              0.296             0.657           0.471               0.644
# 28                NaN               NaN             NaN                 NaN
# 29              0.418             0.515           0.471               0.652
# ..                ...               ...             ...                 ...
# 87              0.467             0.606           0.540               0.429
# 88              0.252             0.604           0.437               0.692
# 89                NaN               NaN             NaN                 NaN
# 90              0.262             0.593           0.431               0.634
# 91                NaN               NaN             NaN                 NaN
# 92              0.415             0.607           0.507               0.633
# 93              0.467             0.606           0.540               0.429
# 94              0.467             0.606           0.540               0.429
# 95              0.467             0.606           0.540               0.429
# 96              0.259             0.717           0.504               0.519
# 97              0.259             0.717           0.504               0.519
# 98              0.259             0.717           0.504               0.519
# 99              0.415             0.607           0.507               0.633
# 100             0.291             0.689           0.468               0.451
# 101               NaN               NaN             NaN                 NaN
# 102             0.259             0.717           0.504               0.519
# 103             0.259             0.717           0.504               0.519
# 104               NaN               NaN             NaN                 NaN
# 105             0.231             0.614           0.419               0.541
# 106             0.285             0.665           0.470               0.564
# 107             0.285             0.665           0.470               0.564
# 108             0.321             0.610           0.454               0.662
# 109             0.345             0.683           0.517               0.441
# 110               NaN               NaN             NaN                 NaN
# 111             0.467             0.606           0.540               0.429
# 112             0.467             0.606           0.540               0.429
# 113             0.467             0.606           0.540               0.429
# 114               NaN               NaN             NaN                 NaN
# 115               NaN               NaN             NaN                 NaN
# 116               NaN               NaN             NaN                 NaN
#
#      18_Z-Contact% (pi)  18_Contact% (pi)  18_Zone% (pi)  18_Pace (pi)
# 0                 0.752             0.650          0.440          22.3
# 1                 0.752             0.650          0.440          22.3
# 2                   NaN               NaN            NaN           NaN
# 3                 0.781             0.704          0.451          26.1
# 4                 0.825             0.762          0.479          23.2
# 5                 0.784             0.689          0.425          25.8
# 6                 0.810             0.698          0.469          23.4
# 7                 0.891             0.808          0.504          21.3
# 8                 0.891             0.808          0.504          21.3
# 9                 0.781             0.718          0.499          27.1
# 10                  NaN               NaN            NaN           NaN
# 11                0.941             0.901          0.491          25.6
# 12                  NaN               NaN            NaN           NaN
# 13                0.781             0.704          0.451          26.1
# 14                  NaN               NaN            NaN           NaN
# 15                  NaN               NaN            NaN           NaN
# 16                0.917             0.857          0.696          17.9
# 17                  NaN               NaN            NaN           NaN
# 18                  NaN               NaN            NaN           NaN
# 19                  NaN               NaN            NaN           NaN
# 20                0.851             0.815          0.515          23.8
# 21                  NaN               NaN            NaN           NaN
# 22                0.830             0.752          0.461          23.8
# 23                  NaN               NaN            NaN           NaN
# 24                  NaN               NaN            NaN           NaN
# 25                  NaN               NaN            NaN           NaN
# 26                  NaN               NaN            NaN           NaN
# 27                0.830             0.770          0.485          22.9
# 28                  NaN               NaN            NaN           NaN
# 29                0.882             0.790          0.546          21.7
# ..                  ...               ...            ...           ...
# 87                0.950             0.735          0.524          21.7
# 88                0.932             0.867          0.527          24.0
# 89                  NaN               NaN            NaN           NaN
# 90                0.880             0.807          0.510          23.6
# 91                  NaN               NaN            NaN           NaN
# 92                0.901             0.787          0.480          24.3
# 93                0.950             0.735          0.524          21.7
# 94                0.950             0.735          0.524          21.7
# 95                0.950             0.735          0.524          21.7
# 96                0.800             0.733          0.534          23.3
# 97                0.800             0.733          0.534          23.3
# 98                0.800             0.733          0.534          23.3
# 99                0.901             0.787          0.480          24.3
# 100               0.882             0.733          0.446          23.1
# 101                 NaN               NaN            NaN           NaN
# 102               0.800             0.733          0.534          23.3
# 103               0.800             0.733          0.534          23.3
# 104                 NaN               NaN            NaN           NaN
# 105               0.820             0.741          0.490          24.1
# 106               0.794             0.722          0.485          24.0
# 107               0.794             0.722          0.485          24.0
# 108               0.884             0.799          0.458          25.7
# 109               0.803             0.684          0.507          25.2
# 110                 NaN               NaN            NaN           NaN
# 111               0.950             0.735          0.524          21.7
# 112               0.950             0.735          0.524          21.7
# 113               0.950             0.735          0.524          21.7
# 114                 NaN               NaN            NaN           NaN
# 115                 NaN               NaN            NaN           NaN
# 116                 NaN               NaN            NaN           NaN
#
# [117 rows x 5190 columns]

# %%
stats_players_start_lineup.head()

# %%
names = stats_players_start_lineup.loc[:]["Name"].isna()

# %%
names.isnull().values.any()
